# %% [markdown]
# # loading R

# %%
# %load_ext rpy2.ipython

# %% [markdown]
# # loading CSV file

# %%
import pandas as pd

df = pd.read_csv('./data/qualtrics/Topic_Item_Assessment_doc_aspect.csv').iloc[2:].reset_index().drop(columns=['index'])
df
# Out:
#                StartDate              EndDate      Status        IPAddress  \
# 0    2024-06-14 08:41:38  2024-06-14 08:49:48  IP Address     73.6.109.221
# 1    2024-06-14 08:40:52  2024-06-14 08:49:57  IP Address     68.4.117.203
# 2    2024-06-14 08:39:36  2024-06-14 08:53:40  IP Address   67.174.243.224
# 3    2024-06-14 08:40:06  2024-06-14 08:54:23  IP Address    75.42.235.181
# 4    2024-06-14 08:37:52  2024-06-14 08:55:06  IP Address  174.199.227.180
# ..                   ...                  ...         ...              ...
# 306  2024-06-17 17:53:24  2024-06-17 17:54:56  IP Address     81.161.5.164
# 307  2024-06-17 17:21:04  2024-06-17 18:00:56  IP Address   176.46.146.141
# 308  2024-06-17 18:12:47  2024-06-17 18:37:41  IP Address    68.98.241.222
# 309  2024-06-17 18:57:21  2024-06-17 19:18:33  IP Address    47.230.33.107
# 310  2024-06-17 18:54:19  2024-06-17 19:23:33  IP Address  107.145.138.187
#
#     Progress Duration (in seconds) Finished         RecordedDate  \
# 0        100                   489     True  2024-06-14 08:49:49
# 1        100                   544     True  2024-06-14 08:49:58
# 2        100                   843     True  2024-06-14 08:53:41
# 3        100                   857     True  2024-06-14 08:54:24
# 4        100                  1034     True  2024-06-14 08:55:07
# ..       ...                   ...      ...                  ...
# 306      100                    91     True  2024-06-17 17:54:57
# 307      100                  2391     True  2024-06-17 18:00:57
# 308      100                  1493     True  2024-06-17 18:37:41
# 309      100                  1272     True  2024-06-17 19:18:34
# 310      100                  1754     True  2024-06-17 19:23:34
#
#             ResponseId RecipientLastName  ...  \
# 0    R_5rODj0o8itocxFJ               NaN  ...
# 1    R_1hlrB7VYLhwtto6               NaN  ...
# 2    R_1SAIYd9XQLHG0be               NaN  ...
# 3    R_34M0vkJJepdabpK               NaN  ...
# 4    R_6DGW5rzfLjzO0Ho               NaN  ...
# ..                 ...               ...  ...
# 306  R_3poKgpvh7jwPOm9               NaN  ...
# 307  R_6vGOzfE5sEqpSi5               NaN  ...
# 308  R_7HSLYjwnwlNP8Ib               NaN  ...
# 309  R_3Nrxk6DPy3krKZb               NaN  ...
# 310  R_3oIZo5fB2deBLbj               NaN  ...
#
#                                                   doc5     model topic_id  \
# 0    i ALWAYS have some form of this immunity stew ...       stm        0
# 1    Fuckin CHEERS y'all. Had a donut to celebrate....   scholar        3
# 2    When others eat one meal a day it's a 'diet' w...       lda        2
# 3    In honor of World Eating Disorders Action Day ...       lda        0
# 4    the other day i asked you on my story: what's ...       stm        8
# ..                                                 ...       ...      ...
# 306  I've had a manic morning. Baby fed at 1.30am a...   scholar       13
# 307  at the end of the day, this is your life and y...  bertopic        9
# 308  1:54am  im getting sick. probably caught somet...   scholar        2
# 309  I've had a manic morning. Baby fed at 1.30am a...   scholar       13
# 310  Question: What political party do you normally...       stm        1
#
#                     NPMI usefulness_first       slider slider_lower  \
# 0     0.0868595659030352            False       twenty           16
# 1    -0.1333804995008216            False  one hundred           96
# 2     0.1618759263781254            False          ten            6
# 3     0.0665338661929107            False          ten            6
# 4     0.0318481973876285            False       ninety           86
# ..                   ...              ...          ...          ...
# 306  -0.0457774936692595            False       twenty           16
# 307   0.2121661276436667            False       thirty           26
# 308  -0.0099138039220776            False       ninety           86
# 309  -0.0457774936692595            False        sixty           56
# 310    0.014207007836655            False       fourty           36
#
#     slider_upper    neg_val_question  \
# 0             29      suprised_of_AI
# 1            101              expect
# 2             19               clear
# 3             19              expect
# 4             99  related_to_dataset
# ..           ...                 ...
# 306           29               clear
# 307           39              expect
# 308           99      suprised_of_AI
# 309           69               clear
# 310           49              expect
#
#                                           neg_val_text
# 0    I am <strong> not surprised </strong>that a co...
# 1    I would<strong> not expect</strong> to see the...
# 2    It is <strong>not clear</strong> why these doc...
# 3    I would<strong> not expect</strong> to see the...
# 4    These documents are <strong>not related </stro...
# ..                                                 ...
# 306  It is <strong>not clear</strong> why these doc...
# 307  I would<strong> not expect</strong> to see the...
# 308  I am <strong> not surprised </strong>that a co...
# 309  It is <strong>not clear</strong> why these doc...
# 310  I would<strong> not expect</strong> to see the...
#
# [311 rows x 146 columns]

# %%
# tdf = df[df.prolific_id_question=='6479ef255eeda61e229715e4']
# tdf.neg_val_check_1,tdf.expect_1
# (datetime.datetime.strptime(row.EndDate,'%Y-%m-%d %H:%M:%S') - datetime.datetime.strptime(tdf.iloc[0].StartDate,'%Y-%m-%d %H:%M:%S')).seconds
#[['distinct_1', 'imagine_1', 'expect_1', 'unusual_1', 'clear_1', 'unrelated_1', 'coherent_1', 'offensive_1', 'meaningful_1', 'arbitrary_1', 'specific_perspective_1', 'confusing_1', 'one_theme_1', 'strange_1', 'general_theme_1', 'could_offend_1', 'easy_label_1', 'insight_1', 'one_randomly_added_1', 'new_way_of_thinking_1', 'neg_val_check_1', 'more_information_1', 'prefer_differently_1', 'agree_1', 'different_themes_1', 'specific_theme_1', 'do_not_fit_1', 'curious_to_know_more_1', 'emotion_1', 'label_consensus_1', 'missing_1', 'important_1', 'two_plus_random_1', 'sensible_1', 'biased_1', 'label_confident_1', 'related_to_corpus_1', 'influence_thinking_1']]
# Out:
# (52    68
#  Name: neg_val_check_1, dtype: object,
#  52    68
#  Name: expect_1, dtype: object)

# %% [markdown]
# number of data collected

# %%
df = df[df.prolific_id_question.str.len() > 5]
print('number of collected data: {0}'.format(len(df)))
# Out:
# number of collected data: 311

# %% [markdown]
# committment check

# %%
df = df[df.Commitment_question == 'Yes, I will.']
print('number of data after commitment check: {0}'.format(len(df)))
# Out:
# number of data after commitment check: 311

# %%
df = df[~pd.isna(df.set_slider_check_1)]
print('number of data after droping  slider_chek == Nan: {0}'.format(len(df)))
# Out:
# number of data after droping  slider_chek == Nan: 310

# %% [markdown]
# drop the ones who did not pass slider check

# %%
idx = []

df.set_slider_check_1 = df.set_slider_check_1.astype(int)
df.slider_upper = df.slider_upper.astype(int)
df.slider_lower = df.slider_lower.astype(int)

for i,row in df.iterrows():
    if row.set_slider_check_1>row.slider_upper or  row.set_slider_check_1<row.slider_lower:
        idx.append(i)


df = df.drop(idx)

print('number of data after slider check: {0}'.format(len(df)))
# Out:
# number of data after slider check: 307

# %% [markdown]
# dropping the ones who timed out!

# %%
import datetime

idx = []

wrong_time_outs = ['6613d855beaacc9c62ba9675','6479ef255eeda61e229715e4']

for i,row in df.iterrows():
    if (datetime.datetime.strptime(row.EndDate,'%Y-%m-%d %H:%M:%S') - datetime.datetime.strptime(row.StartDate,'%Y-%m-%d %H:%M:%S')).seconds > 3700:
        #skipping the list that Qualtrics said timeout but not Prolific
        if row.prolific_id_question in wrong_time_outs:
            continue #skip
        idx.append(i)

df = df.drop(idx)

print('number of data after timeout: {0}'.format(len(df)))
# Out:
# number of data after timeout: 306

# %% [markdown]
# list of people we should pay!

# %%
# df.sort_values('StartDate')
# df.iloc[147:]
# print(','.join(set(df.iloc[147:].prolific_id_question)))

# %%
print(','.join(set(df.prolific_id_question)))
# Out:
# 65cf6dbbe3b7c1159d0364e9,666d61258a386185e18da5f8,66428090de7c2db3caed1c77,663a5fc5b458baec47c1b160,6665c6222d980c779a45e9a5,65e1e69cc010f4b4a1ef32e6,65e5a88bbbf79d273413f88a,663200f99991108a0c4dcb23,663fab7c4193c77a18d5f5a5,5fc1c035ac92312b4c2e6bab,65327a954fb10f7a6e444ae6,6154c1748e0de2c3afdab62c,5db4ef4a2986a3000be1f886,664bae9ae5900c0b842196f2,65983c0f2ea18792568bc3bc,61489a7c8f9dfcc9f78b7c36,663e681740ee374f8d488e51,65293fa9b73b0edd4fd93b95,5f0cc2ab16b21216d946574c,666fb9bd7be39c7cf0a85ef0,637d58b9dd14dc68ba68920a,63d15e1be853005ff591b935,5f79bca83a2eb65c0983816d,66605a391a913effac6190d6,66341aa2ba380c734a4bbf24,63ea4ab1ce4168cbe9f63775,666744fa4b033e071d5996c9,5c6d7db58f6257000148f61d,6659d01c220a87b46ab7ed06,5cd6c1197b871a0001b13589,64527c12fe9ceb65346c27bf,666c9de44f9efd7d991892b9,664bf2201abae3378784ee1a,6638ed323cd2400f1d2b09d4,63d41c2627381fc53af61e58,665f812e4bf9990e80bafb62,66548532974360d0c90b9dd5,6276d97e209059496d37bf74,65631b21aff167a83105c476,662282b15472e856f6b14e2b,6100c3f0a1cd16bb87069625,663a8fe926b597c0bb778ee1,63d520bc8833c489caf0023a,62bb42e2f21cfdb280cc975f,664bc0b44b26e8834be203a0,6643dcdaee723e90ec897171,6078b85e024d1d094113c3aa,662a650b6b7d15a354343ad4,666f2488909bc0331b8563e6,615dbec57d764bf5ab0a56e5,58ccfada8460040001e1ec4f,6633bd3bc5ec5e52e25592a4,6641af97ce9ca0d0d9bf2c92,650b03136ab3d4c832d98b71,652965887d8a23695bc19e1e,65636b8039e7d18bb07ff7b9,63e5a6690eeedc20da056717,662c62abadd0ff2671ea8876,60c4e1091b936c7b812e5af4,662b9fe71356584e49abbfce,66585ecc44201efc39f333bc,6647c63962fb42240af87318,6620f9142f8c0082fd5adc7d,665f6f01b5072291dd7b5645,665696a90e34e3e67cfcfdc0,663a8ea83cc4d5845ef3a672,651c1abbc73b6eea8fa97193,66491e9882aaa64c5d0911d5,65181c2f753b188afdddd2c4,659ed4d20445e9c16df76aee,666d807a9cba927859e24e13,6529648ca1ade4b6c9e876f4,63ebbd7af1c80715178e5586,6400f8f41e203f131c68b79f,61117e8d9c4878fdd4551e02,63a2844c9d6acbec7228a420,5fe49a4ad8918ba1615e298d,6646448ac83b162ea65a4fff,6645f38dace4bab85fbbe4f8,641357b26802e397b5627d5e,65aee2cd05a6baf848046a4e

# %% [markdown]
# negative valence and Mars Check

# %%
neg_val_map = {'clear':'clear_1','related_to_dataset':'related_to_corpus_1',
              'suprised_of_AI':'suprised_of_AI_1','expect':'expect_1',}


import datetime

idx = []

df.neg_val_check_1 = df.neg_val_check_1.astype(float)
df = df[~pd.isna(df.neg_val_check_1)]

for i,row in df.iterrows():
    val = 100-int(row.neg_val_check_1)
    check = int(row[neg_val_map[row.neg_val_question]])
    if (check-10>val or val>check+10) and (row.mars != 'Never') :
        idx.append(i)
        # print(row.neg_val_question,row.neg_val_check_1,row[neg_val_map[row.neg_val_question]])
        # print(row.mars)


df = df.drop(idx)

print('number of data after negative valence & Mars check: {0}'.format(len(df)))
# Out:
# number of data after negative valence & Mars check: 306

# %% [markdown]
# checking data distribution

# %%
# df.topic_id,df.model
import seaborn as sns

sns.distplot(list(df.usefulness_1)).set_title('term aspect')
# Out:
# /var/folders/86/nw630jn16nsg2zqycwy774640000gn/T/ipykernel_3577/1628978546.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(list(df.usefulness_1)).set_title('term aspect')
# Text(0.5, 1.0, 'term aspect')

# %% [markdown]
# checking topic distribution

# %%
from collections import Counter

topic_dist = [i+str(j) for i,j in zip(list(df.model), \
                                    list(df.topic_id))]
Counter(topic_dist)
# Out:
# Counter({'scholar10': 6,
#          'bertopic12': 6,
#          'stm4': 6,
#          'stm9': 6,
#          'lda11': 6,
#          'lda14': 6,
#          'lda2': 6,
#          'scholar2': 5,
#          'scholar14': 5,
#          'stm6': 5,
#          'stm3': 5,
#          'lda3': 5,
#          'bertopic1': 5,
#          'scholar13': 5,
#          'lda12': 5,
#          'stm1': 5,
#          'bertopic13': 5,
#          'stm10': 5,
#          'scholar5': 5,
#          'stm7': 5,
#          'lda7': 5,
#          'scholar0': 5,
#          'stm14': 5,
#          'lda1': 5,
#          'bertopic5': 5,
#          'lda0': 5,
#          'bertopic3': 5,
#          'bertopic8': 5,
#          'bertopic7': 5,
#          'stm11': 5,
#          'bertopic6': 5,
#          'stm5': 5,
#          'bertopic15': 5,
#          'scholar4': 5,
#          'stm12': 5,
#          'lda10': 5,
#          'lda6': 5,
#          'scholar11': 5,
#          'bertopic11': 5,
#          'lda9': 5,
#          'bertopic4': 5,
#          'bertopic9': 5,
#          'bertopic10': 5,
#          'stm13': 5,
#          'bertopic2': 5,
#          'scholar1': 5,
#          'scholar8': 5,
#          'bertopic14': 5,
#          'scholar12': 5,
#          'scholar7': 5,
#          'lda4': 5,
#          'stm0': 5,
#          'stm2': 5,
#          'scholar3': 5,
#          'scholar6': 5,
#          'lda8': 5,
#          'lda5': 5,
#          'scholar9': 4,
#          'lda13': 4,
#          'stm8': 4})

# %% [markdown]
# lets check the text input

# %%
# print('\n'.join(list(df.participant_criteria)))
print('\n'.join(list(df.participant_criteria.dropna())))
# Out:
# disgusting words with little social value
# travel
# Water melon
# i could explain the relationship to a stranger
# Relevance to context
# cookie
# healing
# nutrition
# parents
# indulge

# %%
import collections
# df.usefulness_1,df.usefulness_first_1
# df[["usefulness_first_1","usefulness_1","theme_representation"]].groupby("theme_representation").sum()

df.usefulness_first_1 = df.usefulness_first_1.astype(float)
df.usefulness_1 = df.usefulness_1.astype(float)
print(df[["usefulness_first_1","theme_representation"]].dropna().groupby("theme_representation").mean())
df[["usefulness_1","theme_representation"]].dropna().groupby("theme_representation").mean()

# df[df.topic_id=='11'].doc1
# Out:
#                                                     usefulness_first_1
# theme_representation
# five associated documents                                    60.166667
# ten representative words                                     81.750000
# ten representative words and five associated do...           71.153846
#                                                     usefulness_1
# theme_representation
# five associated documents                                   54.8
# ten representative words                                    77.0
# ten representative words and five associated do...          66.0

# %%
udf = df[["usefulness_1","theme_representation"]].dropna()
udf['order'] = "last"
udf['rating'] = udf.usefulness_1

ldf = df[["usefulness_first_1","theme_representation"]].dropna()
ldf['order'] = "first"
ldf['rating'] = ldf.usefulness_first_1

use_df = pd.concat([udf,ldf])
use_df = use_df.drop(columns=["usefulness_first_1","usefulness_1"])
use_df
# Out:
#                                  theme_representation  order  rating
# 1                           five associated documents   last    82.0
# 5                            ten representative words   last    80.0
# 7   ten representative words and five associated d...   last    70.0
# 8   ten representative words and five associated d...   last    67.0
# 12                          five associated documents   last    59.0
# 14                           ten representative words   last    92.0
# 15                          five associated documents   last    10.0
# 16                           ten representative words   last   100.0
# 17                           ten representative words   last   100.0
# 19                           ten representative words   last    50.0
# 20                          five associated documents   last    70.0
# 22                          five associated documents   last    70.0
# 23  ten representative words and five associated d...   last    60.0
# 24                           ten representative words   last    57.0
# 25                          five associated documents   last    80.0
# 27                           ten representative words   last    66.0
# 32                           ten representative words   last    75.0
# 36                           ten representative words   last    43.0
# 38  ten representative words and five associated d...   last    95.0
# 40  ten representative words and five associated d...   last    80.0
# 43                           ten representative words   last    70.0
# 44                           ten representative words   last   100.0
# 45                          five associated documents   last    43.0
# 47  ten representative words and five associated d...   last    81.0
# 49  ten representative words and five associated d...   last     9.0
# 52                          five associated documents   last     9.0
# 56                          five associated documents   last    70.0
# 57                           ten representative words   last    91.0
# 61                          five associated documents   last    55.0
# 0                            ten representative words  first    74.0
# 2                            ten representative words  first    56.0
# 3                            ten representative words  first    80.0
# 6                           five associated documents  first    80.0
# 9   ten representative words and five associated d...  first    80.0
# 10  ten representative words and five associated d...  first    29.0
# 11                           ten representative words  first    85.0
# 13                          five associated documents  first    70.0
# 18                           ten representative words  first    85.0
# 21                           ten representative words  first    94.0
# 26                          five associated documents  first    80.0
# 28                           ten representative words  first    58.0
# 29  ten representative words and five associated d...  first    75.0
# 30                           ten representative words  first    87.0
# 31  ten representative words and five associated d...  first    72.0
# 33  ten representative words and five associated d...  first    55.0
# 34  ten representative words and five associated d...  first    53.0
# 35                          five associated documents  first    40.0
# 37  ten representative words and five associated d...  first    42.0
# 39                          five associated documents  first    50.0
# 41                           ten representative words  first    84.0
# 42                          five associated documents  first    41.0
# 46  ten representative words and five associated d...  first    92.0
# 48  ten representative words and five associated d...  first    82.0
# 50  ten representative words and five associated d...  first    96.0
# 51                           ten representative words  first   100.0
# 53                           ten representative words  first   100.0
# 54  ten representative words and five associated d...  first    70.0
# 55                           ten representative words  first    78.0
# 58  ten representative words and five associated d...  first    79.0
# 62  ten representative words and five associated d...  first   100.0

# %%
# %%R -i use_df
#
# # print(dim(use_df))
# print(summary(analysis.variance <- aov(rating ~ as.factor(order) * as.factor(theme_representation),data=use_df)))
# TukeyHSD(analysis.variance)
# Out:
#                                                  Df Sum Sq Mean Sq F value
# as.factor(order)                                  1    621   621.3   1.359
# as.factor(theme_representation)                   2   4642  2321.2   5.079
# as.factor(order):as.factor(theme_representation)  2      1     0.5   0.001
# Residuals                                        54  24680   457.0
#                                                   Pr(>F)
# as.factor(order)                                 0.24877
# as.factor(theme_representation)                  0.00953 **
# as.factor(order):as.factor(theme_representation) 0.99895
# Residuals
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = rating ~ as.factor(order) * as.factor(theme_representation), data = use_df)
#
# $`as.factor(order)`
#                 diff       lwr      upr     p adj
# last-first -6.439377 -17.51232 4.633565 0.2487703
#
# $`as.factor(theme_representation)`
#                                                                                       diff
# ten representative words-five associated documents                                21.75758
# ten representative words and five associated documents-five associated documents  10.76667
# ten representative words and five associated documents-ten representative words  -10.99091
#                                                                                         lwr
# ten representative words-five associated documents                                 5.128907
# ten representative words and five associated documents-five associated documents  -6.514350
# ten representative words and five associated documents-ten representative words  -26.589982
#                                                                                        upr
# ten representative words-five associated documents                               38.386248
# ten representative words and five associated documents-five associated documents 28.047693
# ten representative words and five associated documents-ten representative words   4.608169
#                                                                                      p adj
# ten representative words-five associated documents                               0.0073171
# ten representative words and five associated documents-five associated documents 0.2982677
# ten representative words and five associated documents-ten representative words  0.2152395
#
# $`as.factor(order):as.factor(theme_representation)`
#                                                                                                                                diff
# last:five associated documents-first:five associated documents                                                            -5.366667
# first:ten representative words-first:five associated documents                                                            21.583333
# last:ten representative words-first:five associated documents                                                             16.833333
# first:ten representative words and five associated documents-first:five associated documents                              10.987179
# last:ten representative words and five associated documents-first:five associated documents                                5.833333
# first:ten representative words-last:five associated documents                                                             26.950000
# last:ten representative words-last:five associated documents                                                              22.200000
# first:ten representative words and five associated documents-last:five associated documents                               16.353846
# last:ten representative words and five associated documents-last:five associated documents                                11.200000
# last:ten representative words-first:ten representative words                                                              -4.750000
# first:ten representative words and five associated documents-first:ten representative words                              -10.596154
# last:ten representative words and five associated documents-first:ten representative words                               -15.750000
# first:ten representative words and five associated documents-last:ten representative words                                -5.846154
# last:ten representative words and five associated documents-last:ten representative words                                -11.000000
# last:ten representative words and five associated documents-first:ten representative words and five associated documents  -5.153846
#                                                                                                                                   lwr
# last:five associated documents-first:five associated documents                                                           -37.98369380
# first:ten representative words-first:five associated documents                                                            -9.99796739
# last:ten representative words-first:five associated documents                                                            -14.74796739
# first:ten representative words and five associated documents-first:five associated documents                             -20.18660350
# last:ten representative words and five associated documents-first:five associated documents                              -29.30709409
# first:ten representative words-last:five associated documents                                                             -0.09461019
# last:ten representative words-last:five associated documents                                                              -4.84461019
# first:ten representative words and five associated documents-last:five associated documents                              -10.21374936
# last:ten representative words and five associated documents-last:five associated documents                               -19.92686982
# last:ten representative words-first:ten representative words                                                             -30.53602406
# first:ten representative words and five associated documents-first:ten representative words                              -35.88143074
# last:ten representative words and five associated documents-first:ten representative words                               -45.78980894
# first:ten representative words and five associated documents-last:ten representative words                               -31.13143074
# last:ten representative words and five associated documents-last:ten representative words                                -41.03980894
# last:ten representative words and five associated documents-first:ten representative words and five associated documents -34.76493043
#                                                                                                                               upr
# last:five associated documents-first:five associated documents                                                           27.25036
# first:ten representative words-first:five associated documents                                                           53.16463
# last:ten representative words-first:five associated documents                                                            48.41463
# first:ten representative words and five associated documents-first:five associated documents                             42.16096
# last:ten representative words and five associated documents-first:five associated documents                              40.97376
# first:ten representative words-last:five associated documents                                                            53.99461
# last:ten representative words-last:five associated documents                                                             49.24461
# first:ten representative words and five associated documents-last:five associated documents                              42.92144
# last:ten representative words and five associated documents-last:five associated documents                               42.32687
# last:ten representative words-first:ten representative words                                                             21.03602
# first:ten representative words and five associated documents-first:ten representative words                              14.68912
# last:ten representative words and five associated documents-first:ten representative words                               14.28981
# first:ten representative words and five associated documents-last:ten representative words                               19.43912
# last:ten representative words and five associated documents-last:ten representative words                                19.03981
# last:ten representative words and five associated documents-first:ten representative words and five associated documents 24.45724
#                                                                                                                              p adj
# last:five associated documents-first:five associated documents                                                           0.9964700
# first:ten representative words-first:five associated documents                                                           0.3453026
# last:ten representative words-first:five associated documents                                                            0.6182988
# first:ten representative words and five associated documents-first:five associated documents                             0.9017221
# last:ten representative words and five associated documents-first:five associated documents                              0.9963193
# first:ten representative words-last:five associated documents                                                            0.0513037
# last:ten representative words-last:five associated documents                                                             0.1659228
# first:ten representative words and five associated documents-last:five associated documents                              0.4627679
# last:ten representative words and five associated documents-last:five associated documents                               0.8936940
# last:ten representative words-first:ten representative words                                                             0.9940070
# first:ten representative words and five associated documents-first:ten representative words                              0.8161711
# last:ten representative words and five associated documents-first:ten representative words                               0.6347303
# first:ten representative words and five associated documents-last:ten representative words                               0.9831017
# last:ten representative words and five associated documents-last:ten representative words                                0.8864644
# last:ten representative words and five associated documents-first:ten representative words and five associated documents 0.9954014

# %%
grp_df = use_df
grp_df['group'] = [str(i)+'-'+str(j) for i,j in zip(use_df.theme_representation,use_df.order)]
# Out:
# {'five associated documents-first',
#  'five associated documents-last',
#  'ten representative words and five associated documents-first',
#  'ten representative words and five associated documents-last',
#  'ten representative words-first',
#  'ten representative words-last'}

# %%
# %%R -i grp_df
#
# # print(dim(grp_df$value))
# group_mean<- aggregate(x= grp_df$rating,by = list(grp_df$group),FUN = mean)
# print(var(group_mean))#between group variance
#
# s <- 0
# vals = c()
# for (i in 1:60)
# {
#     v <- (grp_df$rating[i] - group_mean[group_mean$Group.1 == grp_df$group[i],"x"])^2
#     s <- s + v
#
#     # vals[i] <- v
# }
# print(s/60)
# # print(var(vals))
# # rownames(group_mean) <- group_mean$Group.1
# # print(group_mean)
#
# # gaov = aov(rating~group,data=grp_df)
# # grandmean = as.vector(gaov$"(Intercept)"[[1]][1])
# # within = summary(gaov)$"Error: Within"[[1]]$"Mean Sq"
# # dfRun = summary(gaov)$"Error: Run"[[1]]$"Df"
# # dfWithin = summary(gaov)$"Error: Within"[[1]]$"Df"
# # Run = summary(gaov)$"Error: Run"[[1]]$"Mean Sq"
# # between = (Run-within)/((dfWithin/(dfRun+1))+1)
# # print(c('between: ',between,as.vector(gaov$"(Intercept)"[[1]][1])))
# # print(ls(gaov))
#
# between <- 103.6474
# within <- 411.3396
#
# power.anova.test(groups = 6, between.var = between, within.var = within,power = .80,sig.level=0.05)
#
# # print(summary(analysis.variance <- aov(rating ~ as.factor(group),data=grp_df)))
# # print(TukeyHSD(analysis.variance))
# Out:
#         Group.1        x
# Group.1      NA       NA
# x            NA 103.6474
# [1] 411.3396
#
#      Balanced one-way analysis of variance power calculation
#
#          groups = 6
#               n = 11.14112
#     between.var = 103.6474
#      within.var = 411.3396
#       sig.level = 0.05
#           power = 0.8
#
# NOTE: n is number in each group
# In addition: Warning message:
# In var(group_mean) : NAs introduced by coercion

# %% [markdown]
# # n_factors

# %%
tdf = df[['distinct_1', 'imagine_1', 'expect_1', 'unusual_1', 'clear_1', 'unrelated_1', 'coherent_1', 'offensive_1', 'meaningful_1', 'arbitrary_1', 'specific_perspective_1', 'confusing_1', 'one_theme_1', 'strange_1', 'general_theme_1', 'could_offend_1', 'easy_label_1', 'insight_1', 'one_randomly_added_1', 'new_way_of_thinking_1', 'more_information_1', 'prefer_differently_1', 'agree_1', 'different_themes_1', 'specific_theme_1', 'do_not_fit_1', 'curious_to_know_more_1', 'emotion_1', 'label_consensus_1', 'missing_1', 'important_1', 'two_plus_random_1', 'sensible_1', 'biased_1', 'label_confident_1', 'related_to_corpus_1', 'influence_thinking_1']]#,'usefulness_1']]
for col in tdf.columns:
    tdf.loc[:,col] = pd.to_numeric(tdf[col])
# list(df.columns)
# set(df.theme_representation)

# %%
# %%R
#
# library(EGAnet)
# library(nFactors)
# library(parameters)
# library(rrcov3way)

# %% [markdown]
# correlation of usefulness vs. others

# %%
# %%R -i tdf
#
# cor(tdf)
# Out:
#                          distinct_1   imagine_1    expect_1    unusual_1
# distinct_1              1.000000000  0.43212373 -0.38592393  0.471309176
# imagine_1               0.432123734  1.00000000 -0.52634194  0.686584450
# expect_1               -0.385923933 -0.52634194  1.00000000 -0.763075895
# unusual_1               0.471309176  0.68658445 -0.76307589  1.000000000
# clear_1                -0.376357322 -0.57063884  0.82162397 -0.788572347
# unrelated_1             0.480432476  0.65682413 -0.74325702  0.892691957
# coherent_1             -0.400657405 -0.57952143  0.81620266 -0.739183604
# biased_1                1.0000000000       -0.21925629        -0.005133304
# label_confident_1      -0.2192562914        1.00000000         0.190924167
# related_to_corpus_1    -0.0051333040        0.19092417         1.000000000
# influence_thinking_1    0.1432124042        0.01505904         0.243038691
# usefulness_1           -0.2350827080        0.48957542         0.322458355
#                        influence_thinking_1 usefulness_1
# distinct_1                      0.203620882  -0.16108379
# imagine_1                       0.156604161  -0.22084384
# expect_1                        0.058557478   0.49779404
# unusual_1                       0.078874606  -0.35642979
# clear_1                         0.030093787   0.51033759
# unrelated_1                     0.056449621  -0.37145187
# coherent_1                     -0.015781321   0.45482750
# offensive_1                     0.141705087  -0.21812419
# meaningful_1                    0.163576142   0.51098537
# arbitrary_1                     0.167379746  -0.27722385
# specific_perspective_1          0.181257899   0.31000968
# confusing_1                     0.044018756  -0.40544201
# one_theme_1                     0.036998285   0.47535633
# strange_1                       0.044100927  -0.36144297
# general_theme_1                 0.204273788   0.03385642
# could_offend_1                  0.109687296  -0.15233981
# easy_label_1                    0.052709491   0.51466136
# insight_1                       0.392092332   0.38634686
# one_randomly_added_1            0.027838632  -0.35519889
# new_way_of_thinking_1           0.557962781   0.28264042
# more_information_1              0.167301425  -0.36289818
# prefer_differently_1            0.037009439  -0.39869573
# agree_1                         0.009363922   0.29316401
# different_themes_1              0.053467278  -0.14049234
# specific_theme_1                0.074880891   0.53365147
# do_not_fit_1                    0.054710126  -0.34274644
# curious_to_know_more_1          0.411297392   0.11792433
# emotion_1                       0.431951852   0.31419433
# label_consensus_1               0.008066425   0.29046234
# missing_1                       0.073448623  -0.28077570
# important_1                     0.253403764   0.50921363
# two_plus_random_1               0.109958951  -0.35129634
# sensible_1                      0.169157922   0.46016909
# biased_1                        0.143212404  -0.23508271
# label_confident_1               0.015059040   0.48957542
# related_to_corpus_1             0.243038691   0.32245836
# influence_thinking_1            1.000000000   0.24429046
# usefulness_1                    0.244290460   1.00000000

# %%
# %%R -i tdf
#
# result <- n_factors(tdf, type = "FA",  rotation = "oblimin",  algorithm = "minres",  package = c('EGAnet','psych','nFactors','fit','PCDimension'))
# # result <- n_factors(tdf, type = "FA",  rotation = "varimax",  algorithm = "minres",  package = c('EGAnet','psych','nFactors','fit','PCDimension'))
# print(summary(result))
# as.data.frame(result)

# %%
# %%R -i tdf
#
# library(psych) #loading fa (Factor Analysis library)
# library(GPArotation)
#
#
#
# efa.model <- fa(tdf,nfactors = 5,fm='minres',rotate='oblimin')#term aspect : 5
# # term.efa.model <- as.matrix(efa.model$loadings)
# doc.efa.model <- as.matrix(efa.model$loadings)
# diagram(efa.model)
# efa.model
# Out:
# Factor Analysis using method =  minres
# Call: fa(r = tdf, nfactors = 5, rotate = "oblimin", fm = "minres")
# Standardized loadings (pattern matrix) based upon correlation matrix
#                          MR1   MR5   MR2   MR3   MR4    h2   u2 com
# distinct_1              0.50  0.01  0.26 -0.01  0.04 0.323 0.68 1.5
# imagine_1               0.67  0.08  0.11  0.07  0.06 0.512 0.49 1.1
# expect_1               -0.79 -0.05  0.09  0.05  0.11 0.722 0.28 1.1
# unusual_1               0.91  0.03  0.02  0.06  0.15 0.877 0.12 1.1
# clear_1                -0.90  0.03  0.04  0.04  0.15 0.799 0.20 1.1
# unrelated_1             0.85  0.11 -0.01  0.08  0.16 0.864 0.14 1.1
# coherent_1             -0.82 -0.01  0.03  0.10  0.09 0.752 0.25 1.1
# offensive_1             0.51  0.01  0.05 -0.09  0.54 0.684 0.32 2.1
# meaningful_1           -0.61  0.02  0.29  0.10  0.09 0.547 0.45 1.5
# arbitrary_1             0.74 -0.01  0.12 -0.02  0.16 0.622 0.38 1.2
# specific_perspective_1 -0.42  0.02  0.27  0.05  0.13 0.303 0.70 2.0
# confusing_1             0.87  0.12  0.02  0.08  0.09 0.883 0.12 1.1
# one_theme_1            -0.70  0.05  0.11  0.21  0.12 0.640 0.36 1.3
# strange_1               0.84  0.13  0.00  0.08  0.14 0.855 0.14 1.1
# general_theme_1        -0.06 -0.01  0.22 -0.11  0.00 0.052 0.95 1.7
# could_offend_1          0.17  0.05 -0.03 -0.19  0.71 0.635 0.36 1.3
# easy_label_1           -0.66 -0.06  0.03  0.24  0.16 0.712 0.29 1.4
# insight_1              -0.15 -0.01  0.64  0.03  0.08 0.491 0.51 1.1
# one_randomly_added_1   -0.02  0.83 -0.07  0.08 -0.02 0.611 0.39 1.0
# new_way_of_thinking_1   0.00 -0.03  0.80 -0.06 -0.01 0.624 0.38 1.0
# more_information_1      0.66  0.20  0.20 -0.05  0.04 0.724 0.28 1.4
# prefer_differently_1    0.61  0.25  0.05 -0.08  0.04 0.713 0.29 1.4
# agree_1                 0.06 -0.08  0.03  0.69 -0.20 0.520 0.48 1.2
# different_themes_1      0.21  0.12  0.16 -0.27  0.01 0.254 0.75 3.1
# specific_theme_1       -0.55  0.00  0.06  0.42  0.18 0.718 0.28 2.1
# do_not_fit_1            0.01  0.82 -0.01 -0.09 -0.03 0.740 0.26 1.0
# curious_to_know_more_1  0.16  0.11  0.68  0.02 -0.24 0.465 0.54 1.4
# emotion_1              -0.06 -0.02  0.58  0.05  0.03 0.372 0.63 1.0
# label_consensus_1       0.09 -0.04 -0.05  0.84 -0.07 0.656 0.34 1.1
# missing_1               0.11  0.46  0.10 -0.17  0.11 0.431 0.57 1.6
# important_1            -0.30 -0.10  0.36  0.33  0.21 0.608 0.39 3.8
# two_plus_random_1       0.27  0.55  0.10 -0.11  0.03 0.680 0.32 1.6
# sensible_1             -0.32 -0.16  0.20  0.32  0.09 0.500 0.50 3.3
# biased_1               -0.09  0.26  0.04 -0.21  0.23 0.183 0.82 3.2
# label_confident_1      -0.20 -0.19  0.01  0.54  0.03 0.594 0.41 1.5
# related_to_corpus_1    -0.27 -0.03  0.10  0.05  0.36 0.232 0.77 2.1
# influence_thinking_1    0.09 -0.06  0.68 -0.07  0.02 0.457 0.54 1.1
#
#                         MR1  MR5  MR2  MR3  MR4
# SS loadings           10.83 3.10 3.03 2.89 1.50
# Proportion Var         0.29 0.08 0.08 0.08 0.04
# Cumulative Var         0.29 0.38 0.46 0.54 0.58
# Proportion Explained   0.51 0.15 0.14 0.14 0.07
# Cumulative Proportion  0.51 0.65 0.79 0.93 1.00
#
#  With factor correlations of
#       MR1   MR5   MR2   MR3  MR4
# MR1  1.00  0.66 -0.06 -0.44 0.14
# MR5  0.66  1.00  0.06 -0.39 0.16
# MR2 -0.06  0.06  1.00  0.18 0.28
# MR3 -0.44 -0.39  0.18  1.00 0.05
# MR4  0.14  0.16  0.28  0.05 1.00
#
# Mean item complexity =  1.6
# Test of the hypothesis that 5 factors are sufficient.
#
# The degrees of freedom for the null model are  666  and the objective function was  29.6 FALSE with Chi Square of  8639.28
# The degrees of freedom for the model are 491  and the objective function was  3.58
#  FALSE
# The root mean square of the residuals (RMSR) is  0.03
# The df corrected root mean square of the residuals is  0.04
#  FALSE
# The harmonic number of observations is  306 with the empirical chi square  395.71  with prob <  1
#  FALSEThe total number of observations was  306  with Likelihood Chi Square =  1032.14  with prob <  1.2e-40
#  FALSE
# Tucker Lewis Index of factoring reliability =  0.907
# RMSEA index =  0.06  and the 90 % confidence intervals are  0.055 0.065 FALSE
# BIC =  -1778.14
# Fit based upon off diagonal values = 0.99
# Measures of factor score adequacy
#                                                    MR1  MR5  MR2  MR3  MR4
# Correlation of (regression) scores with factors   0.99 0.94 0.93 0.93 0.89
# Multiple R square of scores with factors          0.98 0.88 0.86 0.86 0.80
# Minimum correlation of possible factor scores     0.95 0.76 0.72 0.72 0.60

# %% [markdown]
# factor comparisons or factor congruence

# %%
# %%R
#
# factor.congruence(term.efa.model,doc.efa.model)
# Out:
#       MR1   MR5  MR2   MR3  MR4
# MR1  0.98  0.21 0.02 -0.18 0.07
# MR3 -0.32 -0.23 0.00  0.93 0.04
# MR2 -0.11  0.06 0.92  0.07 0.20
# MR4  0.23  0.95 0.02 -0.13 0.05
# MR5  0.02  0.09 0.27 -0.04 0.81

# %% [markdown]
# Checking correlation of varimax factors

# %%
# %%R
#
# f1 = c('imagine_1','unusual_1','unrelated_1','arbitrary_1','confusing_1','strange_1','more_information_1','prefer_differently_1')
# f3 = c('agree_1','different_themes_1','label_consensus_1','label_confident_1')
# f2 = c('new_way_of_thinking_1','insight_1','specific_perspective_1')
# f4 = c('one_randomly_added_1','do_not_fit_1')
# f5 = c('could_offend_1')
#
#
# tdf$f1 <- as.matrix(tdf[,f1]) %*% efa.model$loadings[f1,1]
# tdf$f2 <- as.matrix(tdf[,f2]) %*% efa.model$loadings[f2,2]
# tdf$f3 <- as.matrix(tdf[,f3]) %*% efa.model$loadings[f3,1]
# tdf$f4 <- as.matrix(tdf[,f4]) %*% efa.model$loadings[f4,1]
# tdf$f5 <- as.matrix(tdf[,f5]) %*% efa.model$loadings[f5,1]
#
# cor(tdf[,c('f1','f2','f3','f4','f5')])
# Out:
#            f1          f2         f3          f4         f5
# f1  1.0000000 -0.14564115  0.5805170  0.48713889 0.42674556
# f2 -0.1456412  1.00000000 -0.2537800 -0.07404173 0.04322354
# f3  0.5805170 -0.25377996  1.0000000  0.27251038 0.19820432
# f4  0.4871389 -0.07404173  0.2725104  1.00000000 0.27659646
# f5  0.4267456  0.04322354  0.1982043  0.27659646 1.00000000
