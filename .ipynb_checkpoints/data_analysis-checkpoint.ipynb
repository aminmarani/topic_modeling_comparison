# 0   R_7noreC9zRDpbt3H               NaN  ...
# 1   R_1WI3eYTiYq2QjVD               NaN  ...
# 2   R_12svQAkwxkOOn0E               NaN  ...
# 3   R_3DU9Ad0NQQ0f5cL               NaN  ...
# 4   R_5QmzLLzYLbI4sqo               NaN  ...
# 5   R_3M0rmHEoYEoNOK1               NaN  ...
# 6   R_6OVeJfAhvibjTBI               NaN  ...
# 7   R_7Hh4prYVIkAPc7x               NaN  ...
# 8   R_3jN9SwiD8ZGoDYh               NaN  ...
# 9   R_1CbkiYKYXQbL3oJ               NaN  ...
# 10  R_7QyDD3lyoyaJs7C               NaN  ...
# 11  R_70P1gkfFNN8TMPF               NaN  ...
# 12  R_6JDPE2aKVZPcpZp               NaN  ...
# 13  R_5KeF2h0pPy0WnjX               NaN  ...
# 14  R_6wtHpzYMbtR9Xqx               NaN  ...
# 15  R_7qfOqrUVUUYZjHp               NaN  ...
# 16  R_5BUY3hDIBi3DpGP               NaN  ...
# 17  R_72SuCC271wBy8im               NaN  ...
# 18  R_3xgeaiWMZTHCF8d               NaN  ...
# 19  R_5lsmZp3SKIKgJCV               NaN  ...
# 20  R_3e5ksacDXrN5RVn               NaN  ...
# 21  R_12bTJbNmdyfdw4u               NaN  ...
# 22  R_7pHXQm0PBr7tl5f               NaN  ...
# 23  R_6y8WdCb1HCw4kCW               NaN  ...
# 24  R_7NOkjtoioFCATey               NaN  ...
# 25  R_6EiEIOGYE8a8Zjw               NaN  ...
# 26  R_5MK0SK9htbFdCmd               NaN  ...
# 27  R_5n3codoOwff1yVz               NaN  ...
# 28  R_5FQDh4DSVKrqQGl               NaN  ...
# 29  R_1aj2PY6sIjpqdkl               NaN  ...
# 30  R_3dFBgyXYoXLHT3U               NaN  ...
# 31  R_3dNbjlb2xtuyFg1               NaN  ...
# 32  R_1C9qAqyazs6b9qJ               NaN  ...
# 33  R_6svkJuE1RNoF845               NaN  ...
# 34  R_3mf7eP0XgBYXCCv               NaN  ...
# 35  R_1wGlJXhqMwMHSgW               NaN  ...
# 36  R_7kUMhXtB3Vwtzfj               NaN  ...
# 37  R_3sS4YG9ysBOcdK9               NaN  ...
# 38  R_1BZyPpJLULhX2nf               NaN  ...
# 39  R_1ylrrSrOcuQTChR               NaN  ...
# 40  R_7dSKcv0ffYyXJse               NaN  ...
#
#                                                  doc5     model topic_id  \
# 0   Question: What political party do you normally...       stm        1
# 1   yall my voice is coming BACK. (consequently I ...  bertopic       13
# 2   I'm not single, I'm just dating myself 💐<br><b...       stm       10
# 3   file under: self care, free therapy, pure happ...   scholar        5
# 4   I'm a goddess, don't get it twisted<br><br>ps-...  bertopic       12
# 5   Day 36 of inpatient was okay. I didn't sleep w...       stm        7
# 6   the recipe that single handedly made me a lemo...       lda        7
# 7   In honor of Joe Speir's 5th Angel Anniversary,...   scholar        0
# 8   love. this. freaking. salad. 👏🏽 // power salad...       stm       14
# 9   Breakfast is always the culprit. Either i wake...       lda        1
# 10  mentalhealthmartini: <br><br> pros of having a...       stm        4
# 11  these pictures are taken one year apart. aside...  bertopic        5
# 12  In honor of World Eating Disorders Action Day ...       lda        0
# 13  Question: So I have a question.  Do you ever f...  bertopic        3
# 14  ✨ When you change the way you look at things, ...       stm        9
# 15  Day 13 of inpatient was bad. I got woken up ea...  bertopic        8
# 16  On the final day of #MentalHealthAwarenessMont...  bertopic        7
# 17  it's 4pm and you know my chocolate craving is ...       stm       11
# 18  I am ALL for recovery. I always will be. For e...  bertopic        6
# 19  hierarchical-aestheticism :  <br> Women statue...       lda       11
# 20  ‼️GIVEAWAY ALERT‼️<br>Extremely excited to ann...       stm        5
# 21  Question: Why didn't anyone want to eat the ca...  bertopic       15
# 22  Local pissed off bitch rants again:Im going to...   scholar        4
# 23  Apparently I'm away more than I'm at home at t...       stm       12
# 24  The gym selfie you usually see online VS what ...       lda       10
# 25  veggin' out like ✌🏼✌🏼✌🏼 busy busy day but ther...       lda        6
# 26  cutpriceguignol-deactivated2022:Shout out to a...   scholar       11
# 27  Question: Anon, Sweden is not mass testing, Sw...  bertopic       11
# 28  Swipe ➡️for a reframe that changed my life<br>...       lda        9
# 29  Question: Anon, Sweden is not mass testing, Sw...  bertopic       11
# 30  to the ones who are struggling,<br>the ones wh...       lda       12
# 31  Holly Goes Solo ROUND 3 🤩🌍✌🏻<br>-<br>Don't eve...  bertopic        4
# 32  If i gotta see one more pic of a recovery warr...       lda       14
# 33  at the end of the day, this is your life and y...  bertopic        9
# 34  Melllllting   Oh my goodness what a hot day it...  bertopic       10
# 35  No these are not lentils, not chickpeas, but S...       stm       13
# 36  i used to make 3-ingredient vegan cookie dough...  bertopic        2
# 37  Therapy 22.10.19 // part 2 // weight going dow...   scholar        1
# 38  Without. a. doubt. THiS cake was THE BEST birt...       lda       13
# 39  When others eat one meal a day it's a 'diet' w...       lda        2
# 40  for anyone who's ever asked me where i possibl...   scholar        8
#
#                    NPMI usefulness_first       slider slider_lower  \
# 0     0.014207007836655            False        sixty           56
# 1    0.0557692969744933            False          ten            6
# 2    0.0508991229139362            False          ten            6
# 3    0.1243542452021496            False       ninety           86
# 4    0.1671956471462582            False       twenty           16
# 5    0.0506314854331052            False  one hundred           96
# 6    0.1178832266214691            False       eighty           76
# 7    0.0273431189783318            False       fourty           36
# 8    0.1053688522119064            False       twenty           16
# 9    0.0811925167577126            False          ten            6
# 10   0.1424216444158813            False       thirty           26
# 11  -0.0957887783836396            False       eighty           76
# 12   0.0665338661929107            False        fifty           46
# 13     0.09584414458054            False  one hundred           96
# 14   0.0346375311207305            False        sixty           56
# 15  -0.0535346779097914            False       eighty           76
# 16   0.0967808185420171            False  one hundred           96
# 17    0.122882142913259            False       thirty           26
# 18   0.0584623410849583            False       thirty           26
# 19   0.0602650331933303            False        fifty           46
# 20   0.0830811799332058            False      seventy           66
# 21   0.1904263691230409            False          ten            6
# 22    0.100644296032823            False       twenty           16
# 23   0.0386036760839043            False      seventy           66
# 24   0.0234895981008247            False       ninety           86
# 25   0.0685144885545312            False          ten            6
# 26  -0.1733459094937725            False       ninety           86
# 27  -0.0877324349297858            False       ninety           86
# 28   0.0107709846054428            False        sixty           56
# 29  -0.0877324349297858            False       fourty           36
# 30   0.0407211877032034            False      seventy           66
# 31   0.0206338608366163            False       twenty           16
# 32   0.0549823060031424            False       twenty           16
# 33   0.2121661276436667            False       thirty           26
# 34  -0.0467621530882656            False       eighty           76
# 35   0.1958798428993692            False  one hundred           96
# 36   0.2502496783741754            False  one hundred           96
# 37   0.0648666244147022            False  one hundred           96
# 38   0.0322320157187325            False          ten            6
# 39   0.1618759263781254            False       ninety           86
# 40   0.1104356061554188            False       ninety           86
#
#    slider_upper    neg_val_question  \
# 0            69  related_to_dataset
# 1            19               clear
# 2            19              expect
# 3            99      suprised_of_AI
# 4            29               clear
# 5           101  related_to_dataset
# 6            89              expect
# 7            49               clear
# 8            29              expect
# 9            19      suprised_of_AI
# 10           39      suprised_of_AI
# 11           89               clear
# 12           59               clear
# 13          101               clear
# 14           69              expect
# 15           89               clear
# 16          101               clear
# 17           39               clear
# 18           39  related_to_dataset
# 19           59               clear
# 20           79               clear
# 21           19              expect
# 22           29               clear
# 23           79               clear
# 24           99      suprised_of_AI
# 25           19              expect
# 26           99  related_to_dataset
# 27           99      suprised_of_AI
# 28           69              expect
# 29           49      suprised_of_AI
# 30           79              expect
# 31           29              expect
# 32           29               clear
# 33           39              expect
# 34           89              expect
# 35          101      suprised_of_AI
# 36          101      suprised_of_AI
# 37          101               clear
# 38           19              expect
# 39           99              expect
# 40           99               clear
#
#                                          neg_val_text
# 0   These words are <strong>not related </strong>t...
# 1   It is <strong>not clear</strong> why these wor...
# 2   I would<strong> not expect</strong> to see the...
# 3   I am <strong> not surprised </strong>that a co...
# 4   It is <strong>not clear</strong> why these wor...
# 5   These words are <strong>not related </strong>t...
# 6   I would<strong> not expect</strong> to see the...
# 7   It is <strong>not clear</strong> why these wor...
# 8   I would<strong> not expect</strong> to see the...
# 9   I am <strong> not surprised </strong>that a co...
# 10  I am <strong> not surprised </strong>that a co...
# 11  It is <strong>not clear</strong> why these wor...
# 12  It is <strong>not clear</strong> why these wor...
# 13  It is <strong>not clear</strong> why these wor...
# 14  I would<strong> not expect</strong> to see the...
# 15  It is <strong>not clear</strong> why these wor...
# 16  It is <strong>not clear</strong> why these wor...
# 17  It is <strong>not clear</strong> why these wor...
# 18  These words are <strong>not related </strong>t...
# 19  It is <strong>not clear</strong> why these wor...
# 20  It is <strong>not clear</strong> why these wor...
# 21  I would<strong> not expect</strong> to see the...
# 22  It is <strong>not clear</strong> why these wor...
# 23  It is <strong>not clear</strong> why these wor...
# 24  I am <strong> not surprised </strong>that a co...
# 25  I would<strong> not expect</strong> to see the...
# 26  These words are <strong>not related </strong>t...
# 27  I am <strong> not surprised </strong>that a co...
# 28  I would<strong> not expect</strong> to see the...
# 29  I am <strong> not surprised </strong>that a co...
# 30  I would<strong> not expect</strong> to see the...
# 31  I would<strong> not expect</strong> to see the...
# 32  It is <strong>not clear</strong> why these wor...
# 33  I would<strong> not expect</strong> to see the...
# 34  I would<strong> not expect</strong> to see the...
# 35  I am <strong> not surprised </strong>that a co...
# 36  I am <strong> not surprised </strong>that a co...
# 37  It is <strong>not clear</strong> why these wor...
# 38  I would<strong> not expect</strong> to see the...
# 39  I would<strong> not expect</strong> to see the...
# 40  It is <strong>not clear</strong> why these wor...
#
# [41 rows x 146 columns]

# %% [markdown]
# number of data collected

# %%
df = df[df.prolific_id_question.str.len() > 5]
print('number of collected data: {0}'.format(len(df)))
# Out:
# number of collected data: 41

# %% [markdown]
# committment check

# %%
df = df[df.Commitment_question == 'Yes, I will.']
print('number of data after commitment check: {0}'.format(len(df)))
# Out:
# number of data after commitment check: 41

# %% [markdown]
# drop the ones who did not pass slider check

# %%
idx = []

df.set_slider_check_1 = df.set_slider_check_1.astype(int)
df.slider_upper = df.slider_upper.astype(int)
df.slider_lower = df.slider_lower.astype(int)

for i,row in df.iterrows():
    if row.set_slider_check_1>row.slider_upper or  row.set_slider_check_1<row.slider_lower:
        # print(row.set_slider_check_1,row.slider,row.slider_lower,row.slider_upper)
        idx.append(i)


df = df.drop(idx)

print('number of data after slider check: {0}'.format(len(df)))
# Out:
# number of data after slider check: 41

# %% [markdown]
# dropping the ones who timed out!

# %%
import datetime

idx = []

for i,row in df.iterrows():
    if (datetime.datetime.strptime(row.EndDate,'%Y-%m-%d %H:%M:%S') - datetime.datetime.strptime(row.StartDate,'%Y-%m-%d %H:%M:%S')).seconds > 3360:
        idx.append(i)

df = df.drop(idx)

print('number of data after timeout: {0}'.format(len(df)))
# Out:
# number of data after timeout: 41

# %% [markdown]
# list of people we should pay!

# %%
print(','.join(set(df.prolific_id_question)))
# Out:
# 6662149979f662803eff17de,6610d63631a5eb4328f61c03,6629b6bbe26513bce427df54,6661e11d7c0b4b2265491e5f,5e7129105f07e2038154621a,6400de8f305c51d03c2a9a0e,66622d4acbfc608af24ef17c,663e40565034675772c712f7,614e6f4f00a9e94b123316d3,5c738c1738ff4500017ba1fd,60da51c134df429f4806381a,57509ce803a9750006e311a5,6660cf28e84fdd1b7cd8a450,65cd0c952501aa81d90250d1,6664af330138265e6500381c,65cb84b39bb04db307f28ef7,6664976e6c239e93774ad7d9,60fab1b96bd45f60d1b053dc,662d57d09714cf1c25756326,66639467c7d0df666345fd10,6654861d159b75308b02cfee,5c2fd570e4dd550001e4aa9d,6650febe4228b362517703ee,66514b848f0c8f2c4cd7b025,5faf887aa9c32221f28e240a,66505efb53953d2da6e1a8cd,6661f73b96bb7dd754b9e196,65cd90916d6c5ca9f796e9a3,6648676d5034bff572b0b574,660eceadf7cb19e5bc73aa99,66630a13a509219075157373,6108781e0d1dd936d2b75432,665a968a895ff62a86e127da,66646209b821e70655b52198,6663c09d3fc84cb36dba1139,65ce48bd5a58224a4b85d6bc,666394616b236513fef5062f,6129d940b66000436442b65d,63d85df2ce828accc88ba837,65f860a1ab03181926bce465

# %% [markdown]
# negative valence and Mars Check

# %%
neg_val_map = {'clear':'clear_1','related_to_dataset':'related_to_corpus_1',
              'suprised_of_AI':'suprised_of_AI_1','expect':'expect_1',}


import datetime

idx = []

for i,row in df.iterrows():
    val = 100-int(row.neg_val_check_1)
    check = int(row[neg_val_map[row.neg_val_question]])
    if (check-10>val or val>check+10) and (row.mars != 'Never') :
        idx.append(i)
        # print(row.neg_val_question,row.neg_val_check_1,row[neg_val_map[row.neg_val_question]])
        # print(row.mars)


df = df.drop(idx)

print('number of data after negative valence & Mars check: {0}'.format(len(df)))
# Out:
# number of data after negative valence & Mars check: 10

# %% [markdown]
# checking data distribution

# %%
# df.topic_id,df.model
import seaborn as sns

sns.distplot(list(df.usefulness_1))
# Out:
# /var/folders/86/nw630jn16nsg2zqycwy774640000gn/T/ipykernel_9596/662402430.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(list(df.usefulness_1))
# <Axes: ylabel='Density'>

# %% [markdown]
# lets check the text input

# %%
# print('\n'.join(list(df.participant_criteria)))
print('\n'.join(list(df.participant_criteria.dropna())))
# Out:
# disgusting words with little social value
# travel
# Water melon
# i could explain the relationship to a stranger
# Relevance to context
# cookie
# healing
# nutrition
# parents
# indulge

# %%
import collections
# df.usefulness_1,df.usefulness_first_1
# df[["usefulness_first_1","usefulness_1","theme_representation"]].groupby("theme_representation").sum()

df.usefulness_first_1 = df.usefulness_first_1.astype(float)
df.usefulness_1 = df.usefulness_1.astype(float)
print(df[["usefulness_first_1","theme_representation"]].dropna().groupby("theme_representation").mean())
df[["usefulness_1","theme_representation"]].dropna().groupby("theme_representation").mean()

# df[df.topic_id=='11'].doc1
# Out:
#                                                     usefulness_first_1
# theme_representation
# five associated documents                                    60.166667
# ten representative words                                     81.750000
# ten representative words and five associated do...           71.153846
#                                                     usefulness_1
# theme_representation
# five associated documents                                   54.8
# ten representative words                                    77.0
# ten representative words and five associated do...          66.0

# %%
udf = df[["usefulness_1","theme_representation"]].dropna()
udf['order'] = "last"
udf['rating'] = udf.usefulness_1

ldf = df[["usefulness_first_1","theme_representation"]].dropna()
ldf['order'] = "first"
ldf['rating'] = ldf.usefulness_first_1

use_df = pd.concat([udf,ldf])
use_df = use_df.drop(columns=["usefulness_first_1","usefulness_1"])
use_df
# Out:
#                                  theme_representation  order  rating
# 1                           five associated documents   last    82.0
# 5                            ten representative words   last    80.0
# 7   ten representative words and five associated d...   last    70.0
# 8   ten representative words and five associated d...   last    67.0
# 12                          five associated documents   last    59.0
# 14                           ten representative words   last    92.0
# 15                          five associated documents   last    10.0
# 16                           ten representative words   last   100.0
# 17                           ten representative words   last   100.0
# 19                           ten representative words   last    50.0
# 20                          five associated documents   last    70.0
# 22                          five associated documents   last    70.0
# 23  ten representative words and five associated d...   last    60.0
# 24                           ten representative words   last    57.0
# 25                          five associated documents   last    80.0
# 27                           ten representative words   last    66.0
# 32                           ten representative words   last    75.0
# 36                           ten representative words   last    43.0
# 38  ten representative words and five associated d...   last    95.0
# 40  ten representative words and five associated d...   last    80.0
# 43                           ten representative words   last    70.0
# 44                           ten representative words   last   100.0
# 45                          five associated documents   last    43.0
# 47  ten representative words and five associated d...   last    81.0
# 49  ten representative words and five associated d...   last     9.0
# 52                          five associated documents   last     9.0
# 56                          five associated documents   last    70.0
# 57                           ten representative words   last    91.0
# 61                          five associated documents   last    55.0
# 0                            ten representative words  first    74.0
# 2                            ten representative words  first    56.0
# 3                            ten representative words  first    80.0
# 6                           five associated documents  first    80.0
# 9   ten representative words and five associated d...  first    80.0
# 10  ten representative words and five associated d...  first    29.0
# 11                           ten representative words  first    85.0
# 13                          five associated documents  first    70.0
# 18                           ten representative words  first    85.0
# 21                           ten representative words  first    94.0
# 26                          five associated documents  first    80.0
# 28                           ten representative words  first    58.0
# 29  ten representative words and five associated d...  first    75.0
# 30                           ten representative words  first    87.0
# 31  ten representative words and five associated d...  first    72.0
# 33  ten representative words and five associated d...  first    55.0
# 34  ten representative words and five associated d...  first    53.0
# 35                          five associated documents  first    40.0
# 37  ten representative words and five associated d...  first    42.0
# 39                          five associated documents  first    50.0
# 41                           ten representative words  first    84.0
# 42                          five associated documents  first    41.0
# 46  ten representative words and five associated d...  first    92.0
# 48  ten representative words and five associated d...  first    82.0
# 50  ten representative words and five associated d...  first    96.0
# 51                           ten representative words  first   100.0
# 53                           ten representative words  first   100.0
# 54  ten representative words and five associated d...  first    70.0
# 55                           ten representative words  first    78.0
# 58  ten representative words and five associated d...  first    79.0
# 62  ten representative words and five associated d...  first   100.0

# %%
# %%R -i use_df
#
# # print(dim(use_df))
# print(summary(analysis.variance <- aov(rating ~ as.factor(order) * as.factor(theme_representation),data=use_df)))
# TukeyHSD(analysis.variance)
# Out:
#                                                  Df Sum Sq Mean Sq F value
# as.factor(order)                                  1    621   621.3   1.359
# as.factor(theme_representation)                   2   4642  2321.2   5.079
# as.factor(order):as.factor(theme_representation)  2      1     0.5   0.001
# Residuals                                        54  24680   457.0
#                                                   Pr(>F)
# as.factor(order)                                 0.24877
# as.factor(theme_representation)                  0.00953 **
# as.factor(order):as.factor(theme_representation) 0.99895
# Residuals
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = rating ~ as.factor(order) * as.factor(theme_representation), data = use_df)
#
# $`as.factor(order)`
#                 diff       lwr      upr     p adj
# last-first -6.439377 -17.51232 4.633565 0.2487703
#
# $`as.factor(theme_representation)`
#                                                                                       diff
# ten representative words-five associated documents                                21.75758
# ten representative words and five associated documents-five associated documents  10.76667
# ten representative words and five associated documents-ten representative words  -10.99091
#                                                                                         lwr
# ten representative words-five associated documents                                 5.128907
# last:ten representative words and five associated documents-last:ten representative words                                19.03981
# last:ten representative words and five associated documents-first:ten representative words and five associated documents 24.45724
#                                                                                                                              p adj
# last:five associated documents-first:five associated documents                                                           0.9964700
# first:ten representative words-first:five associated documents                                                           0.3453026
# last:ten representative words-first:five associated documents                                                            0.6182988
# first:ten representative words and five associated documents-first:five associated documents                             0.9017221
# last:ten representative words and five associated documents-first:five associated documents                              0.9963193
# first:ten representative words-last:five associated documents                                                            0.0513037
# last:ten representative words-last:five associated documents                                                             0.1659228
# first:ten representative words and five associated documents-last:five associated documents                              0.4627679
# last:ten representative words and five associated documents-last:five associated documents                               0.8936940
# last:ten representative words-first:ten representative words                                                             0.9940070
# first:ten representative words and five associated documents-first:ten representative words                              0.8161711
# last:ten representative words and five associated documents-first:ten representative words                               0.6347303
# first:ten representative words and five associated documents-last:ten representative words                               0.9831017
# last:ten representative words and five associated documents-last:ten representative words                                0.8864644
# last:ten representative words and five associated documents-first:ten representative words and five associated documents 0.9954014

# %%
grp_df = use_df
grp_df['group'] = [str(i)+'-'+str(j) for i,j in zip(use_df.theme_representation,use_df.order)]
# Out:
# {'five associated documents-first',
#  'five associated documents-last',
#  'ten representative words and five associated documents-first',
#  'ten representative words and five associated documents-last',
#  'ten representative words-first',
#  'ten representative words-last'}

# %%
# %%R -i grp_df
#
# # print(dim(grp_df$value))
# group_mean<- aggregate(x= grp_df$rating,by = list(grp_df$group),FUN = mean)
# print(var(group_mean))#between group variance
#
# s <- 0
# vals = c()
# for (i in 1:60)
# {
#     v <- (grp_df$rating[i] - group_mean[group_mean$Group.1 == grp_df$group[i],"x"])^2
#     s <- s + v
#
#     # vals[i] <- v
# }
# print(s/60)
# # print(var(vals))
# # rownames(group_mean) <- group_mean$Group.1
# # print(group_mean)
#
# # gaov = aov(rating~group,data=grp_df)
# # grandmean = as.vector(gaov$"(Intercept)"[[1]][1])
# # within = summary(gaov)$"Error: Within"[[1]]$"Mean Sq"
# # dfRun = summary(gaov)$"Error: Run"[[1]]$"Df"
# # dfWithin = summary(gaov)$"Error: Within"[[1]]$"Df"
# # Run = summary(gaov)$"Error: Run"[[1]]$"Mean Sq"
# # between = (Run-within)/((dfWithin/(dfRun+1))+1)
# # print(c('between: ',between,as.vector(gaov$"(Intercept)"[[1]][1])))
# # print(ls(gaov))
#
# between <- 103.6474
# within <- 411.3396
#
# power.anova.test(groups = 6, between.var = between, within.var = within,power = .80,sig.level=0.05)
#
# # print(summary(analysis.variance <- aov(rating ~ as.factor(group),data=grp_df)))
# # print(TukeyHSD(analysis.variance))
# Out:
#         Group.1        x
# Group.1      NA       NA
# x            NA 103.6474
# [1] 411.3396
#
#      Balanced one-way analysis of variance power calculation
#
#          groups = 6
#               n = 11.14112
#     between.var = 103.6474
#      within.var = 411.3396
#       sig.level = 0.05
#           power = 0.8
#
# NOTE: n is number in each group
# In addition: Warning message:
# In var(group_mean) : NAs introduced by coercion
