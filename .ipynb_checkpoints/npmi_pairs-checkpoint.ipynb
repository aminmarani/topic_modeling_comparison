# %%
from diskcache_class import db
from lda_mallet import *
from pre_processing import *
from os import walk
from tqdm import tqdm
# Out:
# [nltk_data] Downloading package stopwords to /Users/das-
# [nltk_data]     lab/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/das-lab/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /Users/das-lab/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/das-lab/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
#we are going to run this on 4 different dataset 1. EDML 2. AP 3. Newsgroup 4.Covid-Tweet


############################## reading data for ED corpus
# datafolder = './data/ed_recovery_formatted/Excel'
# #datafolder = 'ed_recovery_topicmodel'
# df = pd.DataFrame(columns=['url','type','photo','date','tags','notes','text','photo_url','reblogged','blog_name'])

# for dirpath,dirnames,filenames in walk(datafolder):
#   for filename in filenames:
#     if filename.endswith('.xlsx'):
#       t = pd.read_excel(datafolder+'/'+filename,names=['url','type','photo','date','tags','notes','text','photo_url','reblogged'])
#       blog_name = t.iloc[0,0].split(':')[1]
#       t['blog_name'] = blog_name
#       df = df.append(t.iloc[3:,:],ignore_index=True)
#       print('blog:{0}   with posts:{1}    and reblogs:{2}  '.format(filename,len(t),len(t[t.reblogged=='yes'])))


# print('number of blogs: {0} - number of posts: {1}'.format(len(set(df.blog_name)),len(df)))
# print('out of {0} documents, {1} are reblogged.'.format(len(df),len(df[df.reblogged == 'yes'])))

# #finding reblogged texts
# texts = sorted(df.text) #sort them to keep smallest post (perhaps original one) at first
# re_texts = []

# while len(texts):
#   t = [texts.pop(0)]#pop first text and find it!
#   if t[0] == ' ' or len(t[0].split())<3: 
#     continue #almost nothing to look
#   i = 0
#   while i<len(texts):
#     if t[0] in texts[i]:
#       t.append(texts.pop(i))
#     else:
#       i += 1
#   if len(t) > 1:
#     re_texts.append(t)


# print('number of unique reblogged texts: {0}'.format(len(re_texts)))
# print('number of unique string in all texts: {0}'.format(len(set(df.text))))

# extra_stopwords = ['isnt','want','cant','wanna','im','could','ive','would','dont','get','also','us','thats','got','ur','wanted',
#                    'may', 'the', 'just', 'can', 'think', 'damn', 'still', 'guys', 'literally', 'hopefully', 'much', 'even', 'rly', 'guess', 'anon']#anything with a length of one
                   

# '''pre-processing'''
# # original_doc_set = list(df.text[df.photo=='no'])
# sel_df = df[df.photo=='no'] #extracting only-text posts
# doc_list = list(sel_df.text)


# ##############reading AP corpus
# text_df = ap_corpus('./data/ap.txt')
# doc_list = list(text_df.text_cleaned)

##############reading Newsgroup corpus
text_df = newsgroup('./data/20newsgroup_preprocessed.csv')
doc_list = list(text_df.text_cleaned)


#loading ref corpus for coherene score for lda_mallet
wiki_docs = loading_wiki_docs('./data/wiki_sampled_5p.txt')
#doing pre-processing on wiki-pedia documents
pre_processed_wiki, _ = preprocess_data(wiki_docs)
wiki_vocab_dict, _ = prepare_corpus(pre_processed_wiki)
del wiki_docs

# %%
#removing terms that are not in Wikipedia ref-corpus
pre_processed_docs,filtered_docs = preprocess_data(doc_list,extra_stopwords={})
#generate vocabulary and texts
vocab_dict, doc_term_matrix = prepare_corpus(pre_processed_docs)

#finding stopwords that are not in Wikipedia and removing those
extra_stopwords = set(vocab_dict.token2id.keys()).difference(set(wiki_vocab_dict.token2id.keys()))
pre_processed_docs,filtered_docs = preprocess_data(doc_list,extra_stopwords=extra_stopwords)
vocab_dict, doc_term_matrix = prepare_corpus(pre_processed_docs)

# %%
#running many many LDA and storing their pair of terms

start = 15; limit=26; step = 1
runs = 3
term_pairs = set()

for num_topics in tqdm(range(start, limit+1, step)):
    model_t = []
    purity_t = []
    coherence_t = []
    contrast_t = []
    for r in range(runs):
        #model=LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics)
        model = LdaMallet(mallet_path, corpus=doc_term_matrix, num_topics=num_topics, id2word=vocab_dict,optimize_interval = 25,workers=1)

        #storing top_terms
        for tn in range(num_topics): 
            tt = model.show_topic(tn,topn=20)

            #saving top_terms and their counts
            top_terms = [i[0] for i in tt]

            #making pair terms
            for i in range(len(top_terms)):
                for j in range(i+1,len(top_terms)):
                    term_pairs.add((top_terms[i],top_terms[j]))
# Out:
#   0%|                                                    | 0/15 [00:00<?, ?it/s]Mallet LDA: 12 topics, 4 topic bits, 1111 topic mask
# Data loaded.
# max tokens: 12555
# total tokens: 2137668
# <10> LL/token: -9.75425
# <20> LL/token: -9.13379
# <30> LL/token: -8.98468
# <40> LL/token: -8.92471
#
# 0	4.16667	people time back mr things good day thing made told put fire make thought heard children started bad fbi home
# 1	4.16667	windows software file drive system dos bit image card program version data mac pc files graphics computer window ftp mail
# 2	4.16667	key government gun chip law public information clipper encryption number phone bill system security control message keys guns david file
# 3	4.16667	article uk ac apr cc de au hp cs ca michael se org mail wrote hz ww advance ai ns
# 4	4.16667	space nasa gov article high earth time light power system cost radio long work sun henry small problem launch apr
# 5	4.16667	ca game cs year team article win games play good mark apr hockey players season andrew john baseball mike player
# 6	4.16667	car article good price uiuc bike buy power sale dod period cars back ca st front engine la att left
# 7	4.16667	people make group time work free states support jpeg state power part world question area news local good united ed
# 8	4.16667	research university information years health number medical science year national insurance study care school money problem program ohio state drugs
# 9	4.16667	ax max gv bf db pl tm di wm ei ey um kn gk bj bh qq sl cs mu
# 10	4.16667	god people jesus christian life true bible church word christians christ question point religion evidence man faith love read paul
# 11	4.16667	article people israel jews war armenian world years turkish armenians jewish israeli history peace killed state government apr muslim today
#
# <50> LL/token: -8.88906
# <60> LL/token: -8.86853
# <70> LL/token: -8.85464
# <80> LL/token: -8.84343
# <90> LL/token: -8.83661
#
# 0	4.16667	people time back day mr things made heard told fire thing remember put children started fbi thought kind home good
# 1	4.16667	windows software file system dos drive bit image card program version mac data pc graphics files window computer ftp scsi
# 2	4.16667	key government gun law chip information public clipper encryption number bill system phone keys security david message control file access
# 3	4.16667	article uk ac apr cs de cc mail ca au michael hp se wrote org email advance hz mil fax
# 4	4.16667	space gov nasa high power earth article system time light radio long work cost henry problem design low launch ground
# 5	4.16667	ca game year team cs games play article win good hockey mark players apr season baseball mike cmu player league
# 6	4.16667	car article good sale uiuc price buy bike dod apr power cars period front cso engine st att offer back
# 7	4.16667	make people time group good question state work support states free money world case point news general power article part
# 8	4.16667	research university information health medical science years year number study national insurance article care school david problem drugs april ohio
# 9	4.16667	ax max gv bf db pl tm di wm ei um ey gk bh bj kn sl cs qq mu
# 10	4.16667	god people jesus christian life bible true question church christians christ word evidence religion faith man point truth love paul
# 11	4.16667	people article israel jews war armenian turkish world armenians jewish israeli history years government peace state killed muslim today arab
#
# <100> LL/token: -8.83054
# <110> LL/token: -8.82525
# <120> LL/token: -8.8229
# <130> LL/token: -8.82063
# <140> LL/token: -8.81709
#
# 0	4.16667	people time back day mr things thought told fire children remember thing put started heard made fbi home days bad
# 1	4.16667	windows file software dos system drive bit image card version program mac graphics files pc window ftp computer problem data
# 2	4.16667	key government gun chip law public information clipper encryption number bill phone control keys system security message guns david file
# 3	4.16667	article uk ac apr cs de cc mail au michael ca se email wrote hp org mil hz advance fax
# 4	4.16667	space gov nasa power high earth system light time radio work long cost article low henry ground launch water design
# 5	4.16667	ca game year team games play article cs win good hockey players mark season baseball apr cmu player john league
# 6	4.16667	article car good sale uiuc price buy bike ca dod apr power cars period front mike cso engine hp att
# 7	4.16667	people make time good question group money free point work states case support made state president lot world general give
# 8	4.16667	university research information health medical number science study national insurance year years article april food school david ohio book problem
# 9	4.16667	ax max gv bf db pl tm di wm ei ey um gk bj kn bh sl qq cs ql
# 10	4.16667	god people jesus christian bible life true church christians christ religion word faith evidence question paul man article love point
# 11	4.16667	israel people article jews war armenian world turkish armenians jewish israeli history government state peace years killed muslim arab today
#
# <150> LL/token: -8.81418
# <160> LL/token: -8.81263
# <170> LL/token: -8.81098
# <180> LL/token: -8.81083
# <190> LL/token: -8.80917
#
# 0	4.16667	people time back day mr told fire heard remember thought children started made things fbi home article happened put days
# 1	4.16667	windows file software system dos drive bit image card version program mac files graphics pc problem window ftp data computer
# 2	4.16667	key government gun law chip public information clipper encryption number control bill phone keys security message system file guns police
# 3	4.16667	uk ac article cs apr de mail cc ca au michael se wrote email hp org advance mil hz fax
# 4	4.16667	space gov nasa power high earth time system radio light cost work low henry ground long launch design article water
# 5	4.16667	game ca year team games play article win cs good hockey apr players season baseball mark mike player league john
# 6	4.16667	article car good sale uiuc apr price buy bike dod ca cars hp cso front engine drive power thing mike
# 7	4.16667	people make good time question point group money free work case president support lot state questions things article world made
# 8	4.16667	university research information health number science medical article study national insurance years school drugs david problems food april year disease
# 9	4.16667	ax max gv bf db pl tm di wm ei ey um gk bj cs bh kn sl qq tq
# 10	4.16667	god people jesus christian bible life true church christians christ word religion faith paul evidence question love man article point
# 11	4.16667	israel people jews article war armenian world turkish armenians jewish israeli history state government years peace rights muslim today arab
#
# <200> LL/token: -8.80786
# <210> LL/token: -8.80497
# <220> LL/token: -8.80495
# [beta: 0.02903]
# <230> LL/token: -8.75364
# <240> LL/token: -8.76219
#
# 0	3.88085	people time back day mr heard article remember told fire children started thought put fbi home made days things thing
# 1	3.97833	windows file software system dos drive bit image program card version files pc problem mac graphics data window ftp computer
# 2	3.29444	key gun government law chip public information clipper encryption number bill phone keys control security system message guns file access
# 3	2.9184	uk ac cs de au mail se michael cc apr article ca mil hz hp ww ah ns ai cx
# 4	3.38274	space gov nasa power earth high system radio light time article ground henry low cost launch ca moon design apr
# 5	3.31914	game ca team year games play article cs win hockey players season good baseball apr player league mike period john
# 6	3.6989	article car apr good sale uiuc ca buy price bike org dod hp cars cc cso engine mike att front
# 7	3.94234	people make good time question article point group case president money work give things free lot world made problem post
# 8	3.36266	university research information health science medical study number national article david years school steve washington food cs drugs disease year
# 9	0.27199	ax max gv bf pl db di tm wm ei ey um gk kn qq tq bh sl bj ql
# 10	3.55893	god jesus people christian bible life true church christians christ article religion word faith paul evidence love question man read
# 11	2.82038	israel jews war people armenian turkish armenians jewish israeli world history article government peace muslim arab rights armenia state muslims
# [beta: 0.03699]
# <250> LL/token: -8.74517
# <260> LL/token: -8.73867
# <270> LL/token: -8.74264
# [beta: 0.04116]
# <280> LL/token: -8.71153
# <290> LL/token: -8.71517
#
# 0	2.81651	people time article back day mr fire children told heard david started thought home fbi remember days happened left apr
# 1	2.94849	windows file software system dos drive bit mail program image card version computer files pc problem mac graphics data window
# 2	1.75742	key government law chip gun public clipper encryption information keys security bill number control phone file system message rights court
# 3	1.24714	uk ac de db cs se hz cx ww mc au ah nz tu mv mm pl mi md du
# 4	1.93711	space gov nasa power earth high henry radio system launch light ground ca moon time article orbit mission shuttle data
# 5	1.81681	game team ca year games play win hockey players cs season baseball article player good league apr la mike period
# 6	2.60057	article car apr ca good sale uiuc cc price buy bike hp dod org cso cars mike drive engine front
# 7	3.02107	people make time good article question point case give problem lot work things made money president group thing world post
# 8	1.92061	university research information health medical science study cs number article disease national food steve dr years drugs washington drug david
# 9	0.00615	ax max gv bf pl di tm wm ei ey um gk kn qq tq sl ql bj mu bq
# 10	2.17478	god people jesus christian bible life church article christians christ religion true word faith paul evidence man love truth question
# 11	1.14627	israel war jews armenian turkish armenians israeli people jewish government muslim arab armenia peace world muslims turkey history turks state
#
# [beta: 0.04403]
# <300> LL/token: -8.7014
# <310> LL/token: -8.68594
# <320> LL/token: -8.68905
# [beta: 0.04653]
# <330> LL/token: -8.65824
# <340> LL/token: -8.66152
#
# 0	1.82333	people article time back day fire children told gun heard fbi started david home happened thought apr left remember news
# 1	1.9973	windows file software system dos drive mail bit program image card files problem version pc mac computer data graphics window
# 2	0.85145	key government law chip clipper public encryption information keys security gun number file rights phone system privacy algorithm court message
# 3	0.45964	ac uk db de hz cx ww mc mv pl ah tu mm mu mk mt lk uw mw md
# 4	1.03338	space nasa gov power earth high henry launch system moon light orbit radio mission shuttle time ground data toronto article
# 5	0.93726	game team year ca games play hockey players win season cs baseball player article league good la nhl fans apr
# 6	1.77987	article car apr ca good sale buy price cc bike hp dod org cars uiuc mail mike engine drive back
# 7	2.22598	people make good article time question point things mr work lot problem world money made thing give case president long
# 8	1.0027	university research information health medical science study article national disease food number drugs drug years cancer doctor msg cs patients
# 9	0.00234	ax max gv bf pl di tm wm ei ey kn gk um qq tq bj sl ql bq ff
# 10	1.20795	god jesus people christian bible church article christ life christians religion faith true word evidence man paul love truth law
# 11	0.45078	israel war armenian jews turkish armenians israeli jewish people muslim arab armenia government muslims turkey world peace history turks russian
#
# [beta: 0.0492]
# <350> LL/token: -8.65146
# <360> LL/token: -8.63235
# <370> LL/token: -8.63466
# [beta: 0.05203]
# <380> LL/token: -8.60469
# <390> LL/token: -8.60445
#
# 0	1.05106	people gun article time fire children day fbi back guns started david heard told police home news happened kill apr
# 1	1.28258	windows file system software dos drive mail bit program image card pc problem version mac files graphics computer window data
# 2	0.39913	key government chip clipper encryption law public information security keys file number system phone privacy algorithm message des escrow court
# 3	0.17143	db cx hz ww ah mv pl mc de mk lk mu uw mw di md mt bh tu ck
# 4	0.55295	space nasa gov power earth high henry launch article moon orbit system shuttle mission data radio light time toronto ground
# 5	0.48065	game team year games ca play hockey players win season article baseball cs player league good nhl fans apr la
# 6	1.17166	article car ca apr good sale hp bike price dod buy cc uk org cars mail back drive engine john
# 7	1.57016	people make time good article point question things work problem mr lot thing made give fact money back read case
# 8	0.50122	university health medical information research study disease science article food number drug cancer doctor msg national patients treatment studies years
# 9	0.00162	ax max gv bf pl tm di wm ei ey kn gk um qq sl tq bj ql bq ff
# 10	0.64351	god jesus people christian bible church article christ christians religion life faith man true evidence word law love paul christianity
# 11	0.19503	israel armenian jews turkish war armenians israeli jewish people arab armenia muslim turkey muslims government world turks peace history article
#
# [beta: 0.05468]
# <400> LL/token: -8.59646
# <410> LL/token: -8.57749
# <420> LL/token: -8.57834
# [beta: 0.0573]
# <430> LL/token: -8.5529
# <440> LL/token: -8.55183
#
# 0	0.52874	people gun article fire children fbi guns police time day government started waco weapons law david home death crime killed
# 1	0.81229	windows file system software dos drive mail bit image card program pc mac graphics problem files version window data computer
# 2	0.2003	key clipper chip encryption government information law keys public security file system phone number privacy algorithm des escrow message data
# 3	0.073	db cx hz ww ah pl mv lk mc uw mw mk di mu bh mt md ck mp um
# 4	0.30862	space nasa gov power earth article henry high launch moon orbit system shuttle data toronto time ca light mission ground
# 5	0.26388	game team games year ca hockey play players article season win baseball cs player league good apr nhl fans time
# 6	0.76259	article car ca apr good sale bike dod hp price buy uk org back cars cc mail cs engine drive
# 7	1.08305	people make time good article question point things work thing problem mr lot made fact back money long give president
# 8	0.2553	medical health university research information study article disease food drug science cancer msg doctor patients number treatment pitt national medicine
# 9	0.00118	ax max gv bf pl tm di wm ey ei kn gk um qq tq bj sl ql ff bq
# 10	0.35222	god jesus people christian article bible church christ christians religion faith life man true word evidence love christianity paul sin
# 11	0.10204	israel armenian jews turkish armenians war israeli people jewish arab armenia muslim turkey article muslims government turks world peace soviet
#
# [beta: 0.05999]
# <450> LL/token: -8.5461
# <460> LL/token: -8.52967
# <470> LL/token: -8.53117
# [beta: 0.06246]
# <480> LL/token: -8.51224
# <490> LL/token: -8.51086
#
# 0	0.25864	gun people article fire fbi children guns police government law day time waco weapons crime started control killed state home
# 1	0.52057	windows file software system dos drive mail bit image card program pc problem graphics mac files version data window computer
# 2	0.11088	key clipper chip encryption information government keys security file public law system number privacy algorithm phone des escrow message data
# 3	0.03789	db cx ww hz mv lk pl mk ah mc mw uw bh ck mt di mu um md ei
# 4	0.19311	space nasa gov earth power article henry high launch system moon orbit shuttle time mission light toronto ca data ground
# 5	0.16231	game team year games ca hockey play players article season win baseball cs player league good time apr nhl fans
# 6	0.49658	article car ca apr good sale bike dod hp back price uk buy cars mail org engine cc drive cs
# 7	0.73533	people make time good article point things question mr thing problem fact made money work president lot case back long
# 8	0.14257	medical health university research article study information disease drug cancer food msg patients doctor science treatment pitt cs medicine number
# 9	0.00093	ax max gv bf pl di tm wm ey ei kn gk um qq tq bj sl ql mu bq
# 10	0.2126	god jesus people christian article bible church christ christians religion faith life man word true love christianity evidence time sin
# 11	0.06442	israel armenian jews turkish armenians israeli war jewish people arab armenia article muslim turkey muslims turks government world peace soviet
# [beta: 0.06471]
# <500> LL/token: -8.50795
# <510> LL/token: -8.49439
# <520> LL/token: -8.49487
# [beta: 0.06674]
# <530> LL/token: -8.48175
# <540> LL/token: -8.48064
#
# 0	0.14423	gun people article fire fbi children guns police government waco time weapons law crime day control started killed state atf
# 1	0.35395	windows file system software dos drive mail bit card image problem pc program graphics mac files version computer window data
# 2	0.07182	key clipper chip encryption information keys file government security public law system number privacy phone algorithm message des escrow data
# 3	0.02342	db cx hz ww ah pl mk mv lk mw uw mc di mu ck bh mt ei um mp
# 4	0.13381	space nasa gov article earth power henry high launch moon orbit shuttle system ca mission time data toronto light ground
# 5	0.11301	game team year games ca article hockey play players season win baseball cs good league player apr time nhl fans
# 6	0.331	article car ca good apr sale bike dod hp back price cars buy time engine cc drive mail org uk
# 7	0.49924	people make time article good point things mr president thing money question problem made work government fact lot years case
# 8	0.09167	medical health article university research study disease information food drug msg cancer patients doctor science treatment pitt medicine number cs
# 9	0.00074	ax max gv bf pl tm di wm ey ei kn gk um qq tq bj sl ql bq ff
# 10	0.14433	god jesus people christian article bible church christ christians faith religion life true man time evidence good word christianity things
# 11	0.0468	israel armenian jews turkish armenians israeli war people jewish article arab armenia muslim turkey muslims turks government world peace genocide
#
# [beta: 0.06887]
# <550> LL/token: -8.47832
# <560> LL/token: -8.4682
# <570> LL/token: -8.46772
# [beta: 0.07048]
# <580> LL/token: -8.45809
# <590> LL/token: -8.45662
#
# 0	0.09356	gun people article fire fbi guns children police government time waco law weapons day control started crime killed atf firearms
# 1	0.26084	windows file system dos software drive mail card image problem bit pc program graphics mac files version window computer scsi
# 2	0.05457	key clipper encryption chip information keys file government security public number system phone law privacy algorithm data message escrow des
# 3	0.01699	db cx ww hz ah pl mv mk lk mw uw di mc ck bh mu mt md mp ei
# 4	0.10307	space nasa gov article earth power henry high launch moon system orbit time shuttle ca mission data ground toronto light
# 5	0.08846	game team year games ca article hockey play players season baseball win good cs time player league apr nhl fans
# 6	0.23652	article car good ca apr sale bike dod back hp cars price time engine buy drive cc uk org mail
# 7	0.34466	people make time good article mr things point president government money question made problem work state years thing case fact
# 8	0.06649	medical article health university research disease information study cancer msg food patients doctor drug treatment pitt medicine cs science number
# 9	0.00058	ax max gv bf pl tm di wm ey ei kn gk um qq tq bj sl ql ff mu
# 10	0.11107	god jesus people article christian bible church christ christians religion life faith time true good man word question love christianity
# 11	0.03697	israel armenian jews turkish armenians israeli war jewish people article arab armenia turkey muslim muslims turks world peace government soviet
#
# [beta: 0.07181]
# <600> LL/token: -8.45439
# <610> LL/token: -8.44672
# <620> LL/token: -8.44685
# [beta: 0.07326]
# <630> LL/token: -8.4388
# <640> LL/token: -8.43748
#
# 0	0.06937	gun people article fbi fire guns children police government time waco weapons law day started atf killed firearms crime control
# 1	0.20815	windows file system dos software drive mail problem image bit card pc program graphics mac files version window scsi computer
# 2	0.04508	key clipper encryption chip information file keys public security government system number phone privacy law algorithm message escrow des data
# 3	0.01355	db cx ww ah hz mv pl lk mk mw di uw mu mc ck bh ei um md mp
# 4	0.08524	space nasa gov article earth power henry high launch time moon orbit system shuttle data mission ca ground toronto light
# 5	0.075	game team year games ca article hockey play players season good win baseball cs time player league apr nhl fans
# 6	0.18233	article car good ca apr sale bike dod back time cars hp price buy engine cc drive uk mail org
# 7	0.24611	people make article time good government mr president money things point state problem made work question case years support care
# 8	0.05383	medical article health university disease research study information food cancer msg patients doctor drug treatment pitt medicine cs people good
# 9	0.0005	ax max gv bf pl tm di wm ey ei kn gk um qq bj sl tq ql bq ff
# 10	0.09285	god people jesus article christian bible church christ christians religion life faith time good true man word things question evidence
# 11	0.03187	israel armenian jews turkish armenians israeli people war jewish article arab armenia turkey muslim muslims turks world peace government genocide
#
# [beta: 0.07482]
# <650> LL/token: -8.43762
# <660> LL/token: -8.42988
# <670> LL/token: -8.42889
# [beta: 0.07587]
# <680> LL/token: -8.42311
# <690> LL/token: -8.42046
#
# 0	0.05718	gun people article fire fbi guns children police time government waco weapons started day law killed atf firearms crime home
# 1	0.17606	windows file system dos software drive problem bit mail image card program pc graphics mac files data version window article
# 2	0.0393	key clipper encryption chip information keys file government security public number system phone privacy law algorithm escrow des message data
# 3	0.01148	db cx ww pl ah hz mv mk lk mw uw mc di bh ck mu mt um mp md
# 4	0.07343	space nasa gov article earth power henry high launch system time moon orbit shuttle ca mission data apr long ground
# 5	0.06538	game team year ca games article hockey play players good season baseball win cs time league apr player nhl fans
# 6	0.15178	article car good ca apr bike sale back dod time cars hp price engine buy drive mail cc uk make
# 7	0.18496	people make article government time president mr good money state point things made fact problem support rights case states question
# 8	0.04626	medical article health disease university research study information cancer patients food msg doctor drug pitt science cs treatment good time
# 9	0.00047	ax max gv bf pl tm di wm ey ei kn gk um qq tq bj sl ql ff mu
# 10	0.0821	god people jesus article christian bible church christ christians time religion life faith good true things man point question word
# 11	0.02794	israel armenian jews turkish armenians israeli people war article jewish arab armenia turkey muslim muslims turks world peace genocide soviet
#
# [beta: 0.07683]
# <700> LL/token: -8.42012
# <710> LL/token: -8.41432
# <720> LL/token: -8.4154
# [beta: 0.07777]
# <730> LL/token: -8.41146
# <740> LL/token: -8.40939
#
# 0	0.05052	gun people article fbi fire guns children police time government waco weapons started day killed atf firearms control law home
# 1	0.15792	windows file system dos software drive problem mail card bit image program pc graphics mac files article version window scsi
# 2	0.03605	key clipper encryption chip information keys file government security system public number phone privacy law algorithm des escrow message mail
# 3	0.0104	db cx ww pl ah mv hz mk lk mw uw di mc ck mu bh mt md mp um
# 4	0.06632	space nasa gov article earth power henry high launch orbit time moon system shuttle data apr mission ground toronto light
# 5	0.05901	game team year ca games article hockey play players season good time baseball win cs apr league player nhl fans
# 6	0.13274	article car good ca apr bike sale dod back time cars price hp buy engine make mail drive front org
# 7	0.14587	people make government article president time mr good money state rights states public things made american point years support law
# 8	0.04086	article medical health disease research university study information cancer patients food msg doctor people cs treatment pitt drug good time
# 9	0.00042	ax max gv bf pl tm di wm ei ey kn gk um qq tq bj ql sl bq ff
# 10	0.07592	god people jesus article christian bible church christ christians life time religion good faith true man things question point word
# 11	0.02511	israel armenian jews turkish armenians israeli people war article jewish arab armenia turkey muslim turks muslims peace world genocide soviet
# [beta: 0.07877]
# <750> LL/token: -8.40962
# <760> LL/token: -8.40535
# <770> LL/token: -8.405
# [beta: 0.07933]
# <780> LL/token: -8.40096
# <790> LL/token: -8.39907
#
# 0	0.04745	gun people article fbi fire guns children police time waco weapons government day started atf killed david firearms compound law
# 1	0.14605	windows file system dos software drive problem mail card bit program image pc graphics mac files article version window data
# 2	0.03345	key clipper chip encryption information keys government file security public system number phone privacy algorithm escrow law article des data
# 3	0.00967	db cx ww hz lk pl mv ah mk mw uw mc di bh ck mp mu mt um md
# 4	0.06271	space nasa gov article power earth henry high time system launch orbit moon shuttle data apr ca mission toronto ground
# 5	0.05507	game team year games ca article hockey play players good season win baseball time cs apr player league nhl fans
# 6	0.1197	article car good ca apr sale bike dod back time cars hp price buy engine make uk mail cc front
# 7	0.12068	people article government make president mr state time money good american states rights public made clinton support law care things
# 8	0.0373	medical article health disease research university food cancer patients people msg information doctor study drug time treatment pitt cs medicine
# 9	0.00044	ax max gv bf pl di tm wm ei ey kn um gk qq bj tq sl ql bq mu
# 10	0.07154	god people jesus article christian bible church christ christians time life religion good faith true things question point man word
# 11	0.02367	israel armenian turkish jews armenians israeli people war article jewish arab armenia turkey muslim turks muslims world peace government genocide
#
# [beta: 0.08024]
# <800> LL/token: -8.39898
# <810> LL/token: -8.3978
# <820> LL/token: -8.39606
# [beta: 0.08075]
# <830> LL/token: -8.39291
# <840> LL/token: -8.39259
#
# 0	0.04662	gun people article fire fbi guns children time police waco weapons government day started killed atf firearms back compound law
# 1	0.13882	windows file system dos software drive mail problem card bit image program pc graphics mac files article version window data
# 2	0.03244	key clipper encryption chip keys information government security file public system number privacy phone article algorithm escrow message des law
# 3	0.00935	db cx ww pl hz ah mv mk lk mw uw di mc bh ck mu mt md ei um
# 4	0.06023	space nasa gov article power earth henry high time launch system orbit moon shuttle data mission ca apr long research
# 5	0.05226	game team year games ca article hockey play players good season baseball win time cs apr league player nhl fans
# 6	0.11166	article car good apr ca bike sale dod back time cars hp price buy engine drive make thing mail speed
# 7	0.10276	people article government president make mr state money time american states rights good public support made clinton year law years
# 8	0.03479	medical article health disease research cancer patients food msg information people doctor time good university pitt treatment drug cs medicine
# 9	0.00039	ax max gv bf pl di tm wm ey ei kn um gk qq tq bj sl ql bq mu
# 10	0.06845	god people jesus article christian bible church christ time christians life good religion faith point true things question man make
# 11	0.02239	israel armenian jews turkish armenians people israeli war article jewish arab armenia turkey muslim turks muslims world peace genocide soviet
#
# [beta: 0.08129]
# <850> LL/token: -8.39079
# <860> LL/token: -8.38935
# <870> LL/token: -8.38955
# [beta: 0.08174]
# <880> LL/token: -8.38739
# <890> LL/token: -8.3864
#
# 0	0.04617	gun people article fbi fire guns children time police government waco weapons started day killed atf firearms good law back
# 1	0.13307	windows file system dos software drive mail problem bit card image pc program graphics files article mac version window scsi
# 2	0.0304	key clipper chip encryption keys information government security system file public number phone privacy law article algorithm message escrow des
# 3	0.00865	db cx hz ww pl ah mv lk mk mw uw di um mc ck bh mu mt mp ei
# 4	0.05778	space nasa gov article power earth henry time high launch system orbit moon shuttle data ca mission apr ground toronto
# 5	0.04966	game team year ca games article hockey play players season good time baseball win cs apr league player nhl fans
# 6	0.10513	article car good apr ca bike sale dod back time cars price hp engine buy make uk drive speed mail
# 7	0.09144	people article government president make mr state money time states american rights good public clinton law support year made care
# 8	0.03228	medical article health disease research cancer people patients msg food doctor good information cs treatment drug time pitt university medicine
# 9	0.00039	ax max gv bf pl tm di wm ey ei kn gk qq um tq bj sl ql bq ff
# 10	0.06567	god people jesus article christian bible church time christ christians life religion good faith true question things point man word
# 11	0.02196	israel armenian jews turkish armenians people israeli war article jewish arab armenia turkey muslim muslims turks world peace genocide government
#
# [beta: 0.08178]
# <900> LL/token: -8.38606
# <910> LL/token: -8.38546
# <920> LL/token: -8.38494
# [beta: 0.08237]
# <930> LL/token: -8.38346
# <940> LL/token: -8.38183
#
# 0	0.04531	gun people article fbi fire guns children time police waco government weapons day started killed back law atf firearms good
# 1	0.12872	windows file system dos software drive mail problem card bit image pc program graphics article files mac version window data
# 2	0.02968	key clipper encryption chip keys information government security system public number file privacy phone algorithm escrow law des article data
# 3	0.00854	db cx hz ww ah pl mv lk mw di uw mk bh mu ck mc mt mp md ei
# 4	0.05584	space nasa gov article power earth time henry high system launch orbit moon shuttle ca data apr mission work toronto
# 5	0.04827	game team year games ca article hockey play players good season time baseball win cs apr league player nhl fans
# 6	0.10226	article car good ca apr bike sale dod back time cars price hp buy engine make drive uk mail front
# 7	0.08447	people article government president mr make state time money american states public rights good clinton year support law made national
# 8	0.03026	article medical health disease people research cancer food patients msg doctor information treatment drug good pitt time cs medicine years
# 9	0.00039	ax max gv bf pl tm di wm ey ei kn um qq gk tq bj ql sl ff bq
# 10	0.06431	god people jesus article christian bible time church christ christians good life religion faith point question true things word man
# 11	0.02075	israel armenian jews turkish armenians people israeli war article jewish arab armenia muslim turkey turks muslims world peace government genocide
#
# [beta: 0.08229]
# <950> LL/token: -8.38308
# <960> LL/token: -8.38207
# <970> LL/token: -8.38118
# [beta: 0.08269]
# <980> LL/token: -8.38047
# <990> LL/token: -8.37932
#
# 0	0.04486	gun people article fbi fire guns children time police government waco weapons day started law killed atf firearms home control
# 1	0.12551	windows file system dos software drive mail problem bit card image pc program graphics article mac files version window computer
# 2	0.02886	key clipper chip encryption keys information government security system public file number privacy phone algorithm article escrow law des message
# 3	0.00832	db cx ww hz ah pl mv mk lk mw uw di bh mu ck mc mp md mt um
# 4	0.05486	space nasa gov article power earth henry time high launch system data orbit moon shuttle ca apr mission ground light
# 5	0.04782	game team year games ca article hockey play players good season time win baseball cs apr player league nhl fans
# 6	0.09841	article car good ca apr bike sale dod back time cars price hp engine buy make drive uk thing mail
# 7	0.0794	people government article president mr make state money time american states rights public good law clinton made year support national
# 8	0.02997	medical article health disease people research cancer food patients msg doctor time good treatment information drug pitt medicine years aids
# 9	0.00039	ax max gv bf pl di tm wm ei ey kn um qq gk tq bj sl ql ff bq
# 10	0.06368	god people jesus article christian bible time church christ christians life good religion faith things point question true word make
# 11	0.02111	israel armenian jews turkish armenians people israeli war article jewish arab armenia muslim turkey turks muslims world peace government genocide
#
# [beta: 0.08269]
# <1000> LL/token: -8.38042
#
# Total time: 2 minutes 41 seconds
# Mallet LDA: 12 topics, 4 topic bits, 1111 topic mask
# Data loaded.
# max tokens: 12555
# total tokens: 2137668
# <10> LL/token: -9.79106
# <20> LL/token: -9.12508
# <30> LL/token: -8.97388
# <40> LL/token: -8.91131
#
# 0	4.16667	world jews armenian university turkish armenians history war jewish years man people ed muslim men armenia work muslims org today
# 1	4.16667	key chip phone clipper encryption david number system public information keys access government security steve company technology order sell org
# 2	4.16667	game ca team year games play win hockey players season baseball john player league andrew period st cmu la san
# 3	4.16667	ax max gv bf pl tm db di ei um wm cx ah ww mu mv mt mr mq mc
# 4	4.16667	article problem apr time good uk thing problems ac work read back mark lot make stuff find heard mine opinions
# 5	4.16667	people government gun mr state children fbi fire time law rights police back president clinton guns started control day told
# 6	4.16667	article car apr cs good uiuc ca bike dod cso back cars mike hit front engine news time road acs
# 7	4.16667	space nasa research gov years national health information high earth medical center time water april drug university science henry general
# 8	4.16667	file windows program image files dos version software graphics window ftp mail list data information system server display code send
# 9	4.16667	people israel question make point evidence article fact true reason human case claim agree wrong argument israeli based moral statement
# 10	4.16667	god jesus christian life bible man people church paul christians christ love word faith time good hell book things true
# 11	4.16667	drive card system scsi mb pc mac hard sale disk ibm apple ca video memory mail computer de bit work
#
# <50> LL/token: -8.87738
# <60> LL/token: -8.85613
# <70> LL/token: -8.83934
# <80> LL/token: -8.82839
# <90> LL/token: -8.82207
#
# 0	4.16667	world jews war armenian turkish university armenians people jewish history years land muslim armenia work muslims today turkey man soviet
# 1	4.16667	key chip phone clipper encryption information public number system david government access keys company security mail private org order make
# 2	4.16667	game ca year team games play win hockey players season baseball cs st player league period san andrew mike la
# 3	4.16667	ax max gv bf pl tm db di ei um wm ah cx ww mu mv mr mt mq mi
# 4	4.16667	article apr problem good uk time cs ac thing make cc mark find lot heard read post wrote stuff opinions
# 5	4.16667	people gun government mr president state time children fbi fire police rights clinton law made guns started control day house
# 6	4.16667	article car uiuc ca apr good back bike dod cso hp cars front left mike org engine hit cs road
# 7	4.16667	space nasa research gov health high years earth medical center national information water university time henry science program system april
# 8	4.16667	file program image files version windows graphics window software ftp mail list data send server information display mit sun code
# 9	4.16667	people question israel point evidence article fact true make reason case claim agree israeli human argument person wrong based moral
# 10	4.16667	god jesus christian people life bible man paul church christians christ love faith word hell time things good book day
# 11	4.16667	drive dos windows card system scsi pc mac mb disk hard sale apple ibm bit computer video work memory price
#
# <100> LL/token: -8.815
# <110> LL/token: -8.80819
# <120> LL/token: -8.80449
# <130> LL/token: -8.80113
# <140> LL/token: -8.7971
#
# 0	4.16667	world war jews armenian turkish people armenians jewish university years history land muslim armenia muslims peace today work turkey man
# 1	4.16667	key chip phone information clipper public system encryption number government david access mail org security keys company technology order private
# 2	4.16667	ca game year team games play win hockey players season baseball player league st john mike cs san good period
# 3	4.16667	ax max gv bf pl tm db di ei um wm cx ah mu mv ww mt mr mq hz
# 4	4.16667	article apr cs good uk ac time problem cc thing mark find heard make post read opinions wrote lot stuff
# 5	4.16667	people gun government mr president state time fbi children fire police day clinton rights guns control made law house started
# 6	4.16667	car article uiuc ca good back bike dod hp cso cars front left mike engine acs apr road ohio time
# 7	4.16667	space nasa gov research health years earth medical high center water national information henry university food program long launch science
# 8	4.16667	file program image files version graphics software window ftp mail list information mit data server display sun windows set code
# 9	4.16667	people question israel point evidence true make reason fact article case agree claim human israeli argument wrong based opinion means
# 10	4.16667	god jesus christian people life bible paul man church christians christ love faith word time book hell john day things
# 11	4.16667	drive windows dos card system scsi pc mac mb hard disk sale ibm apple problem price memory video bit work
#
# <150> LL/token: -8.79477
# <160> LL/token: -8.79546
# <170> LL/token: -8.79144
# <180> LL/token: -8.7901
# <190> LL/token: -8.78918
#
# 0	4.16667	israel war jews world armenian people turkish armenians jewish university years history peace land state muslim arab armenia muslims work
# 1	4.16667	key information chip system phone public clipper government encryption number access org security mail keys private order message company technology
# 2	4.16667	game ca year team games play win hockey players season mike baseball player john league good period la st time
# 3	4.16667	ax max gv bf pl tm db di ei um wm cx ah ww mu mv mr mt mc mq
# 4	4.16667	article apr cs uk good ac cc problem mark time thing read opinions heard net find wrote post michael lot
# 5	4.16667	people gun mr government president time state fbi fire children police rights day clinton started made guns law back control
# 6	4.16667	car uiuc good ca article back bike dod cso cars left front hp engine side road acs turn org mike
# 7	4.16667	space nasa gov research health earth years medical high time center university henry long water science launch food april system
# 8	4.16667	file program image files version graphics window ftp software mail list data mit server display sun information code send color
# 9	4.16667	people question point make evidence true reason fact case agree claim article wrong argument good human based person opinion things
# 10	4.16667	god jesus christian people bible man life church paul christians christ love faith book time word john things world day
# 11	4.16667	drive windows dos card system pc scsi mac hard mb disk sale problem ibm ms bit apple computer work price
#
# <200> LL/token: -8.78877
# <210> LL/token: -8.78815
# <220> LL/token: -8.78578
# [beta: 0.02918]
# <230> LL/token: -8.7443
# <240> LL/token: -8.75162
#
# 0	2.83104	israel war jews armenian turkish armenians world israeli jewish people history peace muslim arab years armenia university muslims turkey state
# 1	3.32039	key information chip government clipper phone public encryption system number keys security access company technology order private service message org
# 2	3.141	game ca year team games play win hockey players season baseball player league mike good st la john period series
# 3	0.91308	ax max gv bf pl di db tm ei um cx wm mu mv ah ww ey mk mw mq
# 4	4.20194	article apr cs good uk ac cc mark university post net read david time problem michael heard opinions find wrote
# 5	3.46501	people gun mr president government time state fbi children fire police day clinton guns control law started house made rights
# 6	3.65838	car ca uiuc back good bike dod hp cars left cso front org article time engine mike buy power ohio
# 7	3.3415	space nasa research gov health years earth medical high center henry information launch time year food science disease moon water
# 8	3.50303	file program image files graphics window ftp version software mail list data server display information mit code sun send windows
# 9	3.80524	people point question make true evidence fact reason case things claim agree article person wrong argument good based opinion simply
# 10	3.15268	god jesus christian people bible man church paul life christians christ faith love book word time world day john hell
# 11	3.50434	drive windows dos card system pc scsi mac mb hard disk sale apple bit ibm problem price work video memory
#
# [beta: 0.03789]
# <250> LL/token: -8.73415
# <260> LL/token: -8.72895
# <270> LL/token: -8.7345
# [beta: 0.04253]
# <280> LL/token: -8.70125
# <290> LL/token: -8.70675
#
# 0	1.17622	israel war armenian jews turkish armenians israeli jewish people world muslim arab armenia peace muslims turkey government history turks russian
# 1	1.83526	key information chip government clipper public encryption phone system keys security number private access org technology law message data order
# 2	1.63424	game team year games play hockey win ca players season baseball player league st la good period time hit series
# 3	0.08378	ax max gv bf pl di db tm ei cx um wm mu ey ww mv ah mw lk mk
# 4	3.50972	article apr cs ca good uk ac cc university david mark post net mail michael read wrote news find heard
# 5	2.12501	people gun mr time government president fire fbi children state police day clinton guns law made house control started told
# 6	2.42391	car uiuc back bike good dod cars front org power time article engine buy light left hp ohio road black
# 7	1.90211	space nasa research gov earth medical health high years henry center launch disease april information moon orbit mission food science
# 8	2.1941	file program image files window ftp graphics version software mail list information data server display windows sun mit code send
# 9	2.74243	people point make question true fact evidence case reason good article things agree wrong person claim time problem argument thing
# 10	1.59342	god jesus christian bible church christ christians people man faith life paul love book christianity sin rutgers lord time hell
# 11	2.21243	drive windows dos card system scsi pc mac mb disk problem sale apple hard ibm work software computer video bit
#
# [beta: 0.04598]
# <300> LL/token: -8.6922
# <310> LL/token: -8.67655
# <320> LL/token: -8.68094
# [beta: 0.04879]
# <330> LL/token: -8.64551
# <340> LL/token: -8.64945
#
# 0	0.46791	israel armenian jews turkish war armenians israeli jewish people arab world armenia muslim muslims turkey peace turks history government genocide
# 1	0.89935	key government chip clipper encryption public information system keys security phone law number private access technology message privacy data algorithm
# 2	0.79489	game team year games play hockey players win season baseball player league ca good time st nhl fans hit boston
# 3	0.01526	ax max gv bf pl di db tm ei cx um wm mu ey ww ah mv mw lk wt
# 4	2.66412	article apr cs ca uk university good ac david cc mail mark michael net uiuc post org news john wrote
# 5	1.21599	people gun mr government president time state fire children fbi police guns day clinton law made house started american told
# 6	1.44592	car back good bike dod power cars time front engine light left buy article road speed work ground state problem
# 7	0.9938	space nasa research gov earth medical health years high henry information time launch disease center moon orbit shuttle mission year
# 8	1.26875	file program image files ftp window graphics version software information windows server display data mail list code color send set
# 9	1.84458	people make point article question true fact evidence reason good things case time wrong person thing agree read claim problem
# 10	0.74228	god jesus christian bible church christians christ faith people man life love christianity paul sin book lord word time hell
# 11	1.29598	drive windows dos card system scsi pc mb mac disk problem apple software sale hard work memory video bit computer
#
# [beta: 0.05182]
# <350> LL/token: -8.63871
# <360> LL/token: -8.62114
# <370> LL/token: -8.62329
# [beta: 0.05473]
# <380> LL/token: -8.59418
# <390> LL/token: -8.59528
#
# 0	0.19489	israel armenian jews turkish armenians war israeli jewish people arab armenia muslim muslims turkey government turks world peace genocide soviet
# 1	0.40827	key government clipper chip encryption public keys security system information law phone private privacy number access des escrow algorithm data
# 2	0.3882	game team year games play hockey players season win baseball ca league good player time nhl fans teams st hit
# 3	0.00582	ax max gv bf pl di db tm ei cx um wm mu ey ww ah mv mw lk mk
# 4	1.87434	article apr ca cs university mail ac uk david cc good uiuc michael mark org news john post net steve
# 5	0.6843	people gun government mr president time children fire fbi guns clinton police state law day house made back control rights
# 6	0.82758	car good bike back dod time power cars article engine front buy left ground light work speed road thing make
# 7	0.5089	space nasa gov earth research medical health years henry launch high system disease moon orbit time shuttle information mission april
# 8	0.6961	file program image files ftp window graphics software version windows data display server information code mail list color bit images
# 9	1.19799	people article make point question good true things fact reason time evidence thing wrong case read agree person claim problem
# 10	0.3483	god jesus christian bible church christ christians faith people man christianity sin lord love life paul word time hell father
# 11	0.72579	drive windows dos card system scsi mb pc mac disk problem apple software hard memory video sale work bit computer
#
# [beta: 0.05733]
# <400> LL/token: -8.58817
# <410> LL/token: -8.5718
# <420> LL/token: -8.57297
# [beta: 0.05992]
# <430> LL/token: -8.55181
# <440> LL/token: -8.55253
#
# 0	0.09776	israel armenian jews turkish armenians israeli war jewish people arab armenia muslim turkey muslims turks government world peace genocide soviet
# 1	0.18753	key clipper encryption government chip keys public security system information law privacy phone des escrow algorithm private data nsa secure
# ...
# 13	0.03981	key clipper encryption chip government keys security public system privacy law information escrow des algorithm phone nsa pgp data secure
#
# [beta: 0.06441]
# <650> LL/token: -8.42955
# <660> LL/token: -8.42807
# <670> LL/token: -8.42425
# [beta: 0.06525]
# <680> LL/token: -8.42332
# <690> LL/token: -8.4227
#
# 0	0.10573	file image program files ftp window graphics windows mail software version server information code data list display images color jpeg
# 1	0.06689	god article people religion evidence true atheists morality science question moral point atheism christian cs argument reason fact keith truth
# 2	0.01162	db cx ww ah lk pl hz mv mk di mw uw bh mc ck mu mp mt um md
# 3	0.0983	car article bike ca dod apr cars engine good hp org uk state bmw front ride oil acs ohio cc
# 4	0.05683	gun article people government fbi guns fire law state police rights children bill waco clinton weapons control crime news federal
# 5	0.03128	israel armenian jews turkish armenians israeli war people jewish article arab government armenia turkey turks muslim muslims world peace state
# 6	0.35568	people time good make article back things thing long point lot put problem made find give years bad work read
# 7	0.00047	ax max gv bf pl tm di wm ei ey kn gk um qq tq bj sl ql bq ff
# 8	0.05951	president health medical mr information disease research national university study food article number cancer msg patients ms treatment myers insurance
# 9	0.05228	god jesus church christ bible christian people christians sin paul lord life rutgers man men faith article love law cramer
# 10	0.13686	drive windows dos card system scsi pc mb mac disk software article computer problem apple sale video ca mail work
# 11	0.06452	game team year ca games hockey players play season article baseball win st cs league player apr nhl fans teams
# 12	0.06951	space nasa gov earth article power henry launch high orbit moon shuttle system mission ground apr toronto light solar satellite
# 13	0.03616	key clipper encryption chip government keys security public system privacy information law escrow des algorithm phone nsa pgp article data
# [beta: 0.0657]
# <700> LL/token: -8.42155
# <710> LL/token: -8.41948
# <720> LL/token: -8.42054
# [beta: 0.06647]
# <730> LL/token: -8.4185
# <740> LL/token: -8.41816
#
# 0	0.09618	file image program files window ftp graphics mail software windows version server data information list code display sun jpeg color
# 1	0.06066	god article people religion evidence true atheists moral morality question science atheism point argument cs claim keith reason exist christian
# 2	0.01048	db cx ww ah mk pl hz mv lk di mw uw bh mu ck mt mc um mp md
# 3	0.08872	car article bike apr ca dod cars engine good hp org bmw uk state front road cc ride speed oil
# 4	0.05377	gun article government people fbi guns law fire state police rights children waco bill clinton weapons control crime apr news
# 5	0.02941	israel armenian jews turkish armenians israeli people war jewish article arab government armenia turkey turks muslim muslims world state peace
# 6	0.30528	people time good make back article things thing point lot long problem made find years put work give day bad
# 7	0.00053	ax max gv bf pl tm di wm ei ey kn um gk qq tq bj sl ql ff bq
# 8	0.05332	president health medical mr information research disease article national study number cancer university food msg patients drug year ms april
# 9	0.04847	god jesus church christ bible christian people christians sin paul man lord article men life rutgers faith love law cramer
# 10	0.12679	windows drive dos card system scsi mb pc mac disk article problem apple computer software video sale work hard ca
# 11	0.06049	game team year ca games hockey article players play season win baseball st cs league player apr nhl fans teams
# 12	0.06559	space nasa gov article earth henry power launch orbit moon high shuttle system mission ca ground apr toronto radio solar
# 13	0.03321	key clipper encryption chip government keys security public system information privacy law escrow des phone algorithm article nsa pgp secret
#
# [beta: 0.06669]
# <750> LL/token: -8.41759
# <760> LL/token: -8.41606
# <770> LL/token: -8.41716
# [beta: 0.06723]
# <780> LL/token: -8.4161
# <790> LL/token: -8.41491
#
# 0	0.09044	file image program files window ftp graphics mail windows software version server data information code list display images jpeg sun
# 1	0.05759	article god people religion evidence true atheists question morality moral science atheism argument point reason fact cs keith truth christian
# 2	0.00948	db cx pl ww ah hz mk mv lk di mw uw bh ck mt mc md um mp mu
# 3	0.08418	car article bike ca apr dod cars engine good org hp bmw uk state front speed ride road oil cc
# 4	0.05173	gun article people government fbi law guns fire state police rights bill waco control weapons clinton children crime apr news
# 5	0.02835	israel armenian jews turkish armenians israeli war people article jewish arab government armenia turkey turks world muslim muslims peace state
# 6	0.26785	people time good make back things thing article years problem long lot point put made give day work bad find
# 7	0.00056	ax max gv bf pl tm di wm ey ei kn um gk qq tq bj sl ql bq ff
# 8	0.0503	president health medical mr information article disease research university number food national study cancer msg patients ms insurance drug myers
# 9	0.04652	god jesus church bible christ christian people christians sin paul lord article man rutgers life men faith love law cramer
# 10	0.1206	windows drive dos card system scsi mb pc mac disk article problem computer software apple ca hard video sale work
# 11	0.05809	game team year ca games hockey article players play season baseball win cs st league player apr nhl good fans
# 12	0.06212	space nasa gov article earth power henry launch high orbit moon shuttle system mission apr ca toronto ground radio solar
# 13	0.032	key clipper encryption chip government keys security public system information privacy law escrow des article algorithm phone nsa data pgp
#
# [beta: 0.06774]
# <800> LL/token: -8.41563
# <810> LL/token: -8.41489
# <820> LL/token: -8.41511
# [beta: 0.06777]
# <830> LL/token: -8.41457
# <840> LL/token: -8.41215
#
# 0	0.0873	file image program files window ftp graphics windows mail software version server data information list code display sun jpeg images
# 1	0.05668	god article people religion evidence true atheists question morality point science moral atheism cs reason fact argument claim keith christian
# 2	0.00908	db cx ww pl mk hz ah lk mv di mw uw bh mc ck mt mp md um mu
# 3	0.08086	car article bike ca apr dod cars engine good hp uk org bmw state front road ride speed drive cc
# 4	0.05003	gun article people government fbi guns law fire state police rights bill waco clinton apr children weapons control crime news
# 5	0.02705	israel armenian jews turkish armenians israeli people war article jewish arab government armenia turkey turks muslim muslims state world peace
# 6	0.24347	people time good make back things thing long years article problem put lot point made day give work find bad
# 7	0.0005	ax max gv bf pl tm di wm ei ey kn gk um qq tq bj sl ql ff mu
# 8	0.0479	president health medical information mr article disease research study national university cancer food msg patients number year insurance ms drug
# 9	0.04483	god jesus church bible people christ christian christians sin paul lord article man rutgers life faith men love law cramer
# 10	0.11657	drive windows dos card system scsi mb pc mac disk article problem computer software apple ca mail sale video work
# 11	0.05635	game team year games ca article hockey players play season baseball win st cs league player apr nhl fans good
# 12	0.05947	space nasa gov article earth power henry launch high orbit moon shuttle system mission apr ground ca toronto solar data
# 13	0.03082	key clipper encryption chip government keys security public system information privacy law article escrow des phone algorithm nsa pgp data
#
# [beta: 0.0684]
# <850> LL/token: -8.41169
# <860> LL/token: -8.41251
# <870> LL/token: -8.41201
# [beta: 0.06848]
# <880> LL/token: -8.41066
# <890> LL/token: -8.41166
#
# 0	0.0838	file image program files ftp window graphics mail windows software version server data information code list display jpeg sun images
# 1	0.05489	article god people religion evidence true atheists question morality point science moral atheism reason argument cs fact keith objective exist
# 2	0.00878	db cx ah ww lk pl hz mv mk di mw uw ck bh mu mc mt um mp ei
# 3	0.07811	car article bike ca apr dod cars engine good org hp state bmw uk front ride road cc drive speed
# 4	0.04883	gun article government people fbi law guns fire state rights police bill waco children weapons clinton control crime apr news
# 5	0.02657	israel armenian jews turkish armenians israeli people war jewish article arab government armenia turkey turks muslim world muslims state peace
# 6	0.22559	people time good back make things thing years lot made long point problem put find give article day bad thought
# 7	0.00052	ax max gv bf pl tm di wm ey ei kn gk um qq tq bj sl ql bq ff
# 8	0.04622	president health medical mr article information disease research university number study food cancer national msg patients insurance treatment drug ms
# 9	0.04355	god jesus people church bible christ christian christians sin article paul lord man faith life rutgers men love law cramer
# 10	0.11479	windows drive dos card system scsi mb pc mac disk article problem software computer apple ca hard sale work video
# 11	0.0546	game team year ca games article hockey players play season baseball win cs st league apr player nhl fans teams
# 12	0.05834	space nasa gov article earth power henry launch orbit high system moon shuttle apr mission ground time ca radio toronto
# 13	0.03031	key clipper encryption chip government keys security public system privacy information law escrow des article phone algorithm nsa data pgp
#
# [beta: 0.0686]
# <900> LL/token: -8.41099
# <910> LL/token: -8.40975
# <920> LL/token: -8.41069
# [beta: 0.06875]
# <930> LL/token: -8.41042
# <940> LL/token: -8.40928
#
# 0	0.08165	file image program files window ftp graphics windows mail software version server data information code list display sun images jpeg
# 1	0.05549	article god people religion evidence question true atheists point morality science moral argument atheism reason cs keith fact truth objective
# 2	0.00832	db cx ww ah pl hz mk lk mv mw uw di bh mu mc ck mt ei mp md
# 3	0.07665	car article ca bike apr dod cars engine good org hp uk bmw front ride state road speed oil drive
# 4	0.0484	gun article government people fbi law guns fire state police bill rights waco children clinton apr weapons control crime news
# 5	0.02583	israel armenian jews turkish armenians israeli war people article jewish arab government armenia turkey muslim turks world muslims peace state
# 6	0.21324	people time good make back things thing years long lot made point problem put give article find day bad work
# 7	0.00043	ax max gv bf pl tm di wm ey ei kn um gk qq tq bj sl ql ff bq
# 8	0.04448	health president medical mr information article research disease number study university food cancer patients msg national ms myers insurance drug
# 9	0.04227	god jesus church bible christ christian people christians sin article paul man lord rutgers life men faith love law cramer
# 10	0.1127	windows drive dos card system scsi mb pc mac article disk problem software computer apple ca sale work hard video
# 11	0.05376	game team year ca games article hockey players play season baseball win st cs league apr player nhl fans good
# 12	0.0575	space nasa gov article earth power henry launch high orbit moon shuttle system apr mission ca toronto ground solar time
# 13	0.0297	key clipper encryption chip government keys security public system privacy law information escrow des algorithm phone article nsa pgp data
# [beta: 0.06893]
# <950> LL/token: -8.40817
# <960> LL/token: -8.40923
# <970> LL/token: -8.41009
# type: 18667 new topic: 12
# 11:2 9:2 4:2 3:2 0:2 6:1
# java.lang.ArrayIndexOutOfBoundsException: Index 6 out of bounds for length 6
# 	at cc.mallet.topics.WorkerRunnable.sampleTopicsForOneDoc(WorkerRunnable.java:552)
# 	at cc.mallet.topics.WorkerRunnable.run(WorkerRunnable.java:275)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.run(FutureTask.java:264)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:830)
# type: 20173 new topic: 5
# 6:3 8:2 4:2 11:1 3:1
# java.lang.ArrayIndexOutOfBoundsException: Index 5 out of bounds for length 5
# 	at cc.mallet.topics.WorkerRunnable.sampleTopicsForOneDoc(WorkerRunnable.java:552)
# 	at cc.mallet.topics.WorkerRunnable.run(WorkerRunnable.java:275)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:515)
# 	at java.base/java.util.concurrent.FutureTask.run(FutureTask.java:264)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:830)
# type: 18650 new topic: 4
# 8:4 10:2 13:1 11:1 6:1
# java.lang.ArrayIndexOutOfBoundsException
# overflow in merging on type 18667
# Exception in thread "main" java.lang.ArrayIndexOutOfBoundsException: Index 6 out of bounds for length 6
# 	at cc.mallet.topics.ParallelTopicModel.sumTypeTopicCounts(ParallelTopicModel.java:477)
# 	at cc.mallet.topics.ParallelTopicModel.estimate(ParallelTopicModel.java:849)
# 	at cc.mallet.topics.tui.TopicTrainer.main(TopicTrainer.java:245)
#  13%|█████▎                                  | 2/15 [33:51<3:40:02, 1015.54s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/86/nw630jn16nsg2zqycwy774640000gn/T/ipykernel_15858/1333348567.py in <module>
#      12     for r in range(runs):
#      13         #model=LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics)
# ---> 14         model = LdaMallet(mallet_path, corpus=doc_term_matrix, num_topics=num_topics, id2word=vocab_dict,optimize_interval = 25,workers=2)
#      15
#      16         #storing top_terms
#
# /usr/local/lib/python3.7/site-packages/gensim/models/wrappers/ldamallet.py in __init__(self, mallet_path, corpus, num_topics, alpha, id2word, workers, prefix, optimize_interval, iterations, topic_threshold, random_seed)
#     129         self.random_seed = random_seed
#     130         if corpus is not None:
# --> 131             self.train(corpus)
#     132
#     133     def finferencer(self):
#
# /usr/local/lib/python3.7/site-packages/gensim/models/wrappers/ldamallet.py in train(self, corpus)
#     282         # NOTE "--keep-sequence-bigrams" / "--use-ngrams true" poorer results + runs out of memory
#     283         logger.info("training MALLET LDA with %s", cmd)
# --> 284         check_output(args=cmd, shell=True)
#     285         self.word_topics = self.load_word_topics()
#     286         # NOTE - we are still keeping the wordtopics variable to not break backward compatibility.
#
# /usr/local/lib/python3.7/site-packages/gensim/utils.py in check_output(stdout, *popenargs, **kwargs)
#    1922         logger.debug("COMMAND: %s %s", popenargs, kwargs)
#    1923         process = subprocess.Popen(stdout=stdout, *popenargs, **kwargs)
# -> 1924         output, unused_err = process.communicate()
#    1925         retcode = process.poll()
#    1926         if retcode:
#
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/subprocess.py in communicate(self, input, timeout)
#     924                 self._stdin_write(input)
#     925             elif self.stdout:
# --> 926                 stdout = self.stdout.read()
#     927                 self.stdout.close()
#     928             elif self.stderr:
#
# KeyboardInterrupt:

# %%
#converting set to list
term_pairs_ls = [[i[0],i[1]] for i in list(term_pairs)]

# %%
#computing Coherence for all term pairs
cscore = CoherenceModel(topics=term_pairs,dictionary=wiki_vocab_dict,texts=pre_processed_wiki,coherence='c_npmi',processes=3,topn=2).get_coherence_per_topic()

# %%
#Loading the DB
npmi_db = db('./db/wiki_5p_old')
# Out:
# Load NPMI coherence DB.
# Number of keys : 136702

# %%
#writing into the DB
for i in tqdm(range(len(term_pairs_ls))):
    #if the key does not exist, insert it
    try:
        npmi_db.db[(term_pairs_ls[i][0],term_pairs_ls[i][1])]
    except:
        npmi_db.db[(term_pairs_ls[i][0],term_pairs_ls[i][1])] = cscore[i]
    #do the other combination
    try:
        npmi_db.db[(term_pairs_ls[i][1],term_pairs_ls[i][0])]
    except:
        npmi_db.db[(term_pairs_ls[i][1],term_pairs_ls[i][0])] = cscore[i]
# Out:
# 100%|█████████████████████████████████████| 4174/4174 [00:02<00:00, 1522.81it/s]

# %%
# for k in tqdm(npmi_db.db.iterkeys()):
#     try:
#         npmi_db.db[(k[1],k[0])]
#     except:
#         npmi_db.db[(k[1],k[0])] =  npmi_db.db[k]
# Out:
# 125087it [00:23, 5268.58it/s]
