# %%
from datetime import datetime
from itertools import dropwhile, takewhile

import instaloader

L = instaloader.Instaloader()

posts = instaloader.Profile.from_username(L.context, "mathworks.ir").get_posts()

# SINCE = datetime(2015, 5, 1)
# UNTIL = datetime(2015, 3, 1)

# for post in takewhile(lambda p: p.date > UNTIL, dropwhile(lambda p: p.date > SINCE, posts)):
#     print(post.date)
#     L.download_post(post, "instagram")

# %%
# for l in posts:
#     L.download_pic(l,"instagram")
#     print('111')
#     break

L.download_pic('test',l.url,l.date)
# Out:
# test.jpg
# True

# %%
l.caption, l.url
# Out:
# ('دانلود كتاب Essential MATLAB for Engineers and Scientists\n\nلینک متلب :\nhttp://mathworks.ir/eng-ebooks\n/essentialmatlab\n\nکانال تلگرام @mathworks_ir',
#  'https://scontent-lga3-1.cdninstagram.com/v/t51.2885-15/28430072_198605117575022_8726136405912190976_n.jpg?stp=dst-jpg_e35&_nc_ht=scontent-lga3-1.cdninstagram.com&_nc_cat=102&_nc_ohc=TDrMGicJXqEAX-QqfB5&edm=APU89FABAAAA&ccb=7-5&oh=00_AfAFH6TqRzALaQgNUh7IJzLPI-Bl6_gPXdhfALwGtIGBAA&oe=65BC3ABA&_nc_sid=bc0c2c')

# %%
install.packages("quanteda.textmodels")
install.packages("quanteda.textstats")
install.packages("quanteda.textplots")
# Out:
# Installing package into ‘/home/amh418/R/x86_64-conda-linux-gnu-library/4.0’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘LiblineaR’, ‘quanteda’, ‘RSpectra’
#
#
# Warning message in install.packages("quanteda.textmodels"):
# “installation of package ‘quanteda’ had non-zero exit status”
# Warning message in install.packages("quanteda.textmodels"):
# “installation of package ‘quanteda.textmodels’ had non-zero exit status”
# Installing package into ‘/home/amh418/R/x86_64-conda-linux-gnu-library/4.0’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘quanteda’, ‘nsyllable’, ‘proxyC’
#
#
# Warning message in install.packages("quanteda.textstats"):
# “installation of package ‘quanteda’ had non-zero exit status”
# Warning message in install.packages("quanteda.textstats"):
# “installation of package ‘proxyC’ had non-zero exit status”
# Warning message in install.packages("quanteda.textstats"):
# ...

# %%
# install.packages('quanteda')
library(quanteda)
# Out:
# Error in library(quanteda): there is no package called ‘quanteda’
# Traceback:
#
# 1. library(quanteda)

# %%
ip = as.data.frame(installed.packages()[,c(1,3:4)])
ip = ip[is.na(ip$Priority),1:2,drop=FALSE]
ip[200:250,]
# Out:
#             Package     Version
# rstatix     rstatix     0.7.0
# rstudioapi  rstudioapi  0.13
# rvest       rvest       1.0.2
# sass        sass        0.4.0
# scales      scales      1.1.1
# selectr     selectr     0.4-2
# servr       servr       0.24
# shape       shape       1.4.6
# shiny       shiny       1.7.1
# snow        snow        0.4-4
# sourcetools sourcetools 0.1.7
# sp          sp          1.4-6
# sparklyr    sparklyr    1.7.3
# SparseM     SparseM     1.81
# SQUAREM     SQUAREM     2021.1
# statmod     statmod     1.4.36
# stringi     stringi     1.7.6
# stringr     stringr     1.4.0
# svglite     svglite     2.0.0
# sys         sys         3.4
# systemfonts systemfonts 1.0.3
# testthat    testthat    3.1.1
# tibble      tibble      3.1.6
# tidyr       tidyr       1.1.4
# tidyselect  tidyselect  1.1.1
# tidyverse   tidyverse   1.3.1
# timeDate    timeDate    3043.102
# tinytex     tinytex     0.35
# triebeard   triebeard   0.3.0
# TTR         TTR         0.24.2
# ...
