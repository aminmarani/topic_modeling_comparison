# %% [markdown]
# # topic modeling pipeline
#
# This notebook will walk you through:
# 1. data reterival from SQL database
# 2. Pre-processing data
# 3. Running topic modeling (different models)
# 4. post processing (including showing topics, topic-doc distribution, etc.)
# 5. Storing results into DB

# %% [markdown]
# # imports

# %%
from pre_processing import remove_html_tags, preprocess_data, prepare_corpus
from post_processing import topic_selection
from rpy2 import robjects #loading R inside Python
#importing functions to read pandas DF
from rpy2.robjects import pandas2ri
pandas2ri.activate()
from rpy2.robjects.packages import importr
from rpy2.robjects.conversion import localconverter

import pandas as pd

import numpy as np

#import R base library
base = importr('base')

mallet_path = 'mallet' #'mallet for mac-os
# Out:
# [nltk_data] Downloading package stopwords to /Users/das-
# [nltk_data]     lab/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/das-lab/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /Users/das-lab/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/das-lab/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# # Loading data from SQL database
#
# First creating a connection
#
# **In order to create a connection from anywhere in LU network you need to run the command below in terminal. Replace your username with amh418 in the command below.**
#
# ssh -L 3306:127.0.0.1:3306 -N -f amh418@128.180.111.76   #it will ask for lehigh pass
#
# on network (128.180.111.76)
# outside the network (ssh.lehigh.edu)
#
# **if you need to kill to SSH forwarding use the link below**
#
# https://superuser.com/questions/87014/how-do-i-remove-an-ssh-forwarded-port

# %%
import mysql.connector

#connecting to DB
cnx = mysql.connector.connect(user='push', password='ElI)g!LDOBIwM)%*5o5{dbfz('
                              ,host='127.0.0.1',database='edml')

# %% [markdown]
# Retreiving all the posts

# %%
cursor = cnx.cursor() #making a cursor to execute a SQL command
cursor.execute("select * from post") #execute a command
myresult = cursor.fetchall() #get all the results 
print('{0} posts were retreived'.format(len(myresult)))
# Out:
# 10873 posts were retreived

# %% [markdown]
# # preprocessing the data
#
# First, removing html tags

# %% [markdown]
# prepare the corupus

# %%
#removing tags from texts
proc_texts = [remove_html_tags(i[3]) for i in myresult]
#pre_processing and tokenizing docs
pre_processed_docs,orig_docs = preprocess_data(proc_texts)
#attaching (id,original_text,pre_processed_text,date,url) together
id_text = [(myresult[orig_docs[i][1]][0],orig_docs[i][0],pre_processed_docs[i],
            myresult[orig_docs[i][1]][4],myresult[orig_docs[i][1]][5]) for i in range(len(orig_docs))]

# vocab_dict, doc_term_matrix = prepare_corpus(pre_processed_docs) ==> we don't need prepare corpus as we are passing this to LDA and STM R and there they will do tokenization 

#creat a pandas DF with one column as text, one column as original text, one column as SQL post-id, etc.
text_df = pd.DataFrame(zip([i[0] for i in id_text],[' '.join(i[2]) for i in id_text],
                           [i[1] for i in id_text],[i[3] for i in id_text],[i[4] for i in id_text]),
                       columns=['id','text','original_text','date','url'])

# %%
#removing duplicates only if necessary
print(len(text_df))
text_df = text_df.drop_duplicates(subset=['text'])
print(len(text_df))
# Out:
# 10414
# 10068

# %% [markdown]
# Processing documens for Topicalizer

# %%
text_df[['date','original_text','url']].rename(columns={'original_text':'entry','url':'Link'}).reset_index().to_csv('./data/Processed_ed.csv')

# %%
list(text_df.sample(frac=0.01)['url'])
# Out:
# ['https://www.instagram.com/p/CjfnF3igEEA/',
#  'https://www.instagram.com/p/BknxAlBAcPW/',
#  'https://www.instagram.com/p/BJtMcdMjxt-/',
#  'https://imtrying-butimpissed.tumblr.com/post/190309874574/that-looks-bomb-omg-i-need-that-in-my-life',
#  'https://www.instagram.com/p/Btj4dqqgewP/',
#  'https://www.instagram.com/p/By3TaoAn_aw/',
#  'https://www.instagram.com/p/CgJVMazAh42/',
#  'https://www.instagram.com/p/gtMg04SsLU/',
#  'https://www.instagram.com/p/Bf6BkQYg5sP/',
#  'https://www.instagram.com/p/ByN6SuRJ2qK/',
#  'https://www.instagram.com/p/CMxbBkpH8xv/',
#  'https://www.instagram.com/p/CE7Tz9DjncJ/',
#  'https://www.instagram.com/p/CbUfPHHgKco/',
#  'https://www.instagram.com/p/CT9FVWABtst/',
#  'https://www.instagram.com/p/B8q-vyPDu3F/',
#  'https://www.instagram.com/p/B4MQvALn98W/',
#  'https://www.instagram.com/p/CjjXfLVoUTQ/',
#  'https://www.instagram.com/p/-2NdXKgTAP/',
#  'https://www.instagram.com/p/B4aLFuiFLxo/',
#  'https://www.instagram.com/p/CNH_HO-jS3y/',
#  'https://www.instagram.com/p/BKYA_h2ATnN/',
#  'https://www.instagram.com/p/B4fMnzLDYJG/',
#  'https://www.instagram.com/p/BmqhJ3NHBfy/',
#  'https://www.instagram.com/p/Crs99KiItmR/',
#  'https://www.instagram.com/p/B2mEUHclsJU/',
#  'https://www.instagram.com/p/Bi5GwacAlld/',
#  'https://www.instagram.com/p/CeTPtUTMhx2/',
#  'https://www.instagram.com/p/Ca22Do8vIsJ/',
#  'https://www.instagram.com/p/CTH15kaLKYv/',
#  'https://www.instagram.com/p/CXyvAA2rWFD/',
#  'https://www.instagram.com/p/Bt03NzgndIw/',
#  'https://www.instagram.com/p/B8ytRjPlwMz/',
#  'https://www.instagram.com/p/CnR_kA7KrZT/',
#  'https://www.instagram.com/p/BjugN3pAoll/',
#  'https://www.instagram.com/p/ByDykwyjkxs/',
#  'https://www.instagram.com/p/BSuX3BMAD5_/',
#  'https://www.instagram.com/p/BNtX4gtDWwH/',
#  'https://www.instagram.com/p/CUkilsVLc0U/',
#  'https://www.instagram.com/p/CC0yrVPplsz/',
#  'https://www.instagram.com/p/BhxmLjmlvSh/',
#  'https://www.instagram.com/p/CI3OXkghAd2/',
#  'https://www.instagram.com/p/Bvd0aanlRzG/',
#  'https://www.instagram.com/p/ByVcaDoHFd-/',
#  'https://www.instagram.com/p/BqcyZJ0gFOa/',
#  'https://www.instagram.com/p/BmXvdkuAhHG/',
#  'https://www.instagram.com/p/CeLcYGOhEGO/',
#  'https://www.instagram.com/p/CidKIngAr2e/',
#  'https://imtrying-butimpissed.tumblr.com/post/190541069429/i-could-use-some-words-of-encouragement',
#  'https://www.instagram.com/p/BZBIrolg1iT/',
#  'https://www.instagram.com/p/B9jheJ8JzqZ/',
#  'https://www.instagram.com/p/CIgA5-FDMYz/',
#  'https://www.instagram.com/p/BIDr4ZOj55F/',
#  'https://www.instagram.com/p/CVa68plsyPe/',
#  'https://www.instagram.com/p/B7uPYS6nvRc/',
#  'https://www.instagram.com/p/CjLvNwNjwvX/',
#  'https://www.instagram.com/p/BSMdwmxAZuJ/',
#  'https://www.instagram.com/p/CTAv2gVrj0F/',
#  'https://www.instagram.com/p/BOhHvVXDm1N/',
#  'https://www.instagram.com/p/CczokOdPkqe/',
#  'https://www.instagram.com/p/B8rCIi9pV2x/',
#  'https://www.instagram.com/p/Bqr8qZUAUWL/',
#  'https://www.instagram.com/p/CZap2vYJrVU/',
#  'https://www.instagram.com/p/CGsnYndDdaO/',
#  'https://www.instagram.com/p/CGk_W3Tj-Bf/',
#  'https://www.instagram.com/p/CMde7WAFSwh/',
#  'https://www.instagram.com/p/B6C-Lw_FdIW/',
#  'https://www.instagram.com/p/CC1j_rNp3Et/',
#  'https://www.instagram.com/p/CjtC-2EggHF/',
#  'https://imtrying-butimpissed.tumblr.com/post/639302701315997696/okay-fatass-retard',
#  'https://www.instagram.com/p/Bw9ysZlpmsS/',
#  'https://imtrying-butimpissed.tumblr.com/post/189446006459/damn-i-miss-having-friends',
#  'https://www.instagram.com/p/B1tLr07pm7T/',
#  'https://www.instagram.com/p/CLHvhz_LkzU/',
#  'https://imtrying-butimpissed.tumblr.com/post/617590523877900288/i-like-this-good-content',
#  'https://www.instagram.com/p/Bammnz3nnit/',
#  'https://www.instagram.com/p/CErrn2ujfQh/',
#  'https://www.instagram.com/p/BsikgBPHF_V/',
#  'https://www.instagram.com/p/CEfbHPQpKsa/',
#  'https://www.instagram.com/p/CWsJxo-Bg2N/',
#  'https://www.instagram.com/p/BLIgUzYjquO/',
#  'https://www.instagram.com/p/CJycpFslazl/',
#  'https://www.instagram.com/p/BotFMcAAI6Q/',
#  'https://www.instagram.com/p/CBa_V9cjeCW/',
#  'https://www.instagram.com/p/CAdAihlJH-u/',
#  'https://www.instagram.com/p/CSBkT7kgS7j/',
#  'https://www.instagram.com/p/COXSsw0BZcm/',
#  'https://www.instagram.com/p/BcN0JvYjkkw/',
#  'https://www.instagram.com/p/BJGnOIjDEHr/',
#  'https://imtrying-butimpissed.tumblr.com/post/659955887354544128/vaccinated-folks-are-cool-actually',
#  'https://www.instagram.com/p/BoH3SfwAhjR/',
#  'https://www.instagram.com/p/CLkENU1sviG/',
#  'https://www.instagram.com/p/CrbTfBeNx2w/',
#  'https://www.instagram.com/p/BWXPlV_AN2b/',
#  'https://imtrying-butimpissed.tumblr.com/post/189445898909/congrats-on-the-recovery-win-hell-yes',
#  'https://imtrying-butimpissed.tumblr.com/post/639719690330079232/did-that-thing-again-where-i-tried-something-new',
#  'https://www.instagram.com/p/CRXEeECD7wD/',
#  'https://www.instagram.com/p/Bn6sl_pg_oz/',
#  'https://www.instagram.com/p/CpOXBmOr6CD/',
#  'https://www.instagram.com/p/BcXhfANl81T/',
#  'https://www.instagram.com/p/CtHNuOEo640/',
#  'https://www.instagram.com/p/CW16wU5oso5/']

# %% [markdown]
# # Running topic modeling (with or without evaluation)

# %%
# from rpy2.robjects.packages import importr
# utils = importr('utils')

# utils.install_packages('stm',repos="https://cloud.r-project.org")

# %%
is_eval = False #not evaluating the model
#need to provide number of topics and other specification
model_spec = {'name':'LDA','K':9,'epochs':2000,'burnin_iteration':20,'after_iteration_burnin':50,
             'save_flag':True,'save_path':'LDA_test'}
# model_spec = {'name':'STM','K':90,'epochs':500,'prevalence':'','content':'','pre_trained_model': 'LDA',\
#                 'burnin_iteration':20,'LDA_epochs':50,'save_flag':True}

if model_spec['name'] == 'LDA':
    if is_eval:
        #loading LDA mallet evaluation score
        from lda_mallet import lda_score
        from gensim.corpora import Dictionary
        import pickle
        from pre_processing import prepare_corpus
        #creating data vocab
        dict = Dictionary([i.split() for i in list(text_df.text)])
        #saving it to pass it to score object
        with open ('./data/ED_vocab.obj','wb') as vfile:
            pickle.dump(dict,vfile)
        wiki_vocab_dict_path = './data/wiki_sampled5p_vocab.obj'
        with open ('./data/wiki_sampled5p_vocab.obj','rb') as vfile:
            wiki_vocab_dict = pickle.load(vfile)


        npmis = []
        for n_topics in range(2,20,1):
            #removing terms that are not in the Wiki Vocab
            #pre_processing and tokenizing docs
            pre_processed_docs,_ = preprocess_data(list(text_df.text),extra_stopwords=\
                                                           set(dict.values()).difference(set(wiki_vocab_dict.values()))\
                                                   .union(['denying']))
            #preparing corpus
            vocab_dict,doc_term_mat = prepare_corpus(pre_processed_docs)
            #temp save of vocab file
            with open ('./data/ED_vocab.tmp','wb') as vfile:
                pickle.dump(vocab_dict,vfile)
            
            scorer = lda_score(num_topics=n_topics,alpha=10,optimize_interval=10,iterations=2000,wiki_path='./data/wiki_sampled_5p.txt',
                      db_path = './data/wiki_full/',vocab_dict_path = './data/ED_vocab.tmp', 
                      wiki_vocab_dict_path=wiki_vocab_dict_path,npmi_skip_threshold=0.30)
            
            scorer.fit(doc_term_mat)#fitting an LDA Mallet
            npmis.append([n_topics,scorer.score()])
    else: 
        robjects.r.source('LDA_R.R')
        ans = robjects.r.findTopics(docs = text_df,n_topics = model_spec['K'],epochs = model_spec['epochs'],
                                    burnin_iteration = model_spec['burnin_iteration'],
                                    after_iteration_burnin =  model_spec['after_iteration_burnin'],
                                    save_flag=model_spec['save_flag'],save_path = model_spec['save_path'])
        top_terms = np.asarray(ans[1])
        topic_doc_dist = np.asarray(ans[0][0]).T
        term_probab = ans[0][1]
        topic_vocab = ans[0][2]
        
        
elif model_spec['name'] == 'STM':
    if is_eval:
        pass
    else: 
        robjects.r.source('stm.R')
        ans = robjects.r.run_stm(docs = text_df,topic_n=model_spec['K'],max_itr=model_spec['epochs'],
                                 prevalence=model_spec['prevalence'],content=model_spec['content'],
                                 model_type = model_spec['pre_trained_model'],
                                 nits = model_spec['LDA_epochs'],burnin = model_spec['burnin_iteration'],
                                 save_flag = True)
        top_terms = np.asarray(ans[1]).reshape(model_spec['K'],50,order='F')
        topic_doc_dist = 0.00
# Out:
# R[write to console]: Loading required package: rJava
#
# R[write to console]: Loading required package: mallet
#
# R[write to console]: Loading required package: reshape2
#
# R[write to console]: Loading required package: reticulate
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
# R[write to console]: Loading required package: qdapTools
#
# R[write to console]: Loading required package: reader
#
# R[write to console]: Loading required package: NCmisc
#
# R[write to console]:
# Attaching package: ‘reader’
#
#
# R[write to console]: The following objects are masked from ‘package:NCmisc’:
#
#     cat.path, get.ext, rmv.ext
#
#
# R[write to console]: Loading required package: dplyr
#
# R[write to console]:
# Attaching package: ‘dplyr’
#
#
# R[write to console]: The following object is masked from ‘package:qdapTools’:
#
#     id
#
#
# R[write to console]: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# R[write to console]: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# R[write to console]: Loading required package: ggplot2
#
# R[write to console]: Loading required package: jsonlite
# [1] "Building mallet instance ..."
# [1] "Building topic trainer ..."
# [1] "Loading documents in mallet instance into topic trainer ..."
# [1] "Training model ..."
# Oct 02, 2023 9:31:20 AM cc.mallet.topics.ParallelTopicModel <init>
# INFO: Mallet LDA: 9 topics, 4 topic bits, 1111 topic mask
# Oct 02, 2023 9:31:20 AM cc.mallet.topics.ParallelTopicModel initializeHistograms
# INFO: max tokens: 595
# Oct 02, 2023 9:31:20 AM cc.mallet.topics.ParallelTopicModel initializeHistograms
# INFO: total tokens: 638933
# Oct 02, 2023 9:31:21 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <10> LL/token: -8.73656
# Oct 02, 2023 9:31:22 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <20> LL/token: -8.40788
# Oct 02, 2023 9:31:23 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <30> LL/token: -8.32238
# Oct 02, 2023 9:31:23 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <40> LL/token: -8.2836
# Oct 02, 2023 9:31:24 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.55556	day food good like meal cream eat
# 1	0.55556	wellness healthy plantpower glutenfree fitness healthyinspo healthyfood
# 2	0.55556	body health weight us recovery know self
# 3	0.55556	eating support us recovery link bio disorders
# 4	0.55556	love day like life time one happy
# 5	0.55556	cup chocolate butter tbsp add mix ingredients
# 6	0.55556	feel life food like time eat eating
# 7	0.55556	also new guys time one day know
# 8	0.55556	edrecovery recovery eatingdisorderrecovery haes meda recoverwithmeda intuitiveeating
#
# Oct 02, 2023 9:31:24 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <50> LL/token: -8.26054
# Oct 02, 2023 9:31:25 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.03302]
# Oct 02, 2023 9:31:25 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <60> LL/token: -8.21375
# Oct 02, 2023 9:31:26 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <70> LL/token: -8.20858
# Oct 02, 2023 9:31:27 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.03848]
# Oct 02, 2023 9:31:27 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <80> LL/token: -8.19496
# Oct 02, 2023 9:31:28 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <90> LL/token: -8.17973
# Oct 02, 2023 9:31:28 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.40055	day food eat good like cream meal
# 1	0.17619	wellness fitness glutenfree cleaneats foodie healthy thenewhealth
# 2	0.39118	body weight health healthy look diet recovery
# 3	0.35326	eating recovery support us disorders meda link
# 4	0.59914	love day life time like one happy
# 5	0.20868	cup chocolate butter tbsp add mix vanilla
# 6	0.58666	feel life like food eating time eat
# 7	0.41649	also guys vegan new video know one
# 8	0.21278	edrecovery eatingdisorderrecovery haes recovery meda recoverwithmeda reads
#
# Oct 02, 2023 9:31:29 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04012]
# Oct 02, 2023 9:31:29 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <100> LL/token: -8.17188
# Oct 02, 2023 9:31:29 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <110> LL/token: -8.15595
# Oct 02, 2023 9:31:30 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04137]
# Oct 02, 2023 9:31:30 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <120> LL/token: -8.15277
# Oct 02, 2023 9:31:31 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <130> LL/token: -8.13632
# Oct 02, 2023 9:31:32 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04237]
# Oct 02, 2023 9:31:32 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <140> LL/token: -8.12919
# Oct 02, 2023 9:31:32 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.24535	food day protein like eat good cream
# 1	0.08234	healthy wellness glutenfree foodie foodblogger healthyfood healthyinspo
# 2	0.1818	body weight way health look diet healthy
# 3	0.20694	eating recovery support us meda disorders edrecovery
# 4	0.47114	life love time day one things like
# 5	0.09212	cup chocolate butter tbsp add mix powder
# 6	0.43391	food feel eating eat like get know
# 7	0.21442	also guys vegan video one new day
# 8	0.08498	edrecovery haes eatingdisorderrecovery recoverwithmeda reads meda intuitiveeating
#
# Oct 02, 2023 9:31:32 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <150> LL/token: -8.11528
# Oct 02, 2023 9:31:33 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04332]
# Oct 02, 2023 9:31:33 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <160> LL/token: -8.11041
# Oct 02, 2023 9:31:34 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <170> LL/token: -8.10433
# Oct 02, 2023 9:31:34 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04411]
# Oct 02, 2023 9:31:34 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <180> LL/token: -8.10104
# Oct 02, 2023 9:31:35 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <190> LL/token: -8.09175
# Oct 02, 2023 9:31:36 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.18458	day protein like food morning eat breakfast
# 1	0.06707	healthy wellness glutenfree foodie healthyfood healthyinspo foodblogger
# 2	0.12339	body weight look see way health feel
# 3	0.16159	eating recovery support us meda disorders edrecovery
# 4	0.39852	life time love day like one things
# 5	0.0632	cup chocolate tbsp butter add mix powder
# 6	0.33795	food eating feel like eat know life
# 7	0.14737	guys also vegan video one new know
# 8	0.05895	edrecovery haes eatingdisorderrecovery recoverwithmeda reads meda green
#
# Oct 02, 2023 9:31:36 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04468]
# Oct 02, 2023 9:31:36 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <200> LL/token: -8.09054
# Oct 02, 2023 9:31:37 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <210> LL/token: -8.08495
# Oct 02, 2023 9:31:38 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04508]
# Oct 02, 2023 9:31:38 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <220> LL/token: -8.0804
# Oct 02, 2023 9:31:38 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <230> LL/token: -8.07866
# Oct 02, 2023 9:31:39 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04568]
# Oct 02, 2023 9:31:39 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <240> LL/token: -8.07547
# Oct 02, 2023 9:31:40 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.13499	protein day like breakfast food morning bowl
# 1	0.05685	healthy wellness glutenfree foodie healthyfood foodblogger healthyinspo
# 2	0.08199	body weight look see way feel bodies
# 3	0.12552	eating recovery support us meda edrecovery disorders
# 4	0.32799	time life love day like feel things
# 5	0.04552	cup chocolate tbsp butter add flour mix
# 6	0.23716	food eating eat like feel body want
# 7	0.10282	guys vegan also video one new know
# 8	0.0459	recoverwithmeda edrecovery haes eatingdisorderrecovery reads meda green
#
# Oct 02, 2023 9:31:40 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <250> LL/token: -8.06802
# Oct 02, 2023 9:31:41 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04616]
# Oct 02, 2023 9:31:41 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <260> LL/token: -8.06914
# Oct 02, 2023 9:31:41 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <270> LL/token: -8.06203
# Oct 02, 2023 9:31:42 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04638]
# Oct 02, 2023 9:31:42 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <280> LL/token: -8.05897
# Oct 02, 2023 9:31:43 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <290> LL/token: -8.0578
# Oct 02, 2023 9:31:44 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.11608	protein day like breakfast morning one cream
# 1	0.05468	healthy glutenfree wellness foodie healthyfood foodblogger healthyinspo
# 2	0.06698	body look weight see way feel like
# 3	0.11313	eating recovery support us meda edrecovery disorders
# 4	0.30353	time life love day like things feel
# 5	0.04018	cup chocolate tbsp butter add flour powder
# 6	0.19367	food eating body eat feel like want
# 7	0.08694	guys vegan also video one new day
# 8	0.04182	edrecovery recoverwithmeda haes eatingdisorderrecovery reads meda green
#
# Oct 02, 2023 9:31:44 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.0466]
# Oct 02, 2023 9:31:44 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <300> LL/token: -8.05685
# Oct 02, 2023 9:31:45 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <310> LL/token: -8.05151
# Oct 02, 2023 9:31:45 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04694]
# Oct 02, 2023 9:31:45 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <320> LL/token: -8.04908
# Oct 02, 2023 9:31:46 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <330> LL/token: -8.04491
# Oct 02, 2023 9:31:47 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04711]
# Oct 02, 2023 9:31:47 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <340> LL/token: -8.0432
# Oct 02, 2023 9:31:47 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.1009	protein like day bowl breakfast chocolate morning
# 1	0.05119	healthy wellness foodie glutenfree healthyfood foodblogger healthyinspo
# 2	0.05444	body see way feel look weight like
# 3	0.10246	eating recovery support us meda edrecovery disorders
# 4	0.28291	life time love day like feel things
# 5	0.03626	cup chocolate tbsp butter add flour powder
# 6	0.1546	food eating body eat feel like im
# 7	0.07605	guys vegan also new one video day
# 8	0.03858	recoverwithmeda edrecovery haes eatingdisorderrecovery reads meda green
#
# Oct 02, 2023 9:31:47 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <350> LL/token: -8.04465
# Oct 02, 2023 9:31:48 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04727]
# Oct 02, 2023 9:31:48 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <360> LL/token: -8.03863
# Oct 02, 2023 9:31:48 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <370> LL/token: -8.03523
# Oct 02, 2023 9:31:49 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04745]
# Oct 02, 2023 9:31:49 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <380> LL/token: -8.03504
# Oct 02, 2023 9:31:50 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <390> LL/token: -8.03251
# Oct 02, 2023 9:31:50 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.0951	protein day like breakfast morning bowl chocolate
# 1	0.04979	healthy glutenfree foodblogger wellness foodie healthyfood healthyinspo
# 2	0.05025	body way see look feel like bodies
# 3	0.09849	eating recovery support us meda edrecovery disorders
# 4	0.27344	life time love like feel day things
# 5	0.03411	cup chocolate tbsp butter add flour mix
# 6	0.13749	food eating body eat im like feel
# 7	0.07384	guys vegan also one video new day
# 8	0.03729	recoverwithmeda edrecovery haes eatingdisorderrecovery reads meda green
#
# Oct 02, 2023 9:31:50 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04761]
# Oct 02, 2023 9:31:50 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <400> LL/token: -8.02836
# Oct 02, 2023 9:31:51 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <410> LL/token: -8.02672
# Oct 02, 2023 9:31:51 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04775]
# Oct 02, 2023 9:31:51 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <420> LL/token: -8.02589
# Oct 02, 2023 9:31:52 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <430> LL/token: -8.02515
# Oct 02, 2023 9:31:53 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04792]
# Oct 02, 2023 9:31:53 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <440> LL/token: -8.02455
# Oct 02, 2023 9:31:53 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.09091	day protein like good breakfast bowl morning
# 1	0.04826	healthy wellness glutenfree foodie healthyfood healthyinspo foodblogger
# 2	0.04604	body see feel way look like bodies
# 3	0.09392	eating recovery support us meda edrecovery disorders
# 4	0.26125	life time feel love things like day
# 5	0.03294	cup chocolate tbsp butter add flour powder
# 6	0.11673	food eating body eat like weight recovery
# 7	0.07499	guys vegan also one new day video
# 8	0.03559	recoverwithmeda haes edrecovery eatingdisorderrecovery reads meda green
#
# Oct 02, 2023 9:31:53 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <450> LL/token: -8.02196
# Oct 02, 2023 9:31:54 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04791]
# Oct 02, 2023 9:31:54 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <460> LL/token: -8.01975
# Oct 02, 2023 9:31:55 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <470> LL/token: -8.0194
# Oct 02, 2023 9:31:55 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04783]
# Oct 02, 2023 9:31:55 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <480> LL/token: -8.01746
# Oct 02, 2023 9:31:56 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <490> LL/token: -8.01631
# Oct 02, 2023 9:31:56 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.08968	day protein like good breakfast bowl morning
# 1	0.04677	healthy foodie wellness healthyfood glutenfree foodblogger healthyinspo
# 2	0.04404	body see look way feel day like
# 3	0.09269	eating recovery support us meda edrecovery disorders
# 4	0.25746	life time feel like love things know
# 5	0.0317	cup chocolate tbsp butter add flour mix
# 6	0.10654	food eating body eat weight recovery im
# 7	0.07615	guys vegan also day one new video
# 8	0.03501	recoverwithmeda edrecovery haes eatingdisorderrecovery reads meda bodyrespect
#
# Oct 02, 2023 9:31:56 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04772]
# Oct 02, 2023 9:31:56 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <500> LL/token: -8.01451
# Oct 02, 2023 9:31:57 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <510> LL/token: -8.01496
# Oct 02, 2023 9:31:58 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.048]
# Oct 02, 2023 9:31:58 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <520> LL/token: -8.01379
# Oct 02, 2023 9:31:58 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <530> LL/token: -8.01417
# Oct 02, 2023 9:31:59 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04798]
# Oct 02, 2023 9:31:59 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <540> LL/token: -8.01524
# Oct 02, 2023 9:31:59 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.08993	protein day like morning breakfast good bowl
# 1	0.04663	healthy glutenfree wellness healthyfood foodblogger foodie healthyinspo
# 2	0.04155	body see look feel way like day
# 3	0.09129	eating recovery support us meda edrecovery disorders
# 4	0.25466	life time feel love things like know
# 5	0.03195	cup chocolate tbsp butter add flour powder
# 6	0.09688	food eating body eat weight recovery im
# 7	0.07706	guys vegan also day one new video
# 8	0.03424	recoverwithmeda eatingdisorderrecovery edrecovery haes reads meda bodyrespect
#
# Oct 02, 2023 9:31:59 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <550> LL/token: -8.01671
# Oct 02, 2023 9:32:00 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04793]
# Oct 02, 2023 9:32:00 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <560> LL/token: -8.01398
# Oct 02, 2023 9:32:01 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <570> LL/token: -8.01379
# Oct 02, 2023 9:32:01 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04816]
# Oct 02, 2023 9:32:01 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <580> LL/token: -8.01119
# Oct 02, 2023 9:32:02 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <590> LL/token: -8.01344
# Oct 02, 2023 9:32:02 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.08927	day protein like breakfast morning one good
# 1	0.04569	healthy glutenfree foodblogger foodie wellness healthyfood healthyinspo
# 2	0.03999	body see look way feel day like
# 3	0.08952	eating recovery support us meda edrecovery disorders
# 4	0.25252	life time feel love like things know
# 5	0.03132	cup chocolate tbsp butter add mix flour
# 6	0.09442	food eating body eat weight recovery like
# 7	0.07807	guys also vegan day new one video
# 8	0.03405	recoverwithmeda haes edrecovery eatingdisorderrecovery reads meda green
#
# Oct 02, 2023 9:32:02 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04788]
# Oct 02, 2023 9:32:02 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <600> LL/token: -8.01175
# Oct 02, 2023 9:32:03 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <610> LL/token: -8.01259
# Oct 02, 2023 9:32:04 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04802]
# Oct 02, 2023 9:32:04 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <620> LL/token: -8.01183
# Oct 02, 2023 9:32:04 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <630> LL/token: -8.01065
# Oct 02, 2023 9:32:05 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04832]
# Oct 02, 2023 9:32:05 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <640> LL/token: -8.01285
# Oct 02, 2023 9:32:05 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.08875	day protein like morning bowl breakfast cream
# 1	0.0456	healthy glutenfree wellness foodie healthyfood healthyinspo foodblogger
# 2	0.03801	body see look feel way like day
# 3	0.08959	eating recovery support us meda edrecovery disorders
# 4	0.24954	life time feel like love things know
# 5	0.03136	cup chocolate tbsp butter add flour mix
# 6	0.09094	food eating body eat weight recovery im
# 7	0.07929	guys vegan also one day new video
# 8	0.03388	recoverwithmeda edrecovery haes eatingdisorderrecovery reads meda green
#
# Oct 02, 2023 9:32:05 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <650> LL/token: -8.0126
# Oct 02, 2023 9:32:06 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04824]
# Oct 02, 2023 9:32:06 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <660> LL/token: -8.01249
# Oct 02, 2023 9:32:07 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <670> LL/token: -8.01272
# Oct 02, 2023 9:32:08 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04805]
# Oct 02, 2023 9:32:08 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <680> LL/token: -8.00914
# Oct 02, 2023 9:32:09 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <690> LL/token: -8.01009
# Oct 02, 2023 9:32:09 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.08911	protein day like morning breakfast chocolate bowl
# 1	0.04508	healthy wellness glutenfree foodie foodblogger healthyfood healthyinspo
# 2	0.03721	body see way look day feel like
# 3	0.08946	eating recovery support us meda edrecovery disorders
# 4	0.24711	life time feel like love know things
# 5	0.03122	cup chocolate tbsp butter add flour powder
# 6	0.08993	food eating body eat weight recovery im
# 7	0.08074	guys also vegan day new one video
# 8	0.03391	recoverwithmeda haes edrecovery eatingdisorderrecovery reads meda green
#
# Oct 02, 2023 9:32:09 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04817]
# Oct 02, 2023 9:32:09 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <700> LL/token: -8.00897
# Oct 02, 2023 9:32:10 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <710> LL/token: -8.01148
# Oct 02, 2023 9:32:11 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04834]
# Oct 02, 2023 9:32:11 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <720> LL/token: -8.0121
# Oct 02, 2023 9:32:12 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <730> LL/token: -8.01093
# Oct 02, 2023 9:32:13 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04817]
# Oct 02, 2023 9:32:13 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <740> LL/token: -8.00969
# Oct 02, 2023 9:32:14 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.08904	day protein like breakfast morning bowl one
# 1	0.04497	healthy glutenfree foodie wellness foodblogger healthyfood healthyinspo
# 2	0.0364	body see look way feel like day
# 3	0.08867	eating recovery support us meda edrecovery disorders
# 4	0.2465	life time feel like love things know
# 5	0.03087	cup chocolate tbsp butter add flour mix
# 6	0.08701	food eating body eat weight recovery like
# 7	0.08017	guys also day vegan one new love
# 8	0.03379	recoverwithmeda eatingdisorderrecovery edrecovery haes reads meda green
#
# Oct 02, 2023 9:32:14 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <750> LL/token: -8.00875
# Oct 02, 2023 9:32:15 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04833]
# Oct 02, 2023 9:32:15 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <760> LL/token: -8.00856
# Oct 02, 2023 9:32:15 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <770> LL/token: -8.00848
# Oct 02, 2023 9:32:16 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04825]
# Oct 02, 2023 9:32:16 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <780> LL/token: -8.00787
# Oct 02, 2023 9:32:17 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <790> LL/token: -8.01132
# Oct 02, 2023 9:32:18 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.08807	day protein like morning bowl breakfast chocolate
# 1	0.04479	healthy glutenfree wellness foodie foodblogger healthyfood healthyinspo
# 2	0.03584	body see feel look way like love
# 3	0.08809	eating recovery support us meda edrecovery disorders
# 4	0.24682	life time feel like love things know
# 5	0.03043	cup chocolate tbsp butter add flour mix
# 6	0.08668	food eating body eat weight recovery im
# 7	0.08012	guys vegan also day one new video
# 8	0.03394	edrecovery recoverwithmeda haes eatingdisorderrecovery reads meda green
#
# Oct 02, 2023 9:32:18 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04832]
# Oct 02, 2023 9:32:18 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <800> LL/token: -8.00893
# Oct 02, 2023 9:32:18 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <810> LL/token: -8.01146
# Oct 02, 2023 9:32:19 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.0482]
# Oct 02, 2023 9:32:19 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <820> LL/token: -8.01122
# Oct 02, 2023 9:32:20 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <830> LL/token: -8.00853
# Oct 02, 2023 9:32:21 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04843]
# Oct 02, 2023 9:32:21 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <840> LL/token: -8.01241
# Oct 02, 2023 9:32:22 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.08691	day protein like morning breakfast bowl one
# 1	0.04505	healthy glutenfree wellness foodie healthyfood healthyinspo foodblogger
# 2	0.03642	body see look way feel like day
# 3	0.08774	eating recovery support us meda edrecovery disorders
# 4	0.24448	life time feel like love things know
# 5	0.0303	cup chocolate tbsp butter add flour powder
# 6	0.08709	food eating body eat weight recovery im
# 7	0.08039	guys vegan also day one new video
# 8	0.03339	recoverwithmeda haes edrecovery eatingdisorderrecovery reads meda green
#
# Oct 02, 2023 9:32:22 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <850> LL/token: -8.00977
# Oct 02, 2023 9:32:22 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04835]
# Oct 02, 2023 9:32:22 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <860> LL/token: -8.01051
# Oct 02, 2023 9:32:23 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <870> LL/token: -8.00983
# Oct 02, 2023 9:32:24 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04838]
# Oct 02, 2023 9:32:24 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <880> LL/token: -8.01099
# Oct 02, 2023 9:32:24 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <890> LL/token: -8.00919
# Oct 02, 2023 9:32:25 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.08683	day protein like bowl breakfast one good
# 1	0.04482	healthy foodie glutenfree wellness healthyfood healthyinspo foodblogger
# 2	0.0364	body see way look feel like day
# 3	0.08806	eating recovery support us meda edrecovery disorders
# 4	0.24328	life time feel like love things know
# 5	0.03034	cup chocolate tbsp butter add flour mix
# 6	0.0867	food eating body eat weight recovery im
# 7	0.0797	guys vegan also day one new time
# 8	0.03305	recoverwithmeda edrecovery haes eatingdisorderrecovery meda reads green
#
# Oct 02, 2023 9:32:25 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04835]
# Oct 02, 2023 9:32:25 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <900> LL/token: -8.00945
# Oct 02, 2023 9:32:26 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <910> LL/token: -8.00983
# Oct 02, 2023 9:32:27 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04853]
# Oct 02, 2023 9:32:27 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <920> LL/token: -8.01043
# Oct 02, 2023 9:32:28 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <930> LL/token: -8.01069
# Oct 02, 2023 9:32:28 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04836]
# Oct 02, 2023 9:32:29 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <940> LL/token: -8.00814
# Oct 02, 2023 9:32:29 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.08585	day protein like breakfast morning bowl one
# 1	0.04487	healthy foodie glutenfree wellness foodblogger healthyfood healthyinspo
# 2	0.03725	body see look way feel like day
# 3	0.08808	eating recovery support us meda edrecovery disorders
# 4	0.24125	life time feel like love things know
# 5	0.03007	cup chocolate tbsp butter add flour mix
# 6	0.08574	food eating body eat weight recovery im
# 7	0.08022	guys vegan also day one new video
# 8	0.03365	edrecovery recoverwithmeda haes eatingdisorderrecovery reads meda green
#
# Oct 02, 2023 9:32:29 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <950> LL/token: -8.01004
# Oct 02, 2023 9:32:30 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04824]
# Oct 02, 2023 9:32:30 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <960> LL/token: -8.01021
# Oct 02, 2023 9:32:31 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <970> LL/token: -8.01362
# Oct 02, 2023 9:32:31 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04833]
# Oct 02, 2023 9:32:31 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <980> LL/token: -8.01014
# Oct 02, 2023 9:32:32 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <990> LL/token: -8.00902
# Oct 02, 2023 9:32:33 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.08703	day protein like bowl morning breakfast chocolate
# 1	0.04479	healthy wellness glutenfree healthyfood foodie foodblogger healthyinspo
# 2	0.03635	body see way look feel like day
# 3	0.08744	eating recovery support us meda edrecovery disorders
# 4	0.24054	life time feel like things love know
# 5	0.03073	cup chocolate tbsp butter add flour mix
# 6	0.08568	food eating body eat weight recovery im
# 7	0.081	guys vegan also one new day video
# 8	0.03328	recoverwithmeda haes edrecovery eatingdisorderrecovery reads meda green
#
# Oct 02, 2023 9:32:33 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04838]
# Oct 02, 2023 9:32:33 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1000> LL/token: -8.01104
# Oct 02, 2023 9:32:33 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1010> LL/token: -8.01063
# Oct 02, 2023 9:32:34 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.0483]
# Oct 02, 2023 9:32:34 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1020> LL/token: -8.01221
# Oct 02, 2023 9:32:36 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1030> LL/token: -8.01074
# Oct 02, 2023 9:32:39 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04835]
# Oct 02, 2023 9:32:39 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1040> LL/token: -8.01149
# Oct 02, 2023 9:32:40 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.08937	day protein like morning breakfast good bowl
# 1	0.04466	healthy glutenfree wellness foodie foodblogger healthyfood healthyinspo
# 2	0.03655	body see feel way look like day
# 3	0.08717	eating recovery support us meda edrecovery disorders
# 4	0.24051	life time feel like things love know
# 5	0.02977	cup chocolate tbsp butter add flour mix
# 6	0.08601	food eating body eat weight recovery im
# 7	0.08058	guys vegan also day new one time
# 8	0.03384	edrecovery recoverwithmeda haes eatingdisorderrecovery reads meda green
#
# Oct 02, 2023 9:32:40 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1050> LL/token: -8.01302
# Oct 02, 2023 9:32:41 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04827]
# Oct 02, 2023 9:32:41 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1060> LL/token: -8.01151
# Oct 02, 2023 9:32:42 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1070> LL/token: -8.01212
# Oct 02, 2023 9:32:42 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.0483]
# Oct 02, 2023 9:32:42 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1080> LL/token: -8.01122
# Oct 02, 2023 9:32:43 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1090> LL/token: -8.01204
# Oct 02, 2023 9:32:44 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.08926	day protein like morning one breakfast bowl
# 1	0.04436	healthy foodie glutenfree wellness foodblogger healthyfood healthyinspo
# 2	0.03641	body see look way day feel like
# 3	0.0876	eating recovery support us meda edrecovery disorders
# 4	0.23965	life time feel love like things know
# 5	0.03017	cup chocolate tbsp butter add flour mix
# 6	0.0862	food eating body eat weight recovery im
# 7	0.08067	guys also day vegan new one love
# 8	0.03355	recoverwithmeda edrecovery haes eatingdisorderrecovery reads meda green
#
# Oct 02, 2023 9:32:44 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04828]
# Oct 02, 2023 9:32:44 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1100> LL/token: -8.01149
# Oct 02, 2023 9:32:45 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1110> LL/token: -8.01056
# Oct 02, 2023 9:32:46 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04825]
# Oct 02, 2023 9:32:46 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1120> LL/token: -8.01034
# Oct 02, 2023 9:32:47 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1130> LL/token: -8.01212
# Oct 02, 2023 9:32:48 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04836]
# Oct 02, 2023 9:32:48 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1140> LL/token: -8.00902
# Oct 02, 2023 9:32:48 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.08941	day protein like breakfast bowl morning chocolate
# 1	0.04466	healthy glutenfree foodie wellness healthyfood foodblogger healthyinspo
# 2	0.03667	body see way look feel like day
# 3	0.08785	eating recovery support us meda edrecovery disorders
# 4	0.23927	life time feel like love things know
# 5	0.03015	cup chocolate tbsp butter add flour mix
# 6	0.08486	food eating body eat weight recovery im
# 7	0.08108	guys vegan also one day new love
# 8	0.03368	edrecovery recoverwithmeda haes eatingdisorderrecovery reads meda green
#
# Oct 02, 2023 9:32:48 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1150> LL/token: -8.01338
# Oct 02, 2023 9:32:49 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04825]
# Oct 02, 2023 9:32:49 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1160> LL/token: -8.01188
# Oct 02, 2023 9:32:50 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1170> LL/token: -8.0124
# Oct 02, 2023 9:32:51 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04832]
# Oct 02, 2023 9:32:51 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1180> LL/token: -8.01124
# Oct 02, 2023 9:32:51 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1190> LL/token: -8.01389
# Oct 02, 2023 9:32:52 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.089	day protein like good morning bowl breakfast
# 1	0.04516	healthy wellness glutenfree foodie foodblogger healthyfood healthyinspo
# 2	0.03683	body see way feel look day like
# 3	0.0875	eating recovery support us meda edrecovery disorders
# 4	0.23973	life time feel like love know things
# 5	0.02994	cup chocolate tbsp butter add flour mix
# 6	0.08601	food eating body eat weight recovery im
# 7	0.08211	guys also day vegan one new love
# 8	0.03344	haes edrecovery recoverwithmeda eatingdisorderrecovery reads meda green
#
# Oct 02, 2023 9:32:52 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04837]
# Oct 02, 2023 9:32:52 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1200> LL/token: -8.01271
# Oct 02, 2023 9:32:53 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1210> LL/token: -8.01145
# Oct 02, 2023 9:32:53 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04821]
# Oct 02, 2023 9:32:53 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1220> LL/token: -8.01054
# Oct 02, 2023 9:32:54 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1230> LL/token: -8.01201
# Oct 02, 2023 9:32:55 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04825]
# Oct 02, 2023 9:32:55 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1240> LL/token: -8.01128
# Oct 02, 2023 9:32:55 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.08972	day protein like breakfast one bowl morning
# 1	0.04462	healthy wellness glutenfree foodie healthyfood foodblogger healthyinspo
# 2	0.03565	body see day way feel like look
# 3	0.08779	eating recovery support us meda edrecovery disorders
# 4	0.23934	life time feel like things love know
# 5	0.03015	cup chocolate tbsp butter add flour mix
# 6	0.08512	food eating body eat weight recovery im
# 7	0.08174	guys also vegan day one new time
# 8	0.03324	recoverwithmeda haes edrecovery eatingdisorderrecovery reads meda green
#
# Oct 02, 2023 9:32:56 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1250> LL/token: -8.0088
# Oct 02, 2023 9:32:56 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04833]
# Oct 02, 2023 9:32:56 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1260> LL/token: -8.00865
# Oct 02, 2023 9:32:57 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1270> LL/token: -8.00929
# Oct 02, 2023 9:32:58 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04829]
# Oct 02, 2023 9:32:58 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1280> LL/token: -8.00942
# Oct 02, 2023 9:32:59 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1290> LL/token: -8.01132
# Oct 02, 2023 9:33:00 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.08882	day protein like breakfast morning chocolate good
# 1	0.0445	healthy foodie glutenfree healthyfood wellness foodblogger healthyinspo
# 2	0.0353	body see way look feel like real
# 3	0.08786	eating recovery support us meda edrecovery disorders
# 4	0.24093	life time feel love like things know
# 5	0.03008	cup chocolate tbsp butter add mix flour
# 6	0.08501	food eating body eat weight recovery im
# 7	0.08177	guys vegan also new day one time
# 8	0.03323	recoverwithmeda edrecovery haes eatingdisorderrecovery reads meda green
#
# Oct 02, 2023 9:33:00 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04849]
# Oct 02, 2023 9:33:00 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1300> LL/token: -8.01185
# Oct 02, 2023 9:33:00 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1310> LL/token: -8.0113
# Oct 02, 2023 9:33:01 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.0484]
# Oct 02, 2023 9:33:01 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1320> LL/token: -8.01065
# Oct 02, 2023 9:33:02 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1330> LL/token: -8.01036
# Oct 02, 2023 9:33:02 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04841]
# Oct 02, 2023 9:33:02 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1340> LL/token: -8.01099
# Oct 02, 2023 9:33:03 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.0883	day protein morning like breakfast bowl butter
# 1	0.04497	healthy wellness glutenfree healthyfood foodblogger foodie healthyinspo
# 2	0.03556	body see way look feel like day
# 3	0.08764	eating recovery support us meda edrecovery disorders
# 4	0.2411	life time feel like love things know
# 5	0.02983	cup chocolate tbsp butter add flour mix
# 6	0.08638	food eating body eat weight recovery im
# 7	0.08203	guys day one vegan also new time
# 8	0.03275	recoverwithmeda haes edrecovery eatingdisorderrecovery meda reads green
#
# Oct 02, 2023 9:33:03 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1350> LL/token: -8.01103
# Oct 02, 2023 9:33:04 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04841]
# Oct 02, 2023 9:33:04 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1360> LL/token: -8.01091
# Oct 02, 2023 9:33:04 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1370> LL/token: -8.01078
# Oct 02, 2023 9:33:05 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04822]
# Oct 02, 2023 9:33:05 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1380> LL/token: -8.01116
# Oct 02, 2023 9:33:05 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1390> LL/token: -8.00993
# Oct 02, 2023 9:33:06 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.08773	protein day like breakfast bowl morning chocolate
# 1	0.04477	healthy glutenfree wellness healthyfood foodblogger foodie healthyinspo
# 2	0.03546	body see feel way look like day
# 3	0.08772	eating recovery support us meda edrecovery disorders
# 4	0.23897	life time feel like things love know
# 5	0.03008	cup chocolate tbsp butter add flour mix
# 6	0.08792	food eating body eat weight recovery im
# 7	0.08228	guys also day vegan new one love
# 8	0.03325	recoverwithmeda edrecovery haes eatingdisorderrecovery reads meda green
#
# Oct 02, 2023 9:33:06 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04827]
# Oct 02, 2023 9:33:06 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1400> LL/token: -8.01059
# Oct 02, 2023 9:33:07 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1410> LL/token: -8.01279
# Oct 02, 2023 9:33:07 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04803]
# Oct 02, 2023 9:33:07 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1420> LL/token: -8.00918
# Oct 02, 2023 9:33:08 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1430> LL/token: -8.012
# Oct 02, 2023 9:33:09 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04842]
# Oct 02, 2023 9:33:09 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1440> LL/token: -8.01078
# Oct 02, 2023 9:33:09 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.08902	day protein like breakfast morning bowl chocolate
# 1	0.04458	healthy glutenfree wellness foodie healthyfood foodblogger healthyinspo
# 2	0.0354	body see look way feel day like
# 3	0.08765	eating recovery support us meda edrecovery disorders
# 4	0.23919	life time feel like things love know
# 5	0.02985	cup chocolate tbsp butter add flour mix
# 6	0.08739	food eating body eat weight recovery im
# 7	0.08146	guys also vegan day one new video
# 8	0.03334	recoverwithmeda haes edrecovery eatingdisorderrecovery reads meda green
#
# Oct 02, 2023 9:33:09 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1450> LL/token: -8.0098
# Oct 02, 2023 9:33:10 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04834]
# Oct 02, 2023 9:33:10 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1460> LL/token: -8.00823
# Oct 02, 2023 9:33:11 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1470> LL/token: -8.00989
# Oct 02, 2023 9:33:12 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04827]
# Oct 02, 2023 9:33:12 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1480> LL/token: -8.00964
# Oct 02, 2023 9:33:12 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1490> LL/token: -8.00992
# Oct 02, 2023 9:33:13 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.0881	day protein like breakfast morning bowl good
# 1	0.04488	healthy glutenfree wellness foodie healthyfood foodblogger healthyinspo
# 2	0.03596	body see feel look way day like
# 3	0.08764	eating recovery support us meda edrecovery disorders
# 4	0.24037	life time feel like love things know
# 5	0.0297	cup chocolate tbsp butter add flour powder
# 6	0.08721	food eating body eat weight recovery im
# 7	0.08108	guys also vegan day one new time
# 8	0.03297	recoverwithmeda haes edrecovery eatingdisorderrecovery reads meda green
#
# Oct 02, 2023 9:33:13 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04834]
# Oct 02, 2023 9:33:13 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1500> LL/token: -8.00953
# Oct 02, 2023 9:33:14 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1510> LL/token: -8.00965
# Oct 02, 2023 9:33:14 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.0482]
# Oct 02, 2023 9:33:14 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1520> LL/token: -8.00978
# Oct 02, 2023 9:33:15 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1530> LL/token: -8.01262
# Oct 02, 2023 9:33:15 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04838]
# Oct 02, 2023 9:33:15 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1540> LL/token: -8.01282
# Oct 02, 2023 9:33:16 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.0879	day protein like breakfast morning bowl cream
# 1	0.04518	healthy wellness glutenfree healthyfood foodblogger foodie healthyinspo
# 2	0.03575	body see way look feel like day
# 3	0.08715	eating recovery support us meda edrecovery disorders
# 4	0.23903	life time feel love things like know
# 5	0.03034	cup chocolate tbsp butter add flour mix
# 6	0.08682	food eating body eat weight recovery im
# 7	0.0824	guys vegan also day one new video
# 8	0.03317	recoverwithmeda haes edrecovery eatingdisorderrecovery reads meda bodyrespect
#
# Oct 02, 2023 9:33:16 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1550> LL/token: -8.0113
# Oct 02, 2023 9:33:17 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04824]
# Oct 02, 2023 9:33:17 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1560> LL/token: -8.01168
# Oct 02, 2023 9:33:18 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1570> LL/token: -8.01072
# Oct 02, 2023 9:33:19 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04835]
# Oct 02, 2023 9:33:19 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1580> LL/token: -8.01069
# Oct 02, 2023 9:33:20 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1590> LL/token: -8.01128
# Oct 02, 2023 9:33:21 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.08754	protein day like breakfast morning bowl one
# 1	0.04492	healthy glutenfree healthyfood wellness foodie foodblogger healthyinspo
# 2	0.03551	body see look way feel like day
# 3	0.0875	eating recovery support us meda edrecovery disorders
# 4	0.2402	life time feel like love things know
# 5	0.03011	cup chocolate tbsp butter add flour mix
# 6	0.08707	food eating eat body weight recovery im
# 7	0.08306	guys also day vegan one new video
# 8	0.03364	recoverwithmeda haes edrecovery eatingdisorderrecovery reads meda green
#
# Oct 02, 2023 9:33:21 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04825]
# Oct 02, 2023 9:33:21 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1600> LL/token: -8.00925
# Oct 02, 2023 9:33:21 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1610> LL/token: -8.00961
# Oct 02, 2023 9:33:22 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04824]
# Oct 02, 2023 9:33:22 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1620> LL/token: -8.00808
# Oct 02, 2023 9:33:23 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1630> LL/token: -8.0119
# Oct 02, 2023 9:33:23 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04832]
# Oct 02, 2023 9:33:23 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1640> LL/token: -8.0127
# Oct 02, 2023 9:33:24 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.08762	day protein like morning breakfast bowl chocolate
# 1	0.0454	healthy glutenfree foodie wellness foodblogger healthyfood healthyinspo
# 2	0.03631	body see way look feel like day
# 3	0.08804	eating recovery support us meda edrecovery disorders
# 4	0.24121	life time feel things love like know
# 5	0.0302	cup chocolate tbsp butter add flour mix
# 6	0.08582	food eating body eat weight recovery im
# 7	0.08159	guys also vegan day new one video
# 8	0.03334	edrecovery recoverwithmeda haes eatingdisorderrecovery meda reads green
#
# Oct 02, 2023 9:33:24 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1650> LL/token: -8.01246
# Oct 02, 2023 9:33:25 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04842]
# Oct 02, 2023 9:33:25 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1660> LL/token: -8.01164
# Oct 02, 2023 9:33:26 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1670> LL/token: -8.01305
# Oct 02, 2023 9:33:27 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04847]
# Oct 02, 2023 9:33:27 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1680> LL/token: -8.00944
# Oct 02, 2023 9:33:27 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1690> LL/token: -8.00995
# Oct 02, 2023 9:33:28 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.08761	day protein like morning breakfast good bowl
# 1	0.04583	healthy wellness glutenfree foodie healthyfood healthyinspo foodblogger
# 2	0.03571	body see look feel way like day
# 3	0.08793	eating recovery support us meda edrecovery disorders
# 4	0.24002	life time feel love things like know
# 5	0.02996	cup chocolate tbsp butter add flour mix
# 6	0.08665	food eating body eat weight recovery im
# 7	0.08164	guys also vegan day new one love
# 8	0.03359	recoverwithmeda edrecovery haes eatingdisorderrecovery reads meda green
#
# Oct 02, 2023 9:33:28 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04838]
# Oct 02, 2023 9:33:28 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1700> LL/token: -8.01101
# Oct 02, 2023 9:33:29 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1710> LL/token: -8.01022
# Oct 02, 2023 9:33:30 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04823]
# Oct 02, 2023 9:33:30 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1720> LL/token: -8.01031
# Oct 02, 2023 9:33:30 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1730> LL/token: -8.01229
# Oct 02, 2023 9:33:31 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04816]
# Oct 02, 2023 9:33:31 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1740> LL/token: -8.00977
# Oct 02, 2023 9:33:31 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.08919	day protein like morning breakfast cream bowl
# 1	0.04491	healthy wellness glutenfree foodie healthyfood foodblogger healthyinspo
# 2	0.03711	body see look feel way day like
# 3	0.0876	eating recovery support us meda edrecovery disorders
# 4	0.24278	life time feel love like things know
# 5	0.03051	cup chocolate tbsp butter add flour mix
# 6	0.08595	food eating body eat weight recovery im
# 7	0.08002	guys vegan also day new one video
# 8	0.03356	recoverwithmeda haes edrecovery eatingdisorderrecovery reads meda green
#
# Oct 02, 2023 9:33:31 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1750> LL/token: -8.01206
# Oct 02, 2023 9:33:32 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04809]
# Oct 02, 2023 9:33:32 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1760> LL/token: -8.00984
# Oct 02, 2023 9:33:33 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1770> LL/token: -8.01104
# Oct 02, 2023 9:33:33 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04824]
# Oct 02, 2023 9:33:33 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1780> LL/token: -8.00938
# Oct 02, 2023 9:33:34 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1790> LL/token: -8.0102
# Oct 02, 2023 9:33:35 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.08982	day protein like morning breakfast bowl chocolate
# 1	0.04448	healthy wellness glutenfree foodie foodblogger healthyfood healthyinspo
# 2	0.03706	body see look feel way day like
# 3	0.08818	eating recovery support us meda edrecovery disorders
# 4	0.24234	life time feel love like things know
# 5	0.03046	cup chocolate tbsp butter add flour mix
# 6	0.08509	food eating body eat weight recovery im
# 7	0.08135	guys vegan also day new one love
# 8	0.03375	recoverwithmeda haes edrecovery eatingdisorderrecovery reads meda green
#
# Oct 02, 2023 9:33:35 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04809]
# Oct 02, 2023 9:33:35 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1800> LL/token: -8.0087
# Oct 02, 2023 9:33:35 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1810> LL/token: -8.00961
# Oct 02, 2023 9:33:36 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04827]
# Oct 02, 2023 9:33:36 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1820> LL/token: -8.01122
# Oct 02, 2023 9:33:37 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1830> LL/token: -8.01055
# Oct 02, 2023 9:33:37 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04832]
# Oct 02, 2023 9:33:37 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1840> LL/token: -8.01211
# Oct 02, 2023 9:33:38 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.08853	day protein like breakfast bowl morning chocolate
# 1	0.04567	healthy wellness glutenfree foodie healthyfood foodblogger healthyinspo
# 2	0.03638	body see way feel look day like
# 3	0.08812	eating recovery support us meda edrecovery disorders
# 4	0.24173	life time feel like things love know
# 5	0.03058	cup chocolate tbsp butter add flour mix
# 6	0.086	food eating body eat weight recovery im
# 7	0.08218	guys vegan also day one new love
# 8	0.03398	recoverwithmeda edrecovery haes eatingdisorderrecovery reads meda green
#
# Oct 02, 2023 9:33:38 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1850> LL/token: -8.01045
# Oct 02, 2023 9:33:38 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04833]
# Oct 02, 2023 9:33:38 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1860> LL/token: -8.01039
# Oct 02, 2023 9:33:39 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1870> LL/token: -8.01235
# Oct 02, 2023 9:33:39 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04832]
# Oct 02, 2023 9:33:39 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1880> LL/token: -8.01054
# Oct 02, 2023 9:33:40 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1890> LL/token: -8.00969
# Oct 02, 2023 9:33:41 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.08923	day protein like one morning breakfast bowl
# 1	0.04537	healthy glutenfree wellness foodblogger healthyfood foodie healthyinspo
# 2	0.03709	body see way look feel day like
# 3	0.08829	eating recovery support us meda edrecovery disorders
# 4	0.24347	life time feel like love things know
# 5	0.03016	cup chocolate tbsp butter add flour powder
# 6	0.08613	food eating body eat weight recovery im
# 7	0.08149	guys also vegan day one new love
# 8	0.03394	edrecovery recoverwithmeda haes eatingdisorderrecovery reads meda green
#
# Oct 02, 2023 9:33:41 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04829]
# Oct 02, 2023 9:33:41 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1900> LL/token: -8.00962
# Oct 02, 2023 9:33:41 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1910> LL/token: -8.00908
# Oct 02, 2023 9:33:42 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04825]
# Oct 02, 2023 9:33:42 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1920> LL/token: -8.00941
# Oct 02, 2023 9:33:43 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1930> LL/token: -8.00954
# Oct 02, 2023 9:33:43 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04833]
# Oct 02, 2023 9:33:43 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1940> LL/token: -8.0063
# Oct 02, 2023 9:33:44 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.08912	day protein like morning breakfast bowl chocolate
# 1	0.04537	healthy glutenfree wellness foodie healthyfood healthyinspo foodblogger
# 2	0.03699	body see way look feel like day
# 3	0.08812	eating recovery support us meda edrecovery disorders
# 4	0.24369	life time feel like love things know
# 5	0.02994	cup chocolate tbsp butter add flour mix
# 6	0.08474	food eating body eat weight recovery im
# 7	0.08006	guys also vegan day one new love
# 8	0.03337	recoverwithmeda haes edrecovery eatingdisorderrecovery reads meda green
#
# Oct 02, 2023 9:33:44 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1950> LL/token: -8.00981
# Oct 02, 2023 9:33:44 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04833]
# Oct 02, 2023 9:33:44 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1960> LL/token: -8.00723
# Oct 02, 2023 9:33:45 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1970> LL/token: -8.00861
# Oct 02, 2023 9:33:45 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.0481]
# Oct 02, 2023 9:33:45 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1980> LL/token: -8.00556
# Oct 02, 2023 9:33:46 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <1990> LL/token: -8.0071
# Oct 02, 2023 9:33:47 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# 0	0.08793	day protein like breakfast morning bowl chocolate
# 1	0.04519	healthy healthyfood glutenfree wellness foodie foodblogger healthyinspo
# 2	0.03664	body see feel way look day like
# 3	0.08773	eating recovery support us meda edrecovery disorders
# 4	0.24523	life time feel like things love know
# 5	0.02963	cup chocolate tbsp butter add flour powder
# 6	0.0853	food eating body eat weight recovery im
# 7	0.07987	guys also vegan day new one love
# 8	0.03328	recoverwithmeda edrecovery haes eatingdisorderrecovery reads meda green
#
# Oct 02, 2023 9:33:47 AM cc.mallet.topics.ParallelTopicModel optimizeBeta
# INFO: [beta: 0.04828]
# Oct 02, 2023 9:33:47 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO: <2000> LL/token: -8.00762
# Oct 02, 2023 9:33:47 AM cc.mallet.topics.ParallelTopicModel estimate
# INFO:
# Total time: 2 minutes 27 seconds
# Oct 02, 2023 9:33:47 AM cc.mallet.topics.ParallelTopicModel maximize
# INFO: 0	123ms	95188	-7.799380326901279
# Oct 02, 2023 9:33:47 AM cc.mallet.topics.ParallelTopicModel maximize
# INFO: 1	204ms	17984	-7.78325574172071
# Oct 02, 2023 9:33:47 AM cc.mallet.topics.ParallelTopicModel maximize
# INFO: 2	63ms	8144	-7.778017159539424
# Oct 02, 2023 9:33:47 AM cc.mallet.topics.ParallelTopicModel maximize
# INFO: 3	61ms	4687	-7.775487832601222
# Oct 02, 2023 9:33:47 AM cc.mallet.topics.ParallelTopicModel maximize
# INFO: 4	47ms	3426	-7.773790144366083
# Oct 02, 2023 9:33:47 AM cc.mallet.topics.ParallelTopicModel maximize
# INFO: 5	48ms	2630	-7.772702540064503
# Oct 02, 2023 9:33:47 AM cc.mallet.topics.ParallelTopicModel maximize
# INFO: 6	45ms	2098	-7.771834371270797
# Oct 02, 2023 9:33:47 AM cc.mallet.topics.ParallelTopicModel maximize
# INFO: 7	45ms	1830	-7.770991927531918
# Oct 02, 2023 9:33:47 AM cc.mallet.topics.ParallelTopicModel maximize
# INFO: 8	45ms	1937	-7.770006776211054
# Oct 02, 2023 9:33:47 AM cc.mallet.topics.ParallelTopicModel maximize
# INFO: 9	52ms	2025	-7.768891024611358
# Oct 02, 2023 9:33:48 AM cc.mallet.topics.ParallelTopicModel maximize
# INFO: 10	46ms	1901	-7.767746682594226
# Oct 02, 2023 9:33:48 AM cc.mallet.topics.ParallelTopicModel maximize
# INFO: 11	44ms	1482	-7.7667121335135425
# Oct 02, 2023 9:33:48 AM cc.mallet.topics.ParallelTopicModel maximize
# INFO: 12	44ms	1134	-7.7658262452286
# Oct 02, 2023 9:33:48 AM cc.mallet.topics.ParallelTopicModel maximize
# INFO: 13	44ms	954	-7.765091504981613
# Oct 02, 2023 9:33:48 AM cc.mallet.topics.ParallelTopicModel maximize
# INFO: 14	46ms	805	-7.76431692111999
# Oct 02, 2023 9:33:48 AM cc.mallet.topics.ParallelTopicModel maximize
# INFO: 15	64ms	890	-7.763419825398515
# Oct 02, 2023 9:33:48 AM cc.mallet.topics.ParallelTopicModel maximize
# INFO: 16	50ms	657	-7.762692486199836
# Oct 02, 2023 9:33:48 AM cc.mallet.topics.ParallelTopicModel maximize
# INFO: 17	108ms	527	-7.76223047427931
# Oct 02, 2023 9:33:48 AM cc.mallet.topics.ParallelTopicModel maximize
# INFO: 18	49ms	390	-7.761957877970198
# Oct 02, 2023 9:33:48 AM cc.mallet.topics.ParallelTopicModel maximize
# INFO: 19	44ms	336	-7.761719178380691
# Oct 02, 2023 9:33:48 AM cc.mallet.topics.ParallelTopicModel maximize
# INFO: 20	44ms	223	-7.761602469362978
# Oct 02, 2023 9:33:48 AM cc.mallet.topics.ParallelTopicModel maximize
# INFO: 21	46ms	161	-7.761524269615211
# Oct 02, 2023 9:33:48 AM cc.mallet.topics.ParallelTopicModel maximize
# INFO: 22	44ms	91	-7.761453657499028
# Oct 02, 2023 9:33:48 AM cc.mallet.topics.ParallelTopicModel maximize
# INFO: 23	48ms	59	-7.7614163135995025
# Oct 02, 2023 9:33:48 AM cc.mallet.topics.ParallelTopicModel maximize
# INFO: 24	44ms	65	-7.761387796434566
# Oct 02, 2023 9:33:48 AM cc.mallet.topics.ParallelTopicModel maximize
# INFO: 25	49ms	38	-7.761361420863982
# Oct 02, 2023 9:33:48 AM cc.mallet.topics.ParallelTopicModel maximize
# INFO: 26	44ms	7	-7.761353441769918
# Oct 02, 2023 9:33:48 AM cc.mallet.topics.ParallelTopicModel maximize
# INFO: 27	44ms	7	-7.761343495696195
# [1] "Training complete."
# Oct 02, 2023 9:33:48 AM cc.mallet.topics.ParallelTopicModel maximize
# INFO: 28	47ms	2	-7.761337435602953
# Oct 02, 2023 9:33:49 AM cc.mallet.topics.ParallelTopicModel maximize
# INFO: 29	43ms	2	-7.76133658553934
# Oct 02, 2023 9:33:49 AM cc.mallet.topics.ParallelTopicModel maximize
# INFO: 30	43ms	0	-7.76133658553934

# %%
import seaborn as sns
df = pd.DataFrame(npmis,columns=['n_topics','npmi_average'])
sns.lineplot(data=df,x='n_topics',y='npmi_average')
# Out:
# <Axes: xlabel='n_topics', ylabel='npmi_average'>

# %% [markdown]
# # Post-processing

# %% [markdown]
# topic distribution and topic selection
#
# for topic selection I used elbow method (selecting top topics till we get to the highest gap)

# %%
#topic selection
topics4docs,topics4docs_bin = topic_selection(topic_doc_dist)

#topic distribution addition
for i in range(topic_doc_dist.shape[1]):
    text_df['Topic{0}_dist'.format(i)] = topic_doc_dist[:,i]
#topic selection addition
for i in range(topic_doc_dist.shape[1]):
    text_df['Topic{0}_select'.format(i)] = topics4docs_bin[:,i]

#saving data to csv
text_df.to_csv('document_topic_info.csv')

# %% [markdown]
# Generating topic_frame.csv for Topicalzier
#
# Columns: id (no header), topic_i (top_10 terms), year
# values: nothing (this will be saved automatically), topic dist, date

# %%
#topic selection
topics4docs,topics4docs_bin = topic_selection(topic_doc_dist)
df = text_df[['date']].copy()

#topic distribution addition
for i in range(topic_doc_dist.shape[1]):
    df['_'.join(top_terms[i].split(' ')[0:10])] = topic_doc_dist[:,i]

#setting date as the last columns
df = df[list(df.columns)[1:]+['date']].reset_index()

#saving data to csv
df.to_csv('./data/topic_frame.csv')

# %%
#storing top terms
topic_df = pd.DataFrame(data=top_terms,columns=['top_terms'])
topic_df.to_csv('topic_terms.csv')

# %% [markdown]
# Running Coherence

# %%
from lda_mallet import lda_score
import pickle

# import importlib
# importlib.reload(scorer.score_per_topic(None))

#initiate scorer
scorer = lda_score(wiki_path='./data/wiki_sampled_5p.txt',db_path='./data/wiki_full/')

'''
loading wikipedia vocab to 
    1. remove the top terms that are not in the wikipedia
    2. use for gensim.coherence vocab argument in case any pairs are not in the DB
'''
with open('./data/wiki_sampled5p_vocab.obj','rb') as f:
    scorer.wiki_vocab_dict = pickle.load(f)
    
#add all_top_terms (except the ones that are not in the wiki_pedia vocab)
scorer.all_top_terms = [[t for t in top_terms[i].split() if t in scorer.wiki_vocab_dict.token2id.keys()] for i in range(len(top_terms))]
#the output is a dictionary: the key is 0-n_topics and associated with npmi score for top-k topics 
#in which k=5,10,15,20
topic_scores = scorer.score_per_topic(None)
#getting avergae of multiple k for each topic
topic_score_avg = [np.mean([vi for ki,vi in v.items()]) for k,v in topic_scores.items()]
# Out:
# Load NPMI coherence DB.
# Number of keys : 1934666
# skipping 0 missed term-pairs < allowed misses = 0.05

# %% [markdown]
# # soring top terms and top documents (as a text file)

# %%
show_top_doc = 10
show_top_terms = 10
file_name = 'top_documents_lda9_no_dups.txt'

#writing the results in a text file
with open(file_name,'w') as tfile:
    for i in range(len(top_terms)):
        #writing top terms
        tfile.write('Topic '+ str(i) + ' : '+'\n'+'top terms: '+', '.join(top_terms[i].split()[:show_top_terms])+'\n')
        #selecting top documents
        top_docs = text_df.sort_values('Topic{0}_dist'.format(i),ascending=False).iloc[0:show_top_doc,:]
        for _,row in top_docs.iterrows():
            tfile.write('Doc ID: {0}, distribution: {1} ; {2} \n'.format(row.id,row['Topic{0}_dist'.format(i)],row['original_text']))
            tfile.write(''.join(['-']*60)+'\n')

# %% [markdown]
# # Storing topic_description for topicalizer
#
# columns: id (no header), coherence, word_i , freq_i
# values: id of the topic, coherence_value, top_term i for topic id, probability of the term

# %%
desc = []

for i in range(len(top_terms)):
    d = {}#adding everything to a dictionary
    d['coherence'] = topic_score_avg[i]
    #extracting top terms and their probabilities
    topic_top_terms = top_terms[i].split()
    #the probability of each term
    probs = [float(term_probab[i][j]) for w in topic_top_terms for j in range(len(topic_vocab)) if w == topic_vocab[j]]
    #adding top terms and probabilities to the dict
    for j in range(10):
        d['word_{0}'.format(j+1)] = topic_top_terms[j]
        d['freq_{0}'.format(j+1)] = probs[j]

    #storing details of this topic
    desc.append(d)

#convert to a df
pd.DataFrame(desc).to_csv('./data/topic_description.csv')

# %% [markdown]
# # Storing to DB

# %% [markdown]
# The process is described in the code cell below
#
# **Used the link below to insert and load blob**
#
# https://pynative.com/python-mysql-blob-insert-retrieve-file-image-as-a-blob-in-mysql/

# %%
#1. save model id (for LDA save as zip and then save)
'''
2. for each topic
    3. save topic
    4. retreive the saved topic_id and save r_topic_model
    5. for each doc save r_topic_post
'''
###table format
#model: model_id, data, model_type, last_used?
# topic: topic_id, coherence, term1-50, probab1-50
#r_topic_model: topic_id, model_id 
#r_topic_post: topic_id, post_id, proportion

##check the columns of a table
# cursor.execute("show columns from r_topic_post") #execute a command
# myresult = cursor.fetchall() #get all the results 
# myresult
# Out:
# '\n2. for each topic\n    3. save topic\n    4. retreive the saved topic_id and save r_topic_model\n    5. for each doc save r_topic_post\n'

# %%
#saving the model first
#model: model_id, data, model_type, last_used?
if model_spec['name'].lower() == 'lda':
    #read binary data of the saved model
    with open('MalletState_ '+model_spec['save_path']+' .gz','rb') as model_file:
        binary_data = model_file.read()
else:
    pass #write codes for other models

#storing the model
cursor.execute(" INSERT INTO model (data, model_type) VALUES (%s,%s)",
                    (binary_data,model_spec['name']))

# %%
#load the model with model id to use for next steps
cursor.execute("Select * from model ORDER BY model_id DESC LIMIT 1")
result = cursor.fetchall()
model_id,model_name = result[0][0],result[0][2]

# %%
#saving each topic separately alongside relation to model table and post table
for k in range(0,model_spec['K']):#iterating over each topic
    #getting topic top terms
    topic_top_terms = top_terms[k].split()
    #we have to find the index in vocab (ans[0][2]) and then call ans[0][1][k][found_index] to get
    #the probability of each term
    probab = [float(term_probab[k][i]) for w in topic_top_terms for i in range(len(topic_vocab)) if w == topic_vocab[i]]
    #adding coherence score, top terms and their probabilities
    vals = tuple([float(topic_score_avg[k])]) + tuple(topic_top_terms) + tuple(probab)
    #save each topic seperately
    cursor.execute(" INSERT INTO topic(coherence,{0},{1}) VALUES (%s,{2})".format(
                                        ','.join(['term'+str(i) for i in range(1,len(topic_top_terms)+1)]),
                                        ','.join(['prob'+str(i) for i in range(1,len(topic_top_terms)+1)]),
                                        ','.join(['%s']*(len(topic_top_terms)*2))),vals)
    
    '''
    retreiving saved topic_id and save an entry for topic_id,model_id in topic_model_r table
    '''
    #load the latest stored topic
    cursor.execute("Select * from topic ORDER BY topic_id DESC LIMIT 1")
    result = cursor.fetchall()
    topic_id = result[0][0]
    #save the topic_id,model_id in r_topic_model table 
    cursor.execute(" INSERT INTO r_topic_model(topic_id,model_id) VALUES (%s,%s)",
                  (topic_id,model_id,))
    
    '''
    saving topic-document proportion for each topic-doc pairs
    '''
    #r_topic_post : topic_id, post_id, proportion
    doc_counter = 0
    for doc_id in list(text_df.id):
        cursor.execute(" INSERT INTO r_topic_post(topic_id,post_id,proportion) VALUES (%s,%s,%s)",
                  (topic_id,doc_id,float(topic_doc_dist[doc_counter,k])))
        doc_counter += 1

# %%
cnx.commit()

# %%
# cursor.execute("delete from r_topic_model")
# cursor.execute("delete from r_topic_post")
# cursor.execute("delete from topic")
# cursor.execute("delete from model")

# cursor.execute("select * from post")
# cursor.execute("SELECT DISTINCT user.* FROM user JOIN post ON user.user_id = post.user_id WHERE post.platform_type_id = %s",('4',))
# cursor.execute("SELECT * FROM post WHERE user_id = %s AND created BETWEEN %s AND %s;",(3,'1/1/2023','1/1/2013',))
# cursor.execute("SELECT r_topic_post.topic_id, AVG(r_topic_post.proportion) as average_proportion FROM r_topic_post JOIN r_topic_model ON r_topic_post.topic_id = r_topic_model.topic_id WHERE r_topic_post.post_id = %s AND r_topic_model.model_id = %s GROUP BY r_topic_post.topic_id;",('1187','2',))
# cursor.execute('select * from model')
cursor.fetchall()
# Out:
# [(11, Decimal('0.005300000')),
#  (12, Decimal('0.223030000')),
#  (13, Decimal('0.002400000')),
#  (14, Decimal('0.007130000')),
#  (15, Decimal('0.005350000')),
#  (16, Decimal('0.012220000')),
#  (17, Decimal('0.006210000')),
#  (18, Decimal('0.005680000')),
#  (19, Decimal('0.004940000')),
#  (20, Decimal('0.727740000'))]
