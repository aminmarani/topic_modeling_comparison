# %% [markdown]
# # topic modeling pipeline
#
# This notebook will walk you through:
# 1. data reterival from SQL database
# 2. Pre-processing data
# 3. Running topic modeling (different models)
# 4. post processing (including showing topics, topic-doc distribution, etc.)
# 5. Storing results into DB

# %% [markdown]
# # imports

# %%
from pre_processing import remove_html_tags, preprocess_data, prepare_corpus
from pre_processing import transition_labeling
from post_processing import topic_selection, date2days, topic_terms_bert
# from rpy2 import robjects #loading R inside Python
#importing functions to read pandas DF
# from rpy2.robjects import pandas2ri
# pandas2ri.activate()
# from rpy2.robjects.packages import importr
# from rpy2.robjects.conversion import localconverter

import pandas as pd

import numpy as np

import os

# from bertopic import BERTopic
# from bertopic.representation import KeyBERTInspired

from scholar.file_handling import save_sparse
import scipy.sparse as sp


import json
import subprocess


#import R base library
# base = importr('base')

mallet_path = 'mallet' #'mallet for mac-os
# Out:
# [nltk_data] Downloading package stopwords to /home/amh418/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/amh418/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/amh418/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/amh418/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# loading stop words

# %%
#downloading github repo for down-sampling==> you only need this once!
# !git clone https://github.com/aminmarani/authorless-tms.git

# %%
stop_words = []

with open('freqPOS+Names.stop','r') as txtfile:
    for r in txtfile:
        stop_words.append(r.strip())
        if "'" in r:#add the term without "'"; e.g., haven't & havent
            stop_words.append(r.replace("'","").strip())

#adding the selected stop_words
stop_words.extend(['go','going','got','want','time','really','good','life','let','even','get',
                  'always','answer','back','day','feel','love','need','never','people',
                  'question','right','see','still','things','today','way','week'])

stop_words[10:15]
# Out:
# ['duncan', 'fluffy', 'jack', 'jake', 'jim']

# %% [markdown]
# # Loading data from SQL database
#
# First creating a connection
#
# **In order to create a connection from anywhere in LU network you need to run the command below in terminal. Replace your username with amh418 in the command below.**
#
# ssh -L 3306:127.0.0.1:3306 -N -f amh418@128.180.111.76   #it will ask for lehigh pass
#
# on network (128.180.111.76)
# outside the network (ssh.lehigh.edu)
#
# **if you need to kill to SSH forwarding use the link below**
#
# https://superuser.com/questions/87014/how-do-i-remove-an-ssh-forwarded-port

# %%
import mysql.connector

#connecting to DB
cnx = mysql.connector.connect(user='push', password='ElI)g!LDOBIwM)%*5o5{dbfz('
                              ,host='127.0.0.1',database='edml')

# %% [markdown]
# Retreiving all the posts
#
# **We are exlcuding recoverwithmeda for now**

# %%
cursor = cnx.cursor() #making a cursor to execute a SQL command
# cursor.execute("select * from post") #execute a command
cursor.execute("select * from post where user_id != (select user_id from user where user_login='recoverwithmeda')") #execute a command
myresult = cursor.fetchall() #get all the results 
print('{0} posts were retreived'.format(len(myresult)))
# Out:
# 8341 posts were retreived

# %%
#loading user_id and user_name to convert id to user_name
cursor.execute("select * from user") #execute a command
users = cursor.fetchall() #get all the results 
users = {i[0]:i[1] for i in users}
myresult = [i[0:2] + tuple([users[i[2]]]) + i[3:] for i in myresult]

# %%
#concatenating the old dataset to the new one
last_id = max([i[0] for i in myresult])+1
myresult_ = [tuple([i[1]+last_id]+list(i[2:])) for i in pd.read_csv('./data/old_ed.csv',index_col=None).values]
myresult += myresult_
print('{0} posts were retreived'.format(len(myresult)))
# Out:
# 21338 posts were retreived

# %% [markdown]
# Language detection
#
# keeping only English language posts/documents

# %%
from langdetect import detect
from tqdm import tqdm


# myresult = [s for s in myresult if len(remove_html_tags(s[3])) > 3 and detect(remove_html_tags(s[3]))=='en']
t = []
#removing tags and detecting language afterward
for s in tqdm(myresult):
    try:#in some case language detection may fail (emojies only, one word docs, etc.) ==> We don't keep those
        if detect(remove_html_tags(s[3]))=='en':
            t.append(s)
    except:
        pass #do nothing

myresult = t[:]
print('after removing non-english posts,the size of the documents are: {0}'.format(len(myresult)))
# Out:
# 100%|██████████| 21338/21338 [02:07<00:00, 166.97it/s]
# after removing non-english posts,the size of the documents are: 17329

# %% [markdown]
# # preprocessing the data
#
# First, removing html tags

# %% [markdown]
# prepare the corupus

# %%
import re

#removing tags from texts 
proc_texts = [remove_html_tags(i[3]) for i in myresult]
#remvoing post that  include tree_htem
proc_texts = [re.sub(r"\{'comment'.*?\}",'',i) if "tree_html" in i else i for i in proc_texts]
#pre_processing and tokenizing docs
pre_processed_docs,orig_docs = preprocess_data(proc_texts,extra_stopwords=stop_words)
#attaching (id,original_text,pre_processed_text,date,url) together
id_text = [(myresult[orig_docs[i][1]][0],orig_docs[i][0],pre_processed_docs[i],
            myresult[orig_docs[i][1]][4],myresult[orig_docs[i][1]][5],
            myresult[orig_docs[i][1]][2]) for i in range(len(orig_docs))]

# vocab_dict, doc_term_matrix = prepare_corpus(pre_processed_docs) ==> we don't need prepare corpus as we are passing this to LDA and STM R and there they will do tokenization 

#creat a pandas DF with one column as text, one column as original text, one column as SQL post-id, etc.
text_df = pd.DataFrame(zip([i[0] for i in id_text],[' '.join(i[2]) for i in id_text],
                           [i[1] for i in id_text],[i[3] for i in id_text],[i[4] for i in id_text],
                          [i[5] for i in id_text]),
                       columns=['id','text','original_text','date','url','blog'])

# %%
#removing duplicates only if necessary
print(len(text_df))
text_df = text_df.drop_duplicates(subset=['text'])
print(len(text_df))
# Out:
# 14052
# 13358

# %% [markdown]
# # Term Frequency
#
# Term frequency and Term/doc frequency
#
# **This is only analysis we already add stop words from these anlaysis to stop_words defined above**

# %%
import collections

#extracting uni-grams
terms = []
for s in list(text_df.text):
    terms.extend(s.split())

#computing frequency of each term
freqs = collections.Counter(terms)
sorted(freqs.items(),key= lambda x:x[1],reverse=True )[0:10]
# freqs
# Out:
# [('body', 3618),
#  ('eating', 3424),
#  ('food', 2996),
#  ('eat', 2528),
#  ('cup', 2433),
#  ('chocolate', 1699),
#  ('new', 1601),
#  ('take', 1582),
#  ('work', 1548),
#  ('last', 1514)]

# %%
#terms-document proportion
term_doc = {k:0 for k,v in freqs.items() if v>len(text_df)*0.05}

#compute term_doc
for s in list(text_df.text):
    for k in term_doc.keys():
        if k in s.split():
            term_doc[k]+=1

# %%
#terms that appear in 20% or more of documents
candids = {k:v for k,v in term_doc.items() if v>=len(text_df)*0.10}
set(candids.keys())
# selected_stop_words = set(candids.keys())
# selected_stop_words
# Out:
# {'body', 'eat', 'eating', 'food'}

# %% [markdown]
# # Blog distribution

# %%
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt

blog_dist = Counter(list(text_df.blog))
sns.barplot(x=list(blog_dist.keys()),y=list(blog_dist.values()))
a = plt.xticks(rotation=30,ha='right') 
# list(blog_dist.values())

# %% [markdown]
# Processing documens for Topicalizer

# %%
# text_df[['date','original_text','url']].rename(columns={'original_text':'entry','url':'Link'}).to_csv('./data/processed_ed.csv')

# %% [markdown]
# # Author down-sampling
#
# down-sampling terms that are more specific to an author

# %%
# vocab = set()

# for tx in list(text_df.text):
#     tokens = tx.split()
#     [vocab.add(t) for t in tokens]

# with open('./data/temp_vocab_corpus.txt','w') as tfile:
#     tfile.writelines([i+'\n' for i in list(vocab)])

# print('size of dictionary is {0}'.format(len(vocab)))

# %%
# #storing corpus for down-sampling (we send the pre-processed docs)
# text_df[['blog','text']].to_csv('./data/temp_documents_corpus.txt',index=True,sep='\t',
#                                 header=False,encoding="UTF-8")

# %%
# #running down-sampling ==> if the original file in repo pops error you need to make changes in the downsample_corpus.py as stated below
# #line 68: term_means = np.mean(author_term_freqs, axis=0).ravel() 
# #line 71: term_vars = np.var(author_term_freqs, axis=0, ddof=1).ravel()
# #line 83: author_term_freqs = author_term_freqs.toarray()#added 2023,Nov
# #line 88: author_freqs = author_term_freqs[:, term_id].ravel()#.getA1() #added 2023,Nov
# !python3 ./authorless-tms/downsample_corpus.py --input ./data/temp_documents_corpus.txt --output ./data/temp_documents_corpus_new003.txt --vocab ./data/temp_vocab_corpus.txt --threshold 0.03

# %% [markdown]
# # loading from down-sampled dataset

# %%
# #updating text_df
# new_df = pd.read_csv('./data/temp_documents_corpus_new005.txt',sep='\t',header=None,
#                      names=['id','blog','text'])

# #replacing down-sampled data with original data
# for id,row in tqdm(new_df.iterrows()):
#     text_df.loc[text_df.id==id,'text'] = row['text']
#     # text_df.at[int(id),'text'] = row['text']

# #removing the ones that were deleted during down-sampling
# text_df = text_df[text_df.id.isin(new_df.id)]

# print('Number of documents after down-sampling: {0}'.format(len(text_df)))

# %% [markdown]
# # Running topic modeling (with or without evaluation)

# %%
# from rpy2.robjects.packages import importr
# utils = importr('utils')

# utils.install_packages('stm',repos="https://cloud.r-project.org")

# %%
#prevalence (use/non-use)

#converting to date format
# text_df.date = pd.to_datetime(text_df.date)
# days = date2days(text_df)

# labels = transition_labeling(days)

# text_df['prevalence'] = ""
# for id,label in labels.items():
#     text_df.loc[text_df.id==id,'prevalence'] = label

# prevalence Author (blog)
text_df['prevalence'] = text_df['blog']



#content (instagram-tumbler)

source = ['tumblr' if 'tumblr' in str(i) else 'instagram' for i in list(text_df.url) ]
text_df['content'] = source

# %%
# from inspect import signature

# min_topic_size=10 or #min_cluster_size

# %%
from lda_mallet import lda_score
import pickle

is_eval = True #not evaluating the model
lon,upn = 5,41 #lowwer and upper topic number for evaluation
#need to provide number of topics and other specification
# model_spec = {'name':'LDA','K':16,'epochs':3500,'burnin_iteration':150,'after_iteration_burnin':50,
             # 'save_flag':True,'save_path':'LDA_test','alpha_sum':30.0}#burnin_iteration=20,after_iteration_burnin=50
stm_lda_epochs = 50  #increase lda nits
stm_lda_burnin = 150
# model_spec = {'name':'STM','K':16,'epochs':500,'prevalence':'prevalence','content':'content','pre_trained_model': 'LDA',\
#                 'burnin_iteration':stm_lda_burnin if stm_lda_epochs>stm_lda_burnin else stm_lda_epochs-1,\
#               'LDA_epochs':stm_lda_epochs,'alpha':30,'save_flag':False}

# model_spec = {'name':'bertopic','K':12,'min_cluster_size':50,'min_topic_size':40,'save_flag':False}
model_spec = {'name':'scholar','K':12,'output_dir':'./result/scholar_output/','save_flag':False}

if model_spec['name'] == 'LDA':
    if is_eval:
        #loading LDA mallet evaluation score
        from gensim.corpora import Dictionary
        from pre_processing import prepare_corpus
        #creating data vocab
        dict = Dictionary([i.split() for i in list(text_df.text)])
        #saving it to pass it to score object
        with open ('./data/ED_vocab.obj','wb') as vfile:
            pickle.dump(dict,vfile)
        wiki_vocab_dict_path = './data/wiki_sampled5p_vocab.obj'
        with open ('./data/wiki_sampled5p_vocab.obj','rb') as vfile:
            wiki_vocab_dict = pickle.load(vfile)


        npmis = []
        for n_topics in range(lon,upn,1):
            #removing terms that are not in the Wiki Vocab
            #pre_processing and tokenizing docs
            # pre_processed_docs,_ = preprocess_data(list(text_df.text),extra_stopwords=\
            #                                                set(dict.values()).difference(set(wiki_vocab_dict.values()))\
            #                                        .union(['denying']))
            pre_processed_docs,_ = preprocess_data(list(text_df.text))
            #preparing corpus
            vocab_dict,doc_term_mat = prepare_corpus(pre_processed_docs)
            #temp save of vocab file
            with open ('./data/ED_vocab.tmp','wb') as vfile:
                pickle.dump(vocab_dict,vfile)
            
            scorer = lda_score(num_topics=n_topics,alpha=10,optimize_interval=10,iterations=2000,wiki_path='./data/wiki_sampled_5p.txt',
                      db_path = './data/wiki_full/',vocab_dict_path = './data/ED_vocab.tmp', 
                      wiki_vocab_dict_path=wiki_vocab_dict_path,npmi_skip_threshold=0.30)
            
            scorer.fit(doc_term_mat)#fitting an LDA Mallet
            npmis.append([n_topics,scorer.score()])
    else: 
        #removing previously created mallet_file
        try:
            os.remove('MalletInstance_ {0}'.format(model_spec['save_path'])) 
            os.remove('MalletState_ {0} .gz'.format(model_spec['save_path']))
            os.remove('MalletSpec_ {0}'.format(model_spec['save_path']))
        except:#in case we don't have any files
            pass
        robjects.r.source('LDA_R.R')
        copy_text_df = text_df.copy()
        ans = robjects.r.findTopics(docs = copy_text_df,n_topics = model_spec['K'],epochs = model_spec['epochs'],
                                    burnin_iteration = model_spec['burnin_iteration'],
                                    after_iteration_burnin =  model_spec['after_iteration_burnin'],
                                    save_flag=model_spec['save_flag'],alpha_sum=model_spec['alpha_sum'],
                                    save_path = model_spec['save_path'])
        top_terms = np.asarray(ans[1])
        topic_doc_dist = np.asarray(ans[0][0]).T
        term_probab = ans[0][1]
        topic_vocab = ans[0][2]
        
        
elif model_spec['name'] == 'STM':
    #loading STM.R
    robjects.r.source('stm.R')
    
    if is_eval:
        
        npmis = []
        for n_topics in range(lon,upn,1):
            print('\n\nRunning STM with {0} topics and other details as below:'.format(n_topics))
            print({k:v for k,v in model_spec.items() if k != 'K'})
            #running STM
            ans = robjects.r.run_stm(docs = text_df[['id','text','prevalence','content']],topic_n=n_topics,max_itr=model_spec['epochs'],
                                 prevalence=model_spec['prevalence'],content=model_spec['content'],
                                 model_type = model_spec['pre_trained_model'],nits = model_spec['LDA_epochs'],
                                 burnin = model_spec['burnin_iteration'],alpha=model_spec['alpha'],
                                 save_flag = False)
            #initializing scorer
            scorer = lda_score(num_topics=n_topics,alpha=-1,optimize_interval=-1,iterations=-1,wiki_path='./data/wiki_sampled_5p.txt',
                      db_path = './data/wiki_full/',vocab_dict_path = './data/ED_vocab.tmp', 
                      wiki_vocab_dict_path='./data/wiki_sampled5p_vocab.obj',npmi_skip_threshold=0.30)
            #setting vocabulary of wikipedia
            with open ('./data/wiki_sampled5p_vocab.obj','rb') as vfile:
                wiki_vocab_dict = pickle.load(vfile)
            scorer.wiki_vocab_dict = wiki_vocab_dict
            #extracting top terms
            top_terms = [[str(i) for i in ls if i in scorer.wiki_vocab_dict.token2id.keys()][0:20] \
             for ls in np.asarray(ans[1]).reshape(n_topics,50,order='F')]
            scorer.all_top_terms = top_terms
            #save the NPMI
            npmis.append([n_topics,scorer.score()])
            
    else: 
        ans = robjects.r.run_stm(docs = text_df[['id','text','prevalence','content']],topic_n=model_spec['K'],max_itr=model_spec['epochs'],
                                 prevalence=model_spec['prevalence'],content=model_spec['content'],
                                 model_type = model_spec['pre_trained_model'],nits = model_spec['LDA_epochs'],
                                 burnin = model_spec['burnin_iteration'],alpha=model_spec['alpha'],
                                 save_flag = True)
        #converting outputs to readable values
        outs = dict(zip(ans[0].names, list(ans[0])))
        beta = dict(zip(outs['beta'].names, list(outs['beta'])))
        #extracting information from STM
        top_terms = [' '.join(s) for s in np.asarray(ans[1]).reshape(model_spec['K'],50,order='F')]
        topic_doc_dist = outs['theta']
        term_probab = np.exp(beta['logbeta'][0])
        topic_vocab = outs['vocab']
        ids = pd.DataFrame(ans[2]).T[0]#ids of the remaini
        text_df = text_df[text_df.id.isin(ids)]
        
elif model_spec['name'] == 'bertopic':
    #you have to set the representation top terms to the number you'd like to see as top terms
    representation_model = KeyBERTInspired(top_n_words=50) 
    docs = text_df.original_text
    #         docs = text_df.text
    if is_eval:
        npmis = []
        for n_topics in range(lon,upn,1):
            print('\n\nRunning BERTopic with {0} topics and other details as below:'.format(n_topics))
            print({k:v for k,v in model_spec.items() if k != 'K'})
            npmi_runs = []
            for _ in range(2): #two runs and then average
                #running bertopic
                from hdbscan import HDBSCAN
                hdbscan_model = HDBSCAN(min_cluster_size=model_spec['min_cluster_size'],prediction_data=True)
                topic_model = BERTopic(nr_topics=n_topics,calculate_probabilities=True,verbose=True,
                           top_n_words=50,representation_model=representation_model,
                                      min_topic_size=model_spec['min_topic_size']).fit(docs)#hdbscan_model=hdbscan_model
                #initializing scorer
                scorer = lda_score(num_topics=n_topics,alpha=-1,optimize_interval=-1,iterations=-1,wiki_path='./data/wiki_sampled_5p.txt',
                          db_path = './data/wiki_full/',vocab_dict_path = './data/ED_vocab.tmp', 
                          wiki_vocab_dict_path='./data/wiki_sampled5p_vocab.obj',npmi_skip_threshold=0.30)
                #setting vocabulary of wikipedia
                with open ('./data/wiki_sampled5p_vocab.obj','rb') as vfile:
                    wiki_vocab_dict = pickle.load(vfile)
                scorer.wiki_vocab_dict = wiki_vocab_dict
                #extracting top terms
                top_terms = []
                for ls in list(topic_model.get_topic_info().Representation):
                    res = []
                    for i in ls:
                        res.extend([j for j in i.split() if j not in res and j in scorer.wiki_vocab_dict.token2id.keys()])
                    top_terms.append(res[0:20])
    #             top_terms = [[str(i) for i in ls if i in scorer.wiki_vocab_dict.token2id.keys()][0:20] \
    #              for ls in list(topic_model.get_topic_info().Representation)]
    #             top_terms = [' '.join(i) for i in list(topic_model.get_topic_info().Representation)]
                scorer.all_top_terms = top_terms
                #save the NPMI
                if len(top_terms) == n_topics:
                    npmi_runs.append(scorer.score())
            npmis.append([n_topics,np.mean(npmi_runs)])
            
    else:
        topic_model = BERTopic(nr_topics=model_spec['K'],calculate_probabilities=True,verbose=True,
                       top_n_words=50,representation_model=representation_model).fit(docs)
        top_terms = [' '.join(i) for i in list(topic_model.get_topic_info().Representation)]
#         topic_doc_dist = np.array([i/np.sum(i) for i in topic_model.probabilities_])
        topic_doc_dist = np.array([[1.0-np.sum(i)]+list(i) for i in topic_model.probabilities_])
        #getting representative documents
        documents = pd.DataFrame({"Document": docs,
                          "ID": range(len( text_df)),
                          "Topic": topic_model.topics_})
        repr_docs, _, _,_ = topic_model._extract_representative_docs(c_tf_idf=topic_model.c_tf_idf_,
                                                          documents=documents,
                                                          topics=topic_model.topic_representations_ ,
                                                          nr_repr_docs=50)
        term_probab = topic_terms_bert(topic_model,len(top_terms)-1)
        topic_vocab = None
              
elif model_spec['name'] == 'scholar':
    #data preparation
    pre_processed_docs,_ = preprocess_data(list(text_df.text))
    vocab_dict,doc_term_mat = prepare_corpus(pre_processed_docs)
    #1. train.npz: a sparse matrix of document word counts (n_documents x vocab_size)
    doc_term_np = np.zeros((len(doc_term_mat), len(vocab_dict)))#making an empty np array
    for i,d in enumerate(doc_term_mat):#filling np array with doc_term_mat
        for id_,cnt_ in d:
            doc_term_np[i,id_] = cnt_
    #saving the np matrix as a sparse matrix
    save_sparse(sp.lil_matrix(doc_term_np, shape=doc_term_np.shape),'./data/train.npz')
    #2. train.vocab.json: a list containing the words in the vocabulary in the same order as 
    #the columns of the matrix in train.npz
    with open('./data/train.vocab.json', 'w') as f:
        json.dump([i for i in vocab_dict.values()], f)          
    #3. train.<label/covar>.csv: A .csv file for each label or covariate, where <label/covar> is the corresponding name. 
    #3.1. author
    author2id = {author:i for i,author in enumerate(set(text_df['blog']))}
    pd.DataFrame({'id':np.arange(len(text_df['blog'])),'author':[author2id[i] for i in list(text_df.blog)]}).to_csv('./data/train.author.csv',index=None)
    #3.2. platform
    platform2id = {platform:i for i,platform in enumerate(set(text_df['content']))}
    pd.DataFrame({'id':np.arange(len(text_df['content'])),'platform':[platform2id[i] for i in list(text_df.content)]}).to_csv('./data/train.platform.csv',index=None)
    #3.3. platform + author
    pl_auth = [platform2id[i]*10+author2id[j] for i,j in zip(list(text_df.content),list(text_df.blog))]
    pd.DataFrame({'id':np.arange(len(text_df['content'])),'pl_auth':pl_auth}).to_csv('./data/train.pl_auth.csv',index=None)
    
    
    
    #4. doc_id
    with open('./data/train.ids.json', 'w') as f:
        json.dump([i for i in range(len(text_df))], f)
              
    #evaluation
    if is_eval:
        npmis = []
        for n_topics in range(lon,upn,1):
            print('\n\nRunning SCHOLAR with {0} topics and other details as below:'.format(n_topics))
            print({k:v for k,v in model_spec.items() if k != 'K'})
            npmi_runs = []
            for _ in range(2): #two runs and then average
                #running SCHOLAR
                subprocess.run(["python", "./scholar/run_scholar.py","./data/","-k {0}".format(n_topics),
                                "-o","{0}".format(model_spec['output_dir']),"--epochs","200"])#'--topic-covars',"pl_auth", ,"-m","0.95"
                #initializing scorer
                scorer = lda_score(num_topics=n_topics,alpha=-1,optimize_interval=-1,iterations=-1,wiki_path='./data/wiki_sampled_5p.txt',
                          db_path = './data/wiki_full/',vocab_dict_path = './data/ED_vocab.tmp', 
                          wiki_vocab_dict_path='./data/wiki_sampled5p_vocab.obj',npmi_skip_threshold=0.25)
                #setting vocabulary of wikipedia
                with open ('./data/wiki_sampled5p_vocab.obj','rb') as vfile:
                    wiki_vocab_dict = pickle.load(vfile)
                scorer.wiki_vocab_dict = wiki_vocab_dict
                #extracting top terms
                        #reading top terms
                top_terms = []
                with open(os.path.join(model_spec['output_dir'],'topics.txt'),'r') as tfile:
                    top_terms = [[j for j in i.strip().split() if j in scorer.wiki_vocab_dict.token2id.keys()] \
                                     for i in tfile.readlines()]
                scorer.all_top_terms = top_terms
                #save the NPMI
                if len(top_terms) == n_topics:
                    npmi_runs.append(scorer.score())
            npmis.append([n_topics,np.mean(npmi_runs)])

    #single run
    else:
        #running SCHOLAR
        subprocess.run(["python", "./scholar/run_scholar.py","./data/","-k {0}".format(model_spec['K']),
                "-o","{0}".format(model_spec['output_dir']),"--epochs","200","--topic-covars","platform"])
        #"--topic-covars","platform"
        #reading top terms
        top_terms = []
        with open(os.path.join(model_spec['output_dir'],'topics.txt'),'r') as tfile:
            top_terms = [i.strip() for i in tfile.readlines()]
        #topic_doc_dist
        topic_doc_dist = np.load(os.path.join(model_spec['output_dir'],'theta.train.npz'))['theta']
        #term_probab
        term_probab = np.load(os.path.join(model_spec['output_dir'],'beta.npz'))['beta']     
            
        #############We need to save the model as well!
# Out:
# Running SCHOLAR with 5 topics and other details as below:
# {'name': 'scholar', 'output_dir': './result/scholar_output/', 'save_flag': False}
# Loading data
# Loaded 13358 documents with 9928 features
# Found 13354 non-empty documents
# Computing background frequencies
# Min/max word counts in training data: 6 3619
# Network architecture:
# embedding_dim: 300
# n_topics: 5
# vocab_size: 9928
# label_type: None
# n_labels: 0
# n_prior_covars: 0
# n_topic_covars: 0
# l1_beta_reg: 0.0
# l1_beta_c_reg: 0.0
# l1_beta_ci_reg: 0.0
# l2_prior_reg: 0.0
# classifier_layers: 1
# use_interactions: False
# Optimizing full model
# Epoch: 10 cost= 372.332000390
# Epoch: 20 cost= 363.629916415
# Epoch: 30 cost= 362.885702058
# Epoch: 40 cost= 360.489024148
# Epoch: 50 cost= 366.439142894
# Epoch: 60 cost= 364.061239899
# Epoch: 70 cost= 362.880854530
# Epoch: 80 cost= 361.325141800
# Epoch: 90 cost= 357.160709067
# Epoch: 100 cost= 363.496173826
# Epoch: 110 cost= 360.933965592
# Epoch: 120 cost= 363.854559978
# Epoch: 130 cost= 357.498759004
# Epoch: 140 cost= 361.040025259
# Epoch: 150 cost= 359.305015245
# Epoch: 160 cost= 359.511746813
# Epoch: 170 cost= 357.110635924
# Epoch: 180 cost= 361.310586876
# Epoch: 190 cost= 358.452443604
# Background frequencies of top words:
# body eating food eat cup chocolate new take work last
# [0.00562901 0.00532727 0.00466155 0.00393051 0.00378586 0.00264419
#  0.00249176 0.00246221 0.00240932 0.00235644]
# Topics:
# 0: nodded session therapy uh skype foster replied rupture  / #fitness #bodyimage #edrecovery #wellness #recovery #healthy #vegans #whatveganseat ; sparsity=0.0000
# 1: #carbthefuckup #freelee #freeleethebananagirl #rt #rawtil #veganfitness #hclf #lowfat  / grease #expectationvsreality #instagramvsreality wet #baking therapist bree beliefs ; sparsity=0.0000
# 2: #expectationvsreality #instagramvsreality cellulite #bodyimagemovement #effyourbeautystandards #selfconfidence #bodyimagehealing #bekindtoyourmind  / #paleo #grainfree #cleaneats #whatveganseat #vegans #thefeedfeed #foodgrams #plantbased ; sparsity=0.0000
# 3: allianceforeatingdisorders #edfighter #prorecovery laurieyurchuck #yourpathtorecovery #anxiety #aeda #findedhelp  / #vegans #paleo #grainfree #whatveganseat #fitness #thefeedfeed #foodgrams #cleaneats ; sparsity=0.0000
# 4: grease batter flour pinch #veganbaking cooled slicing loaf  / #compassion #carbthefuckup #freelee #freeleethebananagirl #rt #rawtil #veganfitness #hclf ; sparsity=0.0000
# sparsity in topics = 0.0000
# Saving document representations
# Load NPMI coherence DB.
# Number of keys : 2310143
# skipping 0.10 missed term-pairs < allowed misses = 0.25
# Loading data
# Loaded 13358 documents with 9928 features
# Found 13354 non-empty documents
# Computing background frequencies
# Min/max word counts in training data: 6 3619
# Network architecture:
# embedding_dim: 300
# n_topics: 5
# vocab_size: 9928
# label_type: None
# n_labels: 0
# n_prior_covars: 0
# n_topic_covars: 0
# l1_beta_reg: 0.0
# l1_beta_c_reg: 0.0
# l1_beta_ci_reg: 0.0
# l2_prior_reg: 0.0
# classifier_layers: 1
# use_interactions: False
# Optimizing full model
# Epoch: 10 cost= 373.226779711
# Epoch: 20 cost= 368.394778042
# Epoch: 30 cost= 368.814132620
# Epoch: 40 cost= 366.057078996
# Epoch: 50 cost= 362.575841918
# Epoch: 60 cost= 361.615892918
# Epoch: 70 cost= 360.209386328
# Epoch: 80 cost= 365.620336208
# Epoch: 90 cost= 362.000354529
# Epoch: 100 cost= 366.095302068
# Epoch: 110 cost= 362.511306175
# Epoch: 120 cost= 364.729525498
# Epoch: 130 cost= 360.442560369
# Epoch: 140 cost= 363.488203240
# Epoch: 150 cost= 351.952978285
# Epoch: 160 cost= 362.722480320
# Epoch: 170 cost= 364.350488219
# Epoch: 180 cost= 362.209840311
# Epoch: 190 cost= 353.283258118
# Background frequencies of top words:
# body eating food eat cup chocolate new take work last
# [0.00562901 0.00532727 0.00466155 0.00393051 0.00378586 0.00264419
#  0.00249176 0.00246221 0.00240932 0.00235644]
# Topics:
# 0: #lowfat #rawtil #veganfitness #freeleethebananagirl #veganism #rt #freelee #carbthefuckup  / disorder disorders behaviors #thefeedfeedbaking recovery #thefeedfeed #chocolate grease ; sparsity=0.0000
# 1: #expectationvsreality #instagramvsreality cellulite #bodyimagemovement #selftalk #selfesteem #bekindtoyourmind #beautystandards  / #raw #plantbased #compassion #veganfood #lowfat #veganfitness #veganism #freeleethebananagirl ; sparsity=0.0000
# 2: nodded session uh therapy replied skype rupture texted  / #edrecovery #carbs #veganfood #bodyimage #girl #raw #compassion #nature ; sparsity=0.0000
# 3: laurieyurchuck #edfighter #prorecovery allianceforeatingdisorders #quoteoftheweek #yougotthis #aeda #anxiety  / #girl #raw #veganfitness #lowfat #carbthefuckup #freeleethebananagirl #veganism #rt ; sparsity=0.0000
# 4: grease preheat pinch flour loaf #veganbaking batter splash  / #girl #compassion #veganfitness #freelee #lowfat #rawtil #rt #carbthefuckup ; sparsity=0.0000
# sparsity in topics = 0.0000
# Saving document representations
# Load NPMI coherence DB.
# Number of keys : 2310143
# skipping 0.05 missed term-pairs < allowed misses = 0.25
#
#
# Running SCHOLAR with 6 topics and other details as below:
# {'name': 'scholar', 'output_dir': './result/scholar_output/', 'save_flag': False}
# Loading data
# Loaded 13358 documents with 9928 features
# Found 13354 non-empty documents
# Computing background frequencies
# Min/max word counts in training data: 6 3619
# Network architecture:
# embedding_dim: 300
# n_topics: 6
# vocab_size: 9928
# label_type: None
# n_labels: 0
# n_prior_covars: 0
# n_topic_covars: 0
# l1_beta_reg: 0.0
# l1_beta_c_reg: 0.0
# l1_beta_ci_reg: 0.0
# l2_prior_reg: 0.0
# classifier_layers: 1
# use_interactions: False
# Optimizing full model
# Epoch: 10 cost= 371.291824028
# Epoch: 20 cost= 367.904206488
# Epoch: 30 cost= 355.946823378
# Epoch: 40 cost= 355.591165389
# Epoch: 50 cost= 358.726128279
# Epoch: 60 cost= 361.994783025
# Epoch: 70 cost= 359.192491445
# Epoch: 80 cost= 364.042304100
# Epoch: 90 cost= 362.132799538
# Epoch: 100 cost= 360.920439499
# Epoch: 110 cost= 363.970116796
# Epoch: 120 cost= 354.727303569
# Epoch: 130 cost= 360.849127456
# Epoch: 140 cost= 362.476532042
# Epoch: 150 cost= 359.951575181
# Epoch: 160 cost= 362.736351947
# Epoch: 170 cost= 361.927763188
# Epoch: 180 cost= 359.761243211
# Epoch: 190 cost= 361.466096721
# Background frequencies of top words:
# body eating food eat cup chocolate new take work last
# [0.00562901 0.00532727 0.00466155 0.00393051 0.00378586 0.00264419
#  0.00249176 0.00246221 0.00240932 0.00235644]
# Topics:
# 0: #quoteoftheweek laurieyurchuck #yourpathtorecovery #allianceforeda #findedhelp #mentalhealth #inspirationalquotes selected  / #fitness #paleo #thenewhealth #cleaneats #grainfree #whatveganseat #mbg #healthyinspo ; sparsity=0.0000
# 1: #veganism #hclf #rt #freeleethebananagirl #lowfat #carbthefuckup #freelee #veganfitness  / disorders alliance allianceforeatingdisorders resources support disorder #notonemore recovery ; sparsity=0.0000
# 2: ppl ur ana fuck fucking rly tags fuckin  / allianceforeatingdisorders com #fitness #wellness #vegan #healthy coaching alliance ; sparsity=0.0000
# 3: grease pinch cooled batter preheat #veganbaking icing flour  / #veganism #hclf #rt #compassion #crueltyfree #freeleethebananagirl #lowfat #carbthefuckup ; sparsity=0.0000
# 4: nodded session therapy skype uh foster rupture sessions  / protein cream seeds topped foods veggies bowl roasted ; sparsity=0.0000
# 5: #instagramvsreality #expectationvsreality #selfesteem cellulite #beautystandards #bekindtoyourmind #bodyimagemovement #selfesteemboost  / allianceforeatingdisorders alliance powder diced oven #healthyrecipe visit sauté ; sparsity=0.0000
# sparsity in topics = 0.0000
# Saving document representations
# Load NPMI coherence DB.
# Number of keys : 2310143
# skipping 0.06 missed term-pairs < allowed misses = 0.25
# Loading data
# Loaded 13358 documents with 9928 features
# Found 13354 non-empty documents
# Computing background frequencies
# Min/max word counts in training data: 6 3619
# Network architecture:
# embedding_dim: 300
# n_topics: 6
# vocab_size: 9928
# label_type: None
# n_labels: 0
# n_prior_covars: 0
# n_topic_covars: 0
# l1_beta_reg: 0.0
# l1_beta_c_reg: 0.0
# l1_beta_ci_reg: 0.0
# l2_prior_reg: 0.0
# classifier_layers: 1
# use_interactions: False
# Optimizing full model
# Epoch: 10 cost= 373.499240850
# Epoch: 20 cost= 363.426397488
# Epoch: 30 cost= 360.655983226
# Epoch: 40 cost= 365.165522828
# Epoch: 50 cost= 362.480692159
# Epoch: 60 cost= 363.936673608
# Epoch: 70 cost= 360.808569288
# Epoch: 80 cost= 361.766697380
# Epoch: 90 cost= 355.152009807
# Epoch: 100 cost= 360.665436042
# Epoch: 110 cost= 360.589288812
# Epoch: 120 cost= 361.077188421
# Epoch: 130 cost= 357.194318624
# Epoch: 140 cost= 365.162477012
# Epoch: 150 cost= 357.407658754
# Epoch: 160 cost= 357.320874934
# Epoch: 170 cost= 362.175127880
# Epoch: 180 cost= 355.124780741
# Epoch: 190 cost= 363.632639093
# Background frequencies of top words:
# body eating food eat cup chocolate new take work last
# [0.00562901 0.00532727 0.00466155 0.00393051 0.00378586 0.00264419
#  0.00249176 0.00246221 0.00240932 0.00235644]
# Topics:
# 0: thailand #hollygoessolo travelling vlogs australia vlog holly narnastore  / #fitness #paleo #cleaneats #grainfree #thenewhealth #healthylife #healthyinspo #thefeedfeed ; sparsity=0.0000
# 1: fuck tags ppl fucking ana ur rly urself  / #edrecovery link #fitness #bodyimage #recovery #wellness #vegan bio ; sparsity=0.0000
# 2: grease cooled #baking icing granulated pinch #cookiedough slicing  / #veganfitness #veganism #lowfat #hclf #carbthefuckup #rawtil #compassion #crueltyfree ; sparsity=0.0000
# 3: #expectationvsreality #instagramvsreality cellulite #bodyimagemovement #bodyimagehealing #bekindtoyourmind #beautystandards #effyourbeautystandards  / #paleo session #foodgrams #thefeedfeed #grainfree #cleaneats #glutenfree #vegans ; sparsity=0.0000
# 4: #findedhelp #allianceforeda #eatingdisorder laurieyurchuck #yourpathtorecovery #quoteoftheweek allianceforeatingdisorders #edwarrior  / cream protein dinner heat water cook bowl ice ; sparsity=0.0000
# 5: #veganfitness #veganism #lowfat #hclf #carbthefuckup #rawtil #freelee #rt  / therapy session nodded bree talked solo speak protect ; sparsity=0.0000
# sparsity in topics = 0.0000
# Saving document representations
# Load NPMI coherence DB.
# Number of keys : 2310143
# skipping 0.04 missed term-pairs < allowed misses = 0.25
#
#
# Running SCHOLAR with 7 topics and other details as below:
# {'name': 'scholar', 'output_dir': './result/scholar_output/', 'save_flag': False}
# Loading data
# Loaded 13358 documents with 9928 features
# Found 13354 non-empty documents
# Computing background frequencies
# Min/max word counts in training data: 6 3619
# Network architecture:
# embedding_dim: 300
# n_topics: 7
# vocab_size: 9928
# label_type: None
# n_labels: 0
# n_prior_covars: 0
# n_topic_covars: 0
# l1_beta_reg: 0.0
# l1_beta_c_reg: 0.0
# l1_beta_ci_reg: 0.0
# l2_prior_reg: 0.0
# classifier_layers: 1
# use_interactions: False
# Optimizing full model
# Epoch: 10 cost= 366.224365783
# Epoch: 20 cost= 361.056991150
# Epoch: 30 cost= 363.670418365
# Epoch: 40 cost= 360.336966441
# Epoch: 50 cost= 361.885307327
# Epoch: 60 cost= 358.800338967
# Epoch: 70 cost= 360.851119303
# Epoch: 80 cost= 364.438332864
# Epoch: 90 cost= 363.349165666
# Epoch: 100 cost= 357.092419530
# Epoch: 110 cost= 355.765781514
# Epoch: 120 cost= 359.414323661
# Epoch: 130 cost= 361.941504096
# Epoch: 140 cost= 358.075159589
# Epoch: 150 cost= 363.093891175
# Epoch: 160 cost= 357.446796851
# Epoch: 170 cost= 355.444959818
# Epoch: 180 cost= 356.833344626
# Epoch: 190 cost= 357.358654663
# Background frequencies of top words:
# body eating food eat cup chocolate new take work last
# [0.00562901 0.00532727 0.00466155 0.00393051 0.00378586 0.00264419
#  0.00249176 0.00246221 0.00240932 0.00235644]
# Topics:
# 0: nodded session uh therapy rupture skype replied client  / #vegan #fitness #plantbased #girl #veganfood #nature #compassion #carbs ; sparsity=0.0000
# 1: #carbthefuckup #veganfitness #freeleethebananagirl #rawtil #rt #lowfat #freelee #veganism  / almond coaching cacao tbsp maple maca syrup awareness ; sparsity=0.0000
# 2: #edfighter #prorecovery #anxiety #aeda #allianceforeatingdisorders #edwarrior #support #quoteoftheweek  / #girl #vegan #raw #carbs #carbthefuckup #veganfitness #freeleethebananagirl #lowfat ; sparsity=0.0000
# 3: mixer grease granulated cooled #baking #cookiedough flour pinch  / confidence coaching beliefs young travelling conversations truth learn ; sparsity=0.0000
# 4: giveaway coaching solo macrmike amandavsevilla winner announced #solodate  / #fitness #healthy #paleo #healthyinspo #thefeedfeed #grainfree #thenewhealth #foodgrams ; sparsity=0.0000
# 5: sauté cumin broth florets onion browned fragrant #buddhabowl  / solo lives women confidence built beliefs bree australia ; sparsity=0.0000
# 6: #instagramvsreality #expectationvsreality cellulite #bekindtoyourmind #selfconfidence #selfesteem #bodyimagemovement #selfesteemboost  / #plantbased #vegan #compassion #veganfood #raw #carbthefuckup #rawtil #freeleethebananagirl ; sparsity=0.0000
# sparsity in topics = 0.0000
# Saving document representations
# Load NPMI coherence DB.
# Number of keys : 2310143
# skipping 0.08 missed term-pairs < allowed misses = 0.25
# Loading data
# Loaded 13358 documents with 9928 features
# Found 13354 non-empty documents
# Computing background frequencies
# Min/max word counts in training data: 6 3619
# Network architecture:
# embedding_dim: 300
# n_topics: 7
# vocab_size: 9928
# label_type: None
# n_labels: 0
# n_prior_covars: 0
# n_topic_covars: 0
# l1_beta_reg: 0.0
# l1_beta_c_reg: 0.0
# l1_beta_ci_reg: 0.0
# l2_prior_reg: 0.0
# classifier_layers: 1
# use_interactions: False
# Optimizing full model
# Epoch: 10 cost= 372.936193590
# Epoch: 20 cost= 365.997238125
# Epoch: 30 cost= 360.626897145
# Epoch: 40 cost= 363.928009211
# Epoch: 50 cost= 359.265621654
# Epoch: 60 cost= 365.307526234
# Epoch: 70 cost= 357.553758288
# Epoch: 80 cost= 359.810862956
# Epoch: 90 cost= 359.446577592
# Epoch: 100 cost= 358.200116662
# Epoch: 110 cost= 357.180831381
# Epoch: 120 cost= 357.161662028
# Epoch: 130 cost= 355.194783321
# Epoch: 140 cost= 358.372169621
# Epoch: 150 cost= 361.649427975
# Epoch: 160 cost= 356.068289921
# Epoch: 170 cost= 356.692156150
# Epoch: 180 cost= 352.598631423
# Epoch: 190 cost= 355.021638000
# Background frequencies of top words:
# body eating food eat cup chocolate new take work last
# [0.00562901 0.00532727 0.00466155 0.00393051 0.00378586 0.00264419
#  0.00249176 0.00246221 0.00240932 0.00235644]
# Topics:
# 0: #expectationvsreality #instagramvsreality cellulite #dontcompare #bodyimagemovement #selfesteem #bekindtoyourmind #bodyimagehealing  / #paleo #grainfree #cleaneats #glutenfree #healthymeals #vegan #thenewhealth #plantpower ; sparsity=0.0000
# 1: nodded session therapy uh rupture skype sessions talked  / #fitness #healthy #vegan #cleaneats #paleo #wellness #grainfree #thefeedfeed ; sparsity=0.0000
# 2: thailand #hollygoessolo travelling vlog vlogs australia holly narnastore  / #cleaneats #thenewhealth #healthyinspo #healthylife #healthymeals #thefeedfeed #paleo #fitness ; sparsity=0.0000
# 3: #veganfitness #lowfat #rawtil #hclf #carbthefuckup #freelee #freeleethebananagirl #veganism  / pinch combined batter uniform grease forms pour smooth ; sparsity=0.0000
# 4: allianceforeatingdisorders alliance alliancefored #notonemore #eatingdisordersawarenessweek #edaw individuals #itstimeforchange  / #paleo #grainfree #fitness #thefeedfeed #foodgrams #vegans #whatveganseat #cleaneats ; sparsity=0.0000
# 5: sauté cumin simmer fragrant diced florets onion browned  / #mentalhealth selected #allianceforeda #findedhelp #quoteoftheweek #girl laurieyurchuck weight ; sparsity=0.0000
# 6: grease preheat slicing #baking cooled #nobake granulated mixer  / #quoteoftheweek #findedhelp #veganfitness #lowfat #allianceforeda #rawtil #compassion #hclf ; sparsity=0.0001
# sparsity in topics = 0.0000
# Saving document representations
# Load NPMI coherence DB.
# Number of keys : 2310143
# skipping 0.04 missed term-pairs < allowed misses = 0.25
#
#
# Running SCHOLAR with 8 topics and other details as below:
# {'name': 'scholar', 'output_dir': './result/scholar_output/', 'save_flag': False}
# Loading data
# Loaded 13358 documents with 9928 features
# Found 13354 non-empty documents
# Computing background frequencies
# Min/max word counts in training data: 6 3619
# Network architecture:
# embedding_dim: 300
# n_topics: 8
# vocab_size: 9928
# label_type: None
# n_labels: 0
# n_prior_covars: 0
# n_topic_covars: 0
# l1_beta_reg: 0.0
# l1_beta_c_reg: 0.0
# l1_beta_ci_reg: 0.0
# l2_prior_reg: 0.0
# classifier_layers: 1
# use_interactions: False
# Optimizing full model
# Epoch: 10 cost= 370.035605883
# Epoch: 20 cost= 361.441387401
# Epoch: 30 cost= 360.246772532
# Epoch: 40 cost= 360.524535511
# Epoch: 50 cost= 361.297145796
# Epoch: 60 cost= 359.587009185
# Epoch: 70 cost= 359.622530604
# Epoch: 80 cost= 363.761228842
# Epoch: 90 cost= 360.069099622
# Epoch: 100 cost= 360.661041913
# Epoch: 110 cost= 361.373089637
# Epoch: 120 cost= 364.484321305
# Epoch: 130 cost= 362.409070689
# Epoch: 140 cost= 363.832323327
# Epoch: 150 cost= 357.822891608
# Epoch: 160 cost= 357.011743340
# Epoch: 170 cost= 357.558709568
# Epoch: 180 cost= 353.162770588
# Epoch: 190 cost= 358.981480926
# Background frequencies of top words:
# body eating food eat cup chocolate new take work last
# [0.00562901 0.00532727 0.00466155 0.00393051 0.00378586 0.00264419
#  0.00249176 0.00246221 0.00240932 0.00235644]
# Topics:
# 0: #veganfitness #hclf #freelee #freeleethebananagirl #veganism #rt #lowfat #carbthefuckup  / weight bree amb gain macrmike towards protect losing ; sparsity=0.0000
# 1: #expectationvsreality #instagramvsreality #selfesteem #bekindtoyourmind #bodyimagemovement #embraceyourbody cellulite #dontcompare  / rice seeds powder garlic cheese oven milk syrup ; sparsity=0.0000
# 2: restriction cues binge restrict hunger restricting weight binging  / #paleo #thefeedfeed #foodgrams #grainfree #glutenfree #thenewhealth #mbg #cleaneats ; sparsity=0.0000
# 3: ppl ur yal tags fuckin yano rly weed  / coconut almond amb cacao maple #reels bree tbsp ; sparsity=0.0000
# 4: nodded session skype foster uh therapy replied rupture  / protein cream vegan topped almond seeds cacao coconut ; sparsity=0.0000
# 5: grease mixer cooled icing slicing pinch loaf batter  / #veganfitness #hclf #freelee #compassion #freeleethebananagirl #veganism #rt #lowfat ; sparsity=0.0000
# 6: allianceforeatingdisorders #quoteoftheweek #findedhelp #prorecovery #edfighter #anxiety #eatingdisorder #yougotthis  / salt smooth heat powder chopped sea water legs ; sparsity=0.0000
# 7: thailand vlog #hollygoessolo vlogs travelling holly cambridge lemonem_ily  / #fitness #paleo #grainfree #thenewhealth #cleaneats #healthylife #thefeedfeed #healthymeals ; sparsity=0.0000
# sparsity in topics = 0.0000
# Saving document representations
# Load NPMI coherence DB.
# Number of keys : 2310143
# skipping 0.05 missed term-pairs < allowed misses = 0.25
# Loading data
# Loaded 13358 documents with 9928 features
# Found 13354 non-empty documents
# Computing background frequencies
# Min/max word counts in training data: 6 3619
# Network architecture:
# embedding_dim: 300
# n_topics: 8
# vocab_size: 9928
# label_type: None
# n_labels: 0
# n_prior_covars: 0
# n_topic_covars: 0
# l1_beta_reg: 0.0
# l1_beta_c_reg: 0.0
# l1_beta_ci_reg: 0.0
# l2_prior_reg: 0.0
# classifier_layers: 1
# use_interactions: False
# Optimizing full model
# Epoch: 10 cost= 369.395889435
# Epoch: 20 cost= 363.641895376
# Epoch: 30 cost= 359.458892946
# Epoch: 40 cost= 361.798971421
# Epoch: 50 cost= 357.841461762
# Epoch: 60 cost= 358.397289834
# Epoch: 70 cost= 360.965507888
# Epoch: 80 cost= 362.064067571
# Epoch: 90 cost= 358.671467215
# Epoch: 100 cost= 359.829621874
# Epoch: 110 cost= 355.109069468
# Epoch: 120 cost= 364.644635715
# Epoch: 130 cost= 363.887637522
# Epoch: 140 cost= 360.429279258
# Epoch: 150 cost= 362.251982175
# Epoch: 160 cost= 361.050027913
# Epoch: 170 cost= 358.353372311
# Epoch: 180 cost= 355.974640674
# Epoch: 190 cost= 358.432677336
# Background frequencies of top words:
# body eating food eat cup chocolate new take work last
# [0.00562901 0.00532727 0.00466155 0.00393051 0.00378586 0.00264419
#  0.00249176 0.00246221 0.00240932 0.00235644]
# Topics:
# 0: fuck ana fucking tags butimpissed imtrying ur ppl  / #fitness #wellness #healthylife #healthy #healthymeals #thenewhealth #plantpower #foodblogger ; sparsity=0.0000
# 1: foster vaccine government fostering sofa babies uk #hollygoessolo  / disorders allianceforeatingdisorders eating recovery tbsp #glutenfree #veganprotein #thefeedfeed ; sparsity=0.0000
# 2: est allianceforeatingdisorders alliance founder fireside virtual individuals alliancefored  / tbsp #healthymeals #thefeedfeed #paleo #mbg #foodgrams #healthylife thick ; sparsity=0.0000
# 3: nodded session rupture therapy uh talked childhood avoidant  / powder tbsp allianceforeatingdisorders cacao seeds milk ad blend ; sparsity=0.0000
# 4: amb macrmike bree choc #macromike chia protein nuzest_usa  / alliance allianceforeatingdisorders #notonemore #allianceforeda #yourpathtorecovery disorders #findedhelp #eatingdisorder ; sparsity=0.0000
# 5: #allianceforeda #findedhelp #mentalhealth #quoteoftheweek laurieyurchuck #eatingdisorder #yourpathtorecovery #edwarrior  / milk vegan cacao chocolate protein powder almond oats ; sparsity=0.0000
# 6: #hclf #freelee #carbthefuckup #lowfat #rt #rawtil #freeleethebananagirl #veganfitness  / weight gain #expectationvsreality #instagramvsreality image likely women common ; sparsity=0.0000
# 7: grease cooled batter mixer preheat loaf pinch slicing  / #hclf #freelee #carbthefuckup #lowfat #rt #crueltyfree #compassion #rawtil ; sparsity=0.0000
# sparsity in topics = 0.0000
# Saving document representations
# Load NPMI coherence DB.
# Number of keys : 2310143
# skipping 0.09 missed term-pairs < allowed misses = 0.25
#
#
# Running SCHOLAR with 9 topics and other details as below:
# {'name': 'scholar', 'output_dir': './result/scholar_output/', 'save_flag': False}
# Loading data
# Loaded 13358 documents with 9928 features
# Found 13354 non-empty documents
# Computing background frequencies
# Min/max word counts in training data: 6 3619
# Network architecture:
# embedding_dim: 300
# n_topics: 9
# vocab_size: 9928
# label_type: None
# n_labels: 0
# n_prior_covars: 0
# n_topic_covars: 0
# l1_beta_reg: 0.0
# l1_beta_c_reg: 0.0
# l1_beta_ci_reg: 0.0
# l2_prior_reg: 0.0
# classifier_layers: 1
# use_interactions: False
# Optimizing full model
# Epoch: 10 cost= 371.474581677
# Epoch: 20 cost= 360.292190111
# Epoch: 30 cost= 363.727792509
# Epoch: 40 cost= 362.007275716
# Epoch: 50 cost= 362.888406911
# Epoch: 60 cost= 357.770809707
# Epoch: 70 cost= 368.028802030
# Epoch: 80 cost= 355.540437286
# Epoch: 90 cost= 367.841084417
# Epoch: 100 cost= 355.264349871
# Epoch: 110 cost= 362.754364037
# Epoch: 120 cost= 357.548836718
# Epoch: 130 cost= 360.075571524
# Epoch: 140 cost= 361.279989771
# Epoch: 150 cost= 362.318306375
# Epoch: 160 cost= 350.588023957
# Epoch: 170 cost= 356.766790984
# Epoch: 180 cost= 352.275992475
# Epoch: 190 cost= 355.438653370
# Background frequencies of top words:
# body eating food eat cup chocolate new take work last
# [0.00562901 0.00532727 0.00466155 0.00393051 0.00378586 0.00264419
#  0.00249176 0.00246221 0.00240932 0.00235644]
# Topics:
# 0: #expectationvsreality #instagramvsreality cellulite #selftalk #bodyimagemovement #effyourbeautystandards #dontcompare #bekindtoyourmind  / #glutenfree #paleo #thefeedfeed powder #grainfree #foodgrams #cleaneats #healthyrecipe ; sparsity=0.0000
# 1: allianceforeatingdisorders alliancefored alliance fireside #itstimeforchange com founder individuals  / #fitness breakfast #healthy bowl nibs #paleo #grainfree #cleaneats ; sparsity=0.0000
# 2: grease cooled batter #baking mixer pinch preheat granulated  / #mentalhealth #allianceforeda #recovery #eatingdisorder #eatingdisorderrecovery #yourpathtorecovery #findedhelp #edwarrior ; sparsity=0.0000
# 3: sauté cumin browned diced simmer fragrant onion florets  / #allianceforeda #mentalhealth #yourpathtorecovery #findedhelp #eatingdisorder #recoveryispossible #rt #rawtil ; sparsity=0.0000
# 4: #rt #rawtil #freeleethebananagirl #lowfat #hclf #carbthefuckup #veganism #compassion  / grease smooth uniform dry cups batter add wet ; sparsity=0.0000
# 5: ana tags thinspo pro fuck proana fucking blogs  / #wellness #fitness #healthy #healthylife #glutenfree #thenewhealth #mbg #plantpower ; sparsity=0.0000
# 6: nodded session rupture uh therapy skype replied texted  / seeds powder vegan cacao protein #vegan #healthyrecipe #foodie ; sparsity=0.0000
# 7: thailand giveaway vlog vlogs #hollygoessolo macrmike holly veganmutti  / #paleo #cleaneats #thenewhealth #grainfree #healthyinspo #healthylife #thefeedfeed #foodgrams ; sparsity=0.0000
# 8: inpatient vaccine tms foster government babies unit sofa  / cacao vegan #vegan vanilla #thefeedfeed #vegans protein butter ; sparsity=0.0001
# sparsity in topics = 0.0000
# Saving document representations
# Load NPMI coherence DB.
# Number of keys : 2310143
# skipping 0.05 missed term-pairs < allowed misses = 0.25
# Loading data
# Loaded 13358 documents with 9928 features
# Found 13354 non-empty documents
# Computing background frequencies
# Min/max word counts in training data: 6 3619
# Network architecture:
# embedding_dim: 300
# n_topics: 9
# vocab_size: 9928
# label_type: None
# n_labels: 0
# n_prior_covars: 0
# n_topic_covars: 0
# l1_beta_reg: 0.0
# l1_beta_c_reg: 0.0
# l1_beta_ci_reg: 0.0
# l2_prior_reg: 0.0
# classifier_layers: 1
# use_interactions: False
# Optimizing full model
# Epoch: 10 cost= 375.682665928
# Epoch: 20 cost= 361.616510857
# Epoch: 30 cost= 356.394277255
# Epoch: 40 cost= 359.286207422
# Epoch: 50 cost= 364.585039368
# Epoch: 60 cost= 358.632297125
# Epoch: 70 cost= 362.459445032
# Epoch: 80 cost= 360.037874065
# Epoch: 90 cost= 354.984736732
# Epoch: 100 cost= 363.408883589
# Epoch: 110 cost= 362.186883341
# Epoch: 120 cost= 359.667082063
# Epoch: 130 cost= 360.939697065
# Epoch: 140 cost= 357.176775473
# Epoch: 150 cost= 357.366702491
# Epoch: 160 cost= 358.831233615
# Epoch: 170 cost= 356.027497284
# Epoch: 180 cost= 357.883883344
# Epoch: 190 cost= 354.568333816
# Background frequencies of top words:
# body eating food eat cup chocolate new take work last
# [0.00562901 0.00532727 0.00466155 0.00393051 0.00378586 0.00264419
#  0.00249176 0.00246221 0.00240932 0.00235644]
# Topics:
# 0: fluctuate #weightgain gain #weightgainjourney kgs weight #expectationvsreality #bloating  / #plantbased #vegan #paleo #cleaneats #grainfree #glutenfree #thefeedfeed #thenewhealth ; sparsity=0.0000
# 1: coaching amandavsevilla flourish purpose giveaway dm bi limiting  / #fitness #grainfree #paleo #cleaneats #healthymeals #thefeedfeed #foodgrams #healthyinspo ; sparsity=0.0000
# 2: #rawtil #carbthefuckup #hclf #veganfitness #veganism #freeleethebananagirl #lowfat #freelee  / cup eating disorder combined add flour disorders batter ; sparsity=0.0000
# 3: sauté fragrant cumin diced browned florets simmer broth  / #expectationvsreality #instagramvsreality lives travelling travel #bodyimagemovement #bekindtoyourmind solo ; sparsity=0.0000
# 4: yal fuckin ppl ur proana rly tags ana  / maple #vegan #bodyimage cacao #fitness almond topped #wellness ; sparsity=0.0000
# 5: grease cooled mixer granulated batter #baking preheat #cookiedough  / #expectationvsreality #instagramvsreality social reality travelling comfortable truth confidence ; sparsity=0.0000
# 6: laurieyurchuck #yourpathtorecovery #quoteoftheweek #edwarrior #aeda #anxiety #prorecovery #edfighter  / protein frozen vegan almond milk smooth water oats ; sparsity=0.0000
# 7: thailand vlog strava parkrun evening cafe kiwi sofa  / #fitness #healthy #cleaneats #thenewhealth #healthylife #grainfree #paleo #foodgrams ; sparsity=0.0000
# 8: nodded session rupture therapy uh skype client replied  / vegan seeds protein topped #vegan almond recipes cacao ; sparsity=0.0000
# sparsity in topics = 0.0000
# Saving document representations
# Load NPMI coherence DB.
# Number of keys : 2310143
# skipping 0.12 missed term-pairs < allowed misses = 0.25
#
#
# Running SCHOLAR with 10 topics and other details as below:
# {'name': 'scholar', 'output_dir': './result/scholar_output/', 'save_flag': False}
# Loading data
# Loaded 13358 documents with 9928 features
# Found 13354 non-empty documents
# Computing background frequencies
# Min/max word counts in training data: 6 3619
# Network architecture:
# embedding_dim: 300
# n_topics: 10
# vocab_size: 9928
# label_type: None
# n_labels: 0
# n_prior_covars: 0
# n_topic_covars: 0
# l1_beta_reg: 0.0
# l1_beta_c_reg: 0.0
# l1_beta_ci_reg: 0.0
# l2_prior_reg: 0.0
# classifier_layers: 1
# use_interactions: False
# Optimizing full model
# Epoch: 10 cost= 365.604264775
# Epoch: 20 cost= 364.261796650
# Epoch: 30 cost= 362.736925094
# Epoch: 40 cost= 359.199674068
# Epoch: 50 cost= 360.031216598
# Epoch: 60 cost= 356.992249020
# Epoch: 70 cost= 357.224429880
# Epoch: 80 cost= 360.035892731
# Epoch: 90 cost= 357.665205723
# Epoch: 100 cost= 359.957483077
# Epoch: 110 cost= 360.835400259
# Epoch: 120 cost= 352.932657445
# Epoch: 130 cost= 364.919601516
# Epoch: 140 cost= 361.220686854
# Epoch: 150 cost= 362.065411314
# Epoch: 160 cost= 360.031613779
# Epoch: 170 cost= 355.906898689
# Epoch: 180 cost= 358.204978359
# Epoch: 190 cost= 356.604027216
# Background frequencies of top words:
# body eating food eat cup chocolate new take work last
# [0.00562901 0.00532727 0.00466155 0.00393051 0.00378586 0.00264419
#  0.00249176 0.00246221 0.00240932 0.00235644]
# Topics:
# 0: allianceforeatingdisorders alliancefored #eatingdisordersawarenessweek alliance #itstimeforchange founder #givehopeday fireside  / #girl #raw #fitness #carbs smooth #hclf #veganfitness #rt ; sparsity=0.0000
# 1: yal inpatient ppl weed fuckin ferrets shes rly  / #edrecovery #recovery #mentalhealth vanilla #recoveryispossible #allianceforeda #fitness cacao ; sparsity=0.0000
# 2: grease cooled icing slicing pinch mixer #baking #veganbaking  / thoughts struggle truth disorder understand sense young protect ; sparsity=0.0000
# 3: gain weight binge restricting restriction gaining binging restrict  / sea #yourpathtorecovery blend #findedhelp #allianceforeda splash thick oat ; sparsity=0.0000
# 4: #deats deats kodiakcakes vitalproteins whites parmesan chicken pancakes  / #fitness #healthy #grainfree #paleo #thenewhealth #cleaneats #mbg #foodgrams ; sparsity=0.0000
# 5: nodded session skype therapy uh rupture foster replied  / #edrecovery protein vegan #fitness #vegan #plantbased #healthy #compassion ; sparsity=0.0000
# 6: #hclf #rt #veganfitness #veganism #freeleethebananagirl #rawtil #freelee #lowfat  / syrup maple tbsp flour batter salt cup disorder ; sparsity=0.0000
# 7: laurieyurchuck #quoteoftheweek #findedhelp #inspirationalquotes #yourpathtorecovery #allianceforeda selected #quotes  / protein milk oil minutes tbsp powder code mix ; sparsity=0.0000
# 8: #instagramvsreality #expectationvsreality cellulite #selfconfidence #bodyimagemovement #allbodiesaregoodbodies #beautystandards #bekindtoyourmind  / #plantbased #raw #compassion #hclf #veganism #veganfitness #rt #freeleethebananagirl ; sparsity=0.0000
# 9: sauté cumin fragrant browned simmer diced onion #vegancurry  / amb despite bree weight macrmike protect towards struggle ; sparsity=0.0000
# sparsity in topics = 0.0000
# Saving document representations
# Load NPMI coherence DB.
# Number of keys : 2310143
# skipping 0.07 missed term-pairs < allowed misses = 0.25
# Loading data
# Loaded 13358 documents with 9928 features
# Found 13354 non-empty documents
# Computing background frequencies
# Min/max word counts in training data: 6 3619
# Network architecture:
# embedding_dim: 300
# n_topics: 10
# vocab_size: 9928
# label_type: None
# n_labels: 0
# n_prior_covars: 0
# n_topic_covars: 0
# l1_beta_reg: 0.0
# l1_beta_c_reg: 0.0
# l1_beta_ci_reg: 0.0
# l2_prior_reg: 0.0
# classifier_layers: 1
# use_interactions: False
# Optimizing full model
# Epoch: 10 cost= 372.205527264
# Epoch: 20 cost= 364.142726449
# Epoch: 30 cost= 359.437212531
# Epoch: 40 cost= 357.882916215
# Epoch: 50 cost= 360.742337414
# Epoch: 60 cost= 356.697769245
# Epoch: 70 cost= 355.806551298
# Epoch: 80 cost= 357.479740021
# Epoch: 90 cost= 360.809032285
# Epoch: 100 cost= 355.299026194
# Epoch: 110 cost= 357.707716431
# Epoch: 120 cost= 357.439101869
# Epoch: 130 cost= 363.483407816
# Epoch: 140 cost= 361.163200731
# Epoch: 150 cost= 365.585331719
# Epoch: 160 cost= 359.823423291
# Epoch: 170 cost= 352.643419180
# Epoch: 180 cost= 353.575837000
# Epoch: 190 cost= 353.123868331
# Background frequencies of top words:
# body eating food eat cup chocolate new take work last
# [0.00562901 0.00532727 0.00466155 0.00393051 0.00378586 0.00264419
#  0.00249176 0.00246221 0.00240932 0.00235644]
# Topics:
# 0: ppl ur yal weed yano rly fuckin thru  / #fitness maple #vegan salt #reels sea #plantbased vanilla ; sparsity=0.0000
# 1: allianceforeatingdisorders fireside alliancefored candid ceo johannakandel founder #itstimeforchange  / #vegan #plantbased #fitness #healthy #freeleethebananagirl #raw #rt #carbthefuckup ; sparsity=0.0000
# 2: #quoteoftheweek laurieyurchuck #findedhelp #yourpathtorecovery #mentalhealth #eatingdisorder selected #yougotthis  / #paleo #thefeedfeed #vegans #whatveganseat #foodgrams #grainfree #plantpower sea ; sparsity=0.0000
# 3: #expectationvsreality #instagramvsreality #bekindtoyourmind #dontcompare cellulite #embraceyourbody #selfesteem #igvsreality  / #plantbased #vegan #grainfree #paleo #foodgrams #thefeedfeed #cleaneats #glutenfree ; sparsity=0.0000
# 4: sofa gin parkrun prosecco takeaway jigsaw stitch spa  / #fitness #healthy #thenewhealth #paleo #cleaneats #healthylife #foodie #grainfree ; sparsity=0.0000
# 5: sauté diced cumin fragrant simmer onion browned florets  / support solo bree #mentalhealth struggling visit alliance holly ; sparsity=0.0000
# 6: nodded session skype therapy foster sessions uh learnt  / #fitness #healthy cream #plantbased almond vanilla protein #wellness ; sparsity=0.0000
# 7: weight gain hunger cues restriction binge restricting gaining  / #paleo #foodgrams #thefeedfeed #thenewhealth #fitness #plantbased #cleaneats #glutenfree ; sparsity=0.0000
# 8: grease granulated mixer cooled icing pinch preheat tin  / #freeleethebananagirl #rt #compassion #carbthefuckup #rawtil #freelee #hclf #veganism ; sparsity=0.0000
# 9: nibs #oatporn #vegansmoothie #toasttuesday #cleaneating kitehillfoods #toastsforall #avocado  / therapy therapist #freeleethebananagirl #compassion #rt #carbthefuckup #rawtil #freelee ; sparsity=0.0000
# sparsity in topics = 0.0000
# Saving document representations
# Load NPMI coherence DB.
# Number of keys : 2310143
# skipping 0.10 missed term-pairs < allowed misses = 0.25
#
#
# Running SCHOLAR with 11 topics and other details as below:
# {'name': 'scholar', 'output_dir': './result/scholar_output/', 'save_flag': False}
# Loading data
# Loaded 13358 documents with 9928 features
# Found 13354 non-empty documents
# Computing background frequencies
# Min/max word counts in training data: 6 3619
# Network architecture:
# embedding_dim: 300
# n_topics: 11
# vocab_size: 9928
# label_type: None
# n_labels: 0
# n_prior_covars: 0
# n_topic_covars: 0
# l1_beta_reg: 0.0
# l1_beta_c_reg: 0.0
# l1_beta_ci_reg: 0.0
# l2_prior_reg: 0.0
# classifier_layers: 1
# use_interactions: False
# Optimizing full model
# Epoch: 10 cost= 370.302860705
# Epoch: 20 cost= 360.696676682
# Epoch: 30 cost= 354.437348185
# Epoch: 40 cost= 355.238721412
# Epoch: 50 cost= 363.063604867
# Epoch: 60 cost= 358.248087809
# Epoch: 70 cost= 363.355138921
# Epoch: 80 cost= 362.888642751
# Epoch: 90 cost= 361.025805357
# Epoch: 100 cost= 364.651548218
# Epoch: 110 cost= 354.797174974
# Epoch: 120 cost= 365.031656377
# Epoch: 130 cost= 359.291487781
# Epoch: 140 cost= 360.813845991
# Epoch: 150 cost= 362.092656377
# Epoch: 160 cost= 356.612863008
# Epoch: 170 cost= 361.017826087
# Epoch: 180 cost= 355.297340118
# Epoch: 190 cost= 349.174198541
# Background frequencies of top words:
# body eating food eat cup chocolate new take work last
# [0.00562901 0.00532727 0.00466155 0.00393051 0.00378586 0.00264419
#  0.00249176 0.00246221 0.00240932 0.00235644]
# Topics:
# 0: #findedhelp #yourpathtorecovery #eatingdisorder laurieyurchuck #quoteoftheweek #yougotthis #allianceforeda #mentalhealth  / vegan salt ingredients powder protein oven #vegans sea ; sparsity=0.0000
# 1: nodded session rupture uh therapy avoidant skype hmm  / vegan #vegans sea #whatveganseat olive #thefeedfeed coconut #foodgrams ; sparsity=0.0000
# 2: pepper onion sauté cauliflower veggies onions mushrooms broccoli  / #chocolate #thefeedfeedbaking wet grease loaf #veganbaking #bananabread pinch ; sparsity=0.0000
# 3: #lowfat #rt #freeleethebananagirl #carbthefuckup #hclf #rawtil #veganism #freelee  / grease sugar dry wet weight uniform batter pinch ; sparsity=0.0000
# 4: ur ppl urself rly fuck fucking abt shit  / sea salt #wellness #vegans #whatveganseat #fitness maple #foodie ; sparsity=0.0000
# 5: #nobake #cookiedough nuzest_usa scoops freezer maca dough healthful_radiance  / onion kale onions broccoli #dinner sauté tomatoes disorders ; sparsity=0.0000
# 6: #hollygoessolo thailand travelling vlogs australia narnastore veganmutti vlog  / #glutenfree disorders #grainfree #thefeedfeed disorder #vegans #paleo #foodgrams ; sparsity=0.0001
# 7: #expectationvsreality #instagramvsreality #selftalk cellulite #selfesteem #bodyimagemovement #bodyimagehealing #dontcompare  / powder #vegans oil #whatveganseat #paleo olive #grainfree #thefeedfeed ; sparsity=0.0000
# 8: coaching giveaway flourish alliancefored dm est allianceforeatingdisorders partnering  / #mbg #grainfree #paleo #whatveganseat #thefeedfeed #foodgrams #plantpower #vegans ; sparsity=0.0000
# 9: grease loaf diced #dinner wet pinch icing #vegandinner  / weight disorder gain #lowfat #rt #freeleethebananagirl #carbthefuckup #compassion ; sparsity=0.0000
# 10: gin sofa slept prosecco inpatient jigsaw stitch takeaway  / #thenewhealth #healthy #healthylife #healthymeals #cleaneats #glutenfree #foodie #healthyinspo ; sparsity=0.0000
# sparsity in topics = 0.0000
# Saving document representations
# Load NPMI coherence DB.
# Number of keys : 2310143
# skipping 0.12 missed term-pairs < allowed misses = 0.25
# Loading data
# Loaded 13358 documents with 9928 features
# Found 13354 non-empty documents
# Computing background frequencies
# Min/max word counts in training data: 6 3619
# Network architecture:
# embedding_dim: 300
# n_topics: 11
# vocab_size: 9928
# label_type: None
# n_labels: 0
# n_prior_covars: 0
# n_topic_covars: 0
# l1_beta_reg: 0.0
# l1_beta_c_reg: 0.0
# l1_beta_ci_reg: 0.0
# l2_prior_reg: 0.0
# classifier_layers: 1
# use_interactions: False
# Optimizing full model
# Epoch: 10 cost= 363.291370117
# Epoch: 20 cost= 364.558892609
# Epoch: 30 cost= 363.647625934
# Epoch: 40 cost= 361.875615928
# Epoch: 50 cost= 362.878715512
# Epoch: 60 cost= 359.874338787
# Epoch: 70 cost= 359.155001947
# Epoch: 80 cost= 359.868067989
# Epoch: 90 cost= 356.432273171
# Epoch: 100 cost= 359.356646490
# Epoch: 110 cost= 360.716011490
# Epoch: 120 cost= 360.746067442
# Epoch: 130 cost= 361.216529022
# Epoch: 140 cost= 354.058587881
# Epoch: 150 cost= 359.907073997
# Epoch: 160 cost= 358.956552220
# Epoch: 170 cost= 362.186646586
# Epoch: 180 cost= 356.139548032
# Epoch: 190 cost= 359.514762921
# Background frequencies of top words:
# body eating food eat cup chocolate new take work last
# [0.00562901 0.00532727 0.00466155 0.00393051 0.00378586 0.00264419
#  0.00249176 0.00246221 0.00240932 0.00235644]
# Topics:
# 0: #oatporn #smoothie nibs nuzest_usa maca healthful_radiance #vegansmoothie #chocolateoats  / #carbthefuckup #rawtil #veganism #freelee #rt #lowfat #compassion #freeleethebananagirl ; sparsity=0.0000
# 1: grease preheat icing mixer cooled powdered slicing granulated  / social journey thoughts weight started gain struggle towards ; sparsity=0.0000
# 2: #carbthefuckup #rawtil #veganism #freelee #rt #lowfat #freeleethebananagirl #hclf  / #thefeedfeed #paleo #foodgrams #grainfree #cleaneats #mbg #thenewhealth #healthymeals ; sparsity=0.0000
# 3: nodded session uh skype rupture therapy replied texted  / #edrecovery vegan #fitness #mentalhealth #recovery #allianceforeda #healthy almond ; sparsity=0.0000
# 4: #instagramvsreality #expectationvsreality cellulite #selfesteem #bekindtoyourmind #bodyimagemovement #selfconfidence #dontcompare  / syrup powder milk #vegan vegan oven #plantbased coconut ; sparsity=0.0000
# 5: fucking fuck tw rn shit thru ass rly  / #fitness #edrecovery maple #healthy #wellness sea #healthylife #recovery ; sparsity=0.0000
# 6: sauté cumin browned fragrant simmer onion #dinner #veggies  / #allianceforeda selected #yourpathtorecovery #findedhelp #mentalhealth gain #edwarrior weight ; sparsity=0.0000
# 7: #quoteoftheweek laurieyurchuck #inspirationalquotes #quotes selected #yourpathtorecovery #findedhelp #yougotthis  / #thefeedfeed #paleo #plantpower #vegan #thenewhealth #fitness #whatveganseat #plantbased ; sparsity=0.0000
# 8: coaching purpose limiting flourish amandavsevilla bi freedom intuitive  / #paleo #foodgrams #grainfree #thefeedfeed #healthy #cleaneats #glutenfree #fitness ; sparsity=0.0000
# 9: allianceforeatingdisorders alliancefored alliance #eatingdisordersawarenessweek #itstimeforchange #edaw #notonemore partnering  / vanilla powder smooth eggs syrup breakfast fridge chips ; sparsity=0.0000
# 10: tags blogs pro ana thinspo ppl butimpissed imtrying  / #fitness #plantbased #healthy #edrecovery #veganfood #carbthefuckup #rawtil #veganism ; sparsity=0.0000
# sparsity in topics = 0.0000
# Saving document representations
# Load NPMI coherence DB.
# Number of keys : 2310143
# skipping 0.13 missed term-pairs < allowed misses = 0.25
#
#
# Running SCHOLAR with 12 topics and other details as below:
# {'name': 'scholar', 'output_dir': './result/scholar_output/', 'save_flag': False}
# Loading data
# Loaded 13358 documents with 9928 features
# Found 13354 non-empty documents
# Computing background frequencies
# Min/max word counts in training data: 6 3619
# Network architecture:
# embedding_dim: 300
# n_topics: 12
# vocab_size: 9928
# label_type: None
# n_labels: 0
# n_prior_covars: 0
# n_topic_covars: 0
# l1_beta_reg: 0.0
# l1_beta_c_reg: 0.0
# l1_beta_ci_reg: 0.0
# l2_prior_reg: 0.0
# classifier_layers: 1
# use_interactions: False
# Optimizing full model
# Epoch: 10 cost= 368.692228675
# Epoch: 20 cost= 367.462740491
# Epoch: 30 cost= 364.485204336
# Epoch: 40 cost= 355.282843240
# Epoch: 50 cost= 358.841087269
# Epoch: 60 cost= 356.347807535
# Epoch: 70 cost= 359.555847616
# Epoch: 80 cost= 363.624697759
# Epoch: 90 cost= 356.170318818
# Epoch: 100 cost= 362.349876551
# Epoch: 110 cost= 359.763062291
# Epoch: 120 cost= 358.248360671
# Epoch: 130 cost= 352.695581523
# Epoch: 140 cost= 358.502519033
# Epoch: 150 cost= 359.084751186
# Epoch: 160 cost= 356.299940597
# Epoch: 170 cost= 352.604885767
# Epoch: 180 cost= 355.788329877
# Epoch: 190 cost= 357.147442125
# Background frequencies of top words:
# body eating food eat cup chocolate new take work last
# [0.00562901 0.00532727 0.00466155 0.00393051 0.00378586 0.00264419
#  0.00249176 0.00246221 0.00240932 0.00235644]
# Topics:
# 0: foster sofa vaccine government inpatient babies cot fostering  / protein powder almond maple cacao vanilla tbsp frozen ; sparsity=0.0000
# 1: sauté diced fragrant cumin onion browned #vegandinner #dinner  / #carbthefuckup #veganfitness #freeleethebananagirl #lowfat #freelee #rawtil #compassion #veganism ; sparsity=0.0000
# 2: grease mixer cooled slicing pinch icing batter preheat  / #carbthefuckup #veganfitness #freeleethebananagirl #lowfat #freelee #rawtil #compassion #crueltyfree ; sparsity=0.0000
# 3: giveaway macrmike amb macro winner entries announced #macromike  / #grainfree #paleo #thefeedfeed #vegans #cleaneats #thenewhealth #whatveganseat #foodgrams ; sparsity=0.0000
# 4: alliancefored allianceforeatingdisorders fireside alliance founder partnering ceo #eatingdisordersawarenessweek  / powder fridge smooth sea splash mix tbsp blend ; sparsity=0.0000
# 5: coaching flourish amandavsevilla bi purpose limiting application dm  / powder protein #glutenfree creamy disorders blend tbsp #foodie ; sparsity=0.0000
# 6: nodded session uh rupture therapy childhood skype replied  / vegan seeds cacao milk syrup coconut almond bio ; sparsity=0.0000
# 7: cellulite #instagramvsreality #expectationvsreality #selfconfidence #bodyimagemovement #selfesteemboost #bodyimagehealing #selfesteem  / powder milk syrup tbsp flax seeds flavor cacao ; sparsity=0.0000
# 8: #carbthefuckup #veganfitness #freeleethebananagirl #lowfat #freelee #rawtil #veganism #hclf  / grease wet preheat sugar comfortable normal cool set ; sparsity=0.0000
# 9: laurieyurchuck #quoteoftheweek #findedhelp #yourpathtorecovery #inspirationalquotes #allianceforeda #quotes #yougotthis  / milk soaked protein frozen almond salt top seeds ; sparsity=0.0000
# 10: deats abbysbetter #deats chicken kodiakcakes whites hungry pizza  / #cleaneats #paleo #thenewhealth #mbg #foodgrams #grainfree #thefeedfeed #fitness ; sparsity=0.0000
# 11: ppl ur yal rly fuckin yano urself fucking  / #edrecovery maple recipe sea #recovery coconut cacao almond ; sparsity=0.0000
# sparsity in topics = 0.0000
# Saving document representations
# Load NPMI coherence DB.
# Number of keys : 2310143
# skipping 0.09 missed term-pairs < allowed misses = 0.25
# Loading data
# Loaded 13358 documents with 9928 features
# Found 13354 non-empty documents
# Computing background frequencies
# Min/max word counts in training data: 6 3619
# Network architecture:
# embedding_dim: 300
# n_topics: 12
# vocab_size: 9928
# label_type: None
# n_labels: 0
# n_prior_covars: 0
# n_topic_covars: 0
# l1_beta_reg: 0.0
# l1_beta_c_reg: 0.0
# l1_beta_ci_reg: 0.0
# l2_prior_reg: 0.0
# classifier_layers: 1
# use_interactions: False
# Optimizing full model
# Epoch: 10 cost= 374.896048271
# Epoch: 20 cost= 365.245241031
# Epoch: 30 cost= 362.424518699
# Epoch: 40 cost= 358.412910611
# Epoch: 50 cost= 356.067624906
# Epoch: 60 cost= 361.944867566
# Epoch: 70 cost= 362.933925042
# Epoch: 80 cost= 360.223837957
# Epoch: 90 cost= 355.230284173
# Epoch: 100 cost= 357.147792686
# Epoch: 110 cost= 356.789933976
# Epoch: 120 cost= 361.986797356
# Epoch: 130 cost= 364.276075513
# Epoch: 140 cost= 362.426240426
# Epoch: 150 cost= 362.249100899
# Epoch: 160 cost= 360.193148069
# Epoch: 170 cost= 355.174982317
# Epoch: 180 cost= 360.043585884
# Epoch: 190 cost= 357.650682336
# Background frequencies of top words:
# body eating food eat cup chocolate new take work last
# [0.00562901 0.00532727 0.00466155 0.00393051 0.00378586 0.00264419
#  0.00249176 0.00246221 0.00240932 0.00235644]
# Topics:
# 0: thailand #hollygoessolo travelling vlogs narnastore vlog australia holly  / maple syrup disorders vanilla tbsp #foodie #glutenfree disorder ; sparsity=0.0000
# 1: sauté diced browned fragrant cumin onion broth #dinner  / #compassion #veganfitness #veganism #freelee #freeleethebananagirl #rawtil #rt #hclf ; sparsity=0.0000
# 2: tags inpatient blogs staff pro tms ect unit  / almond coconut maple tbsp cacao syrup sea recipe ; sparsity=0.0000
# 3: binge gain cues restriction restricting weight gaining binging  / sea splash blend thick details #healthyrecipe flax #thefeedfeed ; sparsity=0.0000
# 4: yal ur rly ppl weed fuckin yano urself  / salt tbsp #fitness #glutenfree cacao recipe #foodie alliance ; sparsity=0.0000
# 5: #veganfitness #veganism #freelee #freeleethebananagirl #rawtil #rt #hclf #lowfat  / grease bree disorders wet preheat sugar weight amb ; sparsity=0.0000
# 6: nodded session uh rupture therapy skype replied texted  / vegan powder seeds protein almond plant tbsp coconut ; sparsity=0.0000
# 7: #quoteoftheweek laurieyurchuck #findedhelp #yourpathtorecovery #edfighter #prorecovery #allianceforeda #eatingdisorder  / used protein milk plant powder almond frozen salt ; sparsity=0.0000
# 8: grease icing slicing batter pinch cooled loaf tin  / #veganfitness #compassion #veganism #freelee #freeleethebananagirl #rawtil #rt #veganfood ; sparsity=0.0000
# 9: coaching fireside candid alliancefored allianceforeatingdisorders founder amandavsevilla flourish  / powder tbsp thick sweet slices fridge sea blend ; sparsity=0.0000
# 10: macrmike amb choc #macromike bree giveaway deats #deats  / #thenewhealth #paleo #fitness #grainfree #cleaneats #mbg #thefeedfeed #foodgrams ; sparsity=0.0000
# 11: #expectationvsreality cellulite #instagramvsreality #bodyimagemovement #dontcompare #selfconfidence #bekindtoyourmind #selfesteem  / seeds rice powder tbsp allianceforeatingdisorders #vegan bowl #glutenfree ; sparsity=0.0001
# sparsity in topics = 0.0000
# Saving document representations
# Load NPMI coherence DB.
# Number of keys : 2310143
# skipping 0.08 missed term-pairs < allowed misses = 0.25
#
#
# Running SCHOLAR with 13 topics and other details as below:
# {'name': 'scholar', 'output_dir': './result/scholar_output/', 'save_flag': False}
# Loading data
# Loaded 13358 documents with 9928 features
# Found 13354 non-empty documents
# Computing background frequencies
# Min/max word counts in training data: 6 3619
# Network architecture:
# embedding_dim: 300
# n_topics: 13
# ...
# 9: inpatient staff slept ect headache woke tms anxious  / tbsp #fitness olive #mbg stir #healthyfood #glutenfree coconut ; sparsity=0.0000
# 10: #expectationvsreality #bodyimagemovement #instagramvsreality cellulite #bodyimagehealing #bodyacceptance #bekindtoyourmind #selftalk  / powder syrup vanilla tbsp maple #vegan coconut #glutenfree ; sparsity=0.0000
# 11: virtual individuals register led est groups alliance join  / #healthy trying #fitness #vegan salt top powder milk ; sparsity=0.0000
# 12: talked scales mum behaviours adult child weight weigh  / vegan recipe #wellness #healthy favorite #fitness sea tbsp ; sparsity=0.0000
# 13: blake grace joy grateful moments gratitude peace feelings  / #vegan #glutenfree #healthymeals splash bake #cleaneats #plantbased #grainfree ; sparsity=0.0000
# 14: #thefeedfeedbaking processor loaf wet greased batter grease flour  / journey understand disorder struggle thoughts young body started ; sparsity=0.0000
# 15: #edwarrior #prorecovery #edfighter #thealliance #eatingdisorders #keepgoing #support #eatingdisorderrecovery  / used #healthymeals #healthylife bowl #healthyfood #healthyinspo ingredients #cleaneats ; sparsity=0.0000
# 16: yal fuckin rn rly lmao ass ur bc  / salt cup #healthy maple #wellness vanilla sea #fitness ; sparsity=0.0000
# 17: macrmike amb giveaway bree choc #macromike winner announced  / #plantpower #healthyinspo #grainfree #paleo #whatveganseat #foodgrams ground #thefeedfeed ; sparsity=0.0000
# 18: #hollygoessolo thailand holly whilst travelling australia london vlog  / #healthy #wellness #fitness maple #healthylife #foodie #foodblogger syrup ; sparsity=0.0000
# 19: covid uk government vaccine foster schools hospital isolating  / salt powder oil #healthy coconut #wellness maple #fitness ; sparsity=0.0000
# 20: yoga solo #solodate #rishikesh #travel #selfcare india date  / salt vanilla #healthy maple tbsp #foodie syrup #glutenfree ; sparsity=0.0000
# 21: session nodded therapy sessions talked talking asked uh  / sea powder maple #healthy vegan salt syrup #wellness ; sparsity=0.0000
# 22: #toasttuesday #toastsforall #vegetarian avo #buddhabowl #hummus garlicky kitehillfoods  / smooth transfer combined stir forms cups seem #allianceforeda ; sparsity=0.0000
# 23: chicken pepper mushrooms corn spinach pasta cheese fried  / #healthy #healthyfood #healthylife #wellness #healthyinspo #glutenfree #foodie #fitness ; sparsity=0.0000
# 24: channel lemonem_ily vlog video mutti cambridge holly ps  / cup salt tbsp ground thick body vanilla olive ; sparsity=0.0000
# 25: trauma treatment center informed destructive protective pain compassion  / milk mix syrup #healthy coconut #fitness powder tbsp ; sparsity=0.0000
# 26: foods lifestyle sustainable healthier nutritious loss diets #foodfreedom  / sea #plantpower #paleo splash #foodgrams #foodblogger pour #thefeedfeed ; sparsity=0.0000
# 27: maca nibs #smoothie #oatporn scoops blueberries nuzest_usa #healthyrecipe  / understand important often journey lives although wanted normal ; sparsity=0.0000
# 28: ice cream cake slice caramel pizza mitchellsicecream eaten  / #healthy #fitness #glutenfree #thenewhealth #healthyinspo #cleaneats #plantpower #grainfree ; sparsity=0.0000
# 29: #dinner #veganmeal #healthylunch #recipes #veggies #savory #fallrecipe #mealinspo  / thoughts scary disorder struggling human matter hard care ; sparsity=0.0000
# 30: photos #instagramvsreality media instagram #bekindtoyourself #loveyourself #realme #reality  / milk powder oil coconut maple #healthylife butter bowl ; sparsity=0.0000
# 31: floor car cardigan driving houses dylan feet sky  / recipe tbsp #fitness maple syrup #healthyfood creamy #glutenfree ; sparsity=0.0000
# 32: recover recovery disorder recovering linear anorexia heal toxic  / powder cup tbsp blend #foodgrams #thefeedfeed syrup flour ; sparsity=0.0001
# 33: thankyou anon therapist tumblr hi message therapists therapy  / body bowl ingredients maple syrup vanilla chips coconut ; sparsity=0.0000
# 34: tw binge hungry stomach fuck fucking junk hunger  / sea #wellness maple #healthy #fitness #foodie #healthylife #vegan ; sparsity=0.0000
# 35: sauté cumin onion diced browned boil stirring generous  / chocolate #chocolate taken physical cacao struggling although lives ; sparsity=0.0000
# 36: #baking directions uniform #recipe #dessert preheat cooled dough  / maybe understand thoughts etc disorder struggle meals journey ; sparsity=0.0000
# sparsity in topics = 0.0000
# Saving document representations
# Load NPMI coherence DB.
# Number of keys : 2311757
# skipping 0.23 missed term-pairs < allowed misses = 0.25
# Loading data
# Loaded 13358 documents with 9928 features
# Found 13354 non-empty documents
# Computing background frequencies
# Min/max word counts in training data: 6 3619
# Network architecture:
# embedding_dim: 300
# n_topics: 37
# vocab_size: 9928
# label_type: None
# n_labels: 0
# n_prior_covars: 0
# n_topic_covars: 0
# l1_beta_reg: 0.0
# l1_beta_c_reg: 0.0
# l1_beta_ci_reg: 0.0
# l2_prior_reg: 0.0
# classifier_layers: 1
# use_interactions: False
# Optimizing full model
# Epoch: 10 cost= 377.727408564
# Epoch: 20 cost= 368.071822812
# Epoch: 30 cost= 365.759695092
# Epoch: 40 cost= 368.219603852
# Epoch: 50 cost= 361.803492611
# Epoch: 60 cost= 364.428704539
# Epoch: 70 cost= 359.524029716
# Epoch: 80 cost= 366.234950268
# Epoch: 90 cost= 360.986131591
# Epoch: 100 cost= 366.783496079
# Epoch: 110 cost= 364.350955330
# Epoch: 120 cost= 368.038944086
# Epoch: 130 cost= 365.422586690
# Epoch: 140 cost= 368.782290952
# Epoch: 150 cost= 371.038983356
# Epoch: 160 cost= 369.170417231
# Epoch: 170 cost= 364.933003747
# Epoch: 180 cost= 361.883678839
# Epoch: 190 cost= 364.211847826
# Background frequencies of top words:
# body eating food eat cup chocolate new take work last
# [0.00562901 0.00532727 0.00466155 0.00393051 0.00378586 0.00264419
#  0.00249176 0.00246221 0.00240932 0.00235644]
# Topics:
# 0: #pasta #veganfood #nature #carbs #compassion #veganism #freeleethebananagirl #rawtil  / tbsp powder cup smooth although set rather vanilla ; sparsity=0.0000
# 1: #thefeedfeedbaking processor greased batter flour runny flax #veganbaking  / thoughts understand journey helps etc recently body constantly ; sparsity=0.0000
# 2: tags pro triggering recovery blogs ed imtrying butimpissed  / bowl maple coconut #healthy #wellness #fitness milk sea ; sparsity=0.0000
# 3: #toasttuesday kitehillfoods #toastsforall avo #avocado garlicky #vegetarian #vegans  / #reels transfer heard although uniform smooth stir within ; sparsity=0.0000
# 4: behaviors disorder pain relationships trauma toxic destructive deeply  / powder tbsp vanilla #thefeedfeed blend #foodgrams #glutenfree cup ; sparsity=0.0000
# 5: sauté onion diced cumin stirring boil cook browned  / story lives physical choose live whether understand struggle ; sparsity=0.0000
# 6: #dinner #healthylunch #veggies #veganmeal dressing toss hummus #grainbowl  / vanilla cacao struggle although lives learning given #edrecovery ; sparsity=0.0000
# 7: chicken pepper pizza cheese pasta corn plant mozzarella  / #fitness #mbg #thenewhealth #paleo #grainfree #cleaneats #foodgrams #thefeedfeed ; sparsity=0.0000
# 8: child therapist childhood parents therapists learnt adult therapy  / powder butter #wellness #healthy vegan syrup sea #fitness ; sparsity=0.0000
# 9: allianceforeatingdisorders plant disorders alliancefored resources partnering com nutrition  / #healthy #fitness #plantpower #mbg fridge #foodie #wellness #healthylife ; sparsity=0.0000
# 10: inpatient staff unit hospital ect tms covid slept  / powder milk salt oil cup maple #fitness #healthy ; sparsity=0.0000
# 11: session nodded talked talking uh therapy asked faith  / sea maple #healthy #fitness #wellness #foodie #foodblogger #healthylife ; sparsity=0.0001
# 12: art hair dog depressed witcher lay sleep drink  / syrup maple recipe #glutenfree #thefeedfeed tbsp #healthyfood #foodgrams ; sparsity=0.0000
# 13: founder register candid ceo tap johannakandel est fireside  / sit fridge smooth thick #fitness lot #foodie vanilla ; sparsity=0.0001
# 14: solo #selfcare #solodate mirror #selflove appearance wear #expectationvsreality  / #vegan syrup salt #glutenfree #healthymeals maple #healthyfood #cleaneats ; sparsity=0.0000
# 15: maca #smoothie nuzest_usa scoops #oatporn nibs blueberries healthful_radiance  / eggs normal family although understand told sad experienced ; sparsity=0.0000
# 16: skinny gain weight fucking lose fuck gained thin  / #wellness salt #healthy cup #foodie #healthylife powder sea ; sparsity=0.0000
# 17: travelling holly thailand #hollygoessolo australia vlogs whilst vlog  / #healthy #fitness #wellness maple syrup #foodie #healthylife vanilla ; sparsity=0.0000
# 18: dylan lemonem_ily vlog photo birthday holly channel camera  / syrup powder vanilla maple tbsp #plantbased #foodie #foodblogger ; sparsity=0.0000
# 19: deats collagen sliced topped chia pancakes granola kodiakcakes  / #healthy #fitness #glutenfree #foodie #healthyinspo #healthylife #foodgrams #thefeedfeed ; sparsity=0.0000
# 20: lovely sofa baby evening gin till cafe stitch  / #healthy #fitness #vegan powder #wellness #foodblogger #foodie #glutenfree ; sparsity=0.0000
# 21: rn ass fuckin money weed thru plants fucking  / salt #wellness #healthy #fitness sea #foodie #foodblogger cup ; sparsity=0.0000
# 22: allianceforeatingdisorders com individuals resources alliance national alliancefored #itstimeforchange  / used vegan milk ingredients butter felt trying powder ; sparsity=0.0000
# 23: hungry binge hunger ate tw snacks meals lunch  / #wellness #fitness #healthy sea #healthylife #vegan #foodblogger #healthyinspo ; sparsity=0.0000
# 24: #veganism #freeleethebananagirl #rawtil #hclf #lowfat #freelee #veganfitness #carbthefuckup  / #glutenfree #healthylife #wellness #healthyinspo #foodblogger #healthyfood #cleaneats #healthymeals ; sparsity=0.0000
# 25: deserve grace okay worthy reminder joy gentle struggles  / ingredients #wellness #healthy #fitness #vegan #foodie #healthylife blend ; sparsity=0.0000
# 26: coaching purpose dm program amandavsevilla flourish clients limiting  / sea powder #glutenfree #healthyfood tbsp #thefeedfeed #healthymeals sweet ; sparsity=0.0000
# 27: uniform #baking directions preheat #recipe cooled #dessert slicing  / etc maybe understand thoughts disorder although journey learning ; sparsity=0.0000
# 28: run running marathon training foster babies lockdown fostering  / maple #glutenfree #foodie #foodblogger vanilla #grainfree #healthyfood #paleo ; sparsity=0.0000
# 29: ur ppl rly yal abt tho bitch bc  / maple mix #healthy #fitness sea bowl #wellness ingredients ; sparsity=0.0000
# 30: #eatingdisorder #findedhelp #yourpathtorecovery #allianceforeda #quoteoftheweek #mentalhealth #edwarrior laurieyurchuck  / used salt ingredients smooth thick oil felt #vegan ; sparsity=0.0000
# 31: freedom gain foods lifestyle #foodfreedom sustainable guilt weight  / #paleo #plantpower sea #glutenfree #plantbased #thefeedfeed blend #foodgrams ; sparsity=0.0001
# 32: macrmike amb bree giveaway #macromike choc macro announced  / #paleo #plantpower #grainfree #foodgrams #mbg #healthyinspo #thefeedfeed #whatveganseat ; sparsity=0.0000
# 33: god #rishikesh #travel #yoga voice #applesandamandas #rishikeshdiaries words  / syrup recipe coconut #plantpower #healthy #fitness milk #glutenfree ; sparsity=0.0000
# 34: therapist session thankyou therapy anon text replied whatsapp  / vegan milk serve smooth bowl almond thick maple ; sparsity=0.0000
# 35: ice cream cleveland caramel blake mitchellsicecream coffee drinks  / #healthy #fitness #glutenfree #healthyinspo #foodie #grainfree #healthyfood #cleaneats ; sparsity=0.0000
# 36: #instagramvsreality #expectationvsreality #bodyimagemovement cellulite #selftalk #beautystandards #bodyacceptance #bekindtoyourself  / powder cup maple oil #foodblogger syrup coconut #plantpower ; sparsity=0.0000
# sparsity in topics = 0.0000
# Saving document representations
# Load NPMI coherence DB.
# Number of keys : 2311757
# skipping 0.21 missed term-pairs < allowed misses = 0.25
#
#
# Running SCHOLAR with 38 topics and other details as below:
# {'name': 'scholar', 'output_dir': './result/scholar_output/', 'save_flag': False}
# Loading data
# Loaded 13358 documents with 9928 features
# Found 13354 non-empty documents
# Computing background frequencies
# Min/max word counts in training data: 6 3619
# Network architecture:
# embedding_dim: 300
# n_topics: 38
# vocab_size: 9928
# label_type: None
# n_labels: 0
# n_prior_covars: 0
# n_topic_covars: 0
# l1_beta_reg: 0.0
# l1_beta_c_reg: 0.0
# l1_beta_ci_reg: 0.0
# l2_prior_reg: 0.0
# classifier_layers: 1
# use_interactions: False
# Optimizing full model
# Epoch: 10 cost= 380.776248993
# Epoch: 20 cost= 368.577758734
# Epoch: 30 cost= 363.540212926
# Epoch: 40 cost= 367.584490865
# Epoch: 50 cost= 369.337451724
# Epoch: 60 cost= 360.904434796
# Traceback (most recent call last):
#   File "./scholar/run_scholar.py", line 954, in <module>
#     main(sys.argv[1:])
#   File "./scholar/run_scholar.py", line 332, in main
#     model = train(model, network_architecture, train_X, train_labels, train_prior_covars, train_topic_covars, training_epochs=options.epochs, batch_size=options.batch_size, rng=rng, X_dev=dev_X, Y_dev=dev_labels, PC_dev=dev_prior_covars, TC_dev=dev_topic_covars)
#   File "./scholar/run_scholar.py", line 598, in train
#     batch_xs, batch_ys, batch_pcs, batch_tcs = next(mb_gen)
#   File "./scholar/run_scholar.py", line 679, in create_minibatch
#     X_mb = np.array(X[ixs, :].todense()).astype('float32')
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /share/ceph/scratch/amh418/10956964/ipykernel_3515721/1657203308.py in <cell line: 18>()
#     220             for _ in range(2): #two runs and then average
#     221                 #running SCHOLAR
# --> 222                 subprocess.run(["python", "./scholar/run_scholar.py","./data/","-k {0}".format(n_topics),
#     223                                 "-o","{0}".format(model_spec['output_dir']),"--epochs","200"])#'--topic-covars',"pl_auth", ,"-m","0.95"
#     224                 #initializing scorer
#
# /share/Apps/anaconda3/2020.07/envs/nlp/lib/python3.8/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     489     with Popen(*popenargs, **kwargs) as process:
#     490         try:
# --> 491             stdout, stderr = process.communicate(input, timeout=timeout)
#     492         except TimeoutExpired as exc:
#     493             process.kill()
#
# /share/Apps/anaconda3/2020.07/envs/nlp/lib/python3.8/subprocess.py in communicate(self, input, timeout)
#    1014                 stderr = self.stderr.read()
#    1015                 self.stderr.close()
# -> 1016             self.wait()
#    1017         else:
#    1018             if timeout is not None:
#
# /share/Apps/anaconda3/2020.07/envs/nlp/lib/python3.8/subprocess.py in wait(self, timeout)
#    1077             endtime = _time() + timeout
#    1078         try:
# -> 1079             return self._wait(timeout=timeout)
#    1080         except KeyboardInterrupt:
#    1081             # https://bugs.python.org/issue25942
#
# /share/Apps/anaconda3/2020.07/envs/nlp/lib/python3.8/subprocess.py in _wait(self, timeout)
#    1802                         if self.returncode is not None:
#    1803                             break  # Another thread waited.
# -> 1804                         (pid, sts) = self._try_wait(0)
#    1805                         # Check the pid and loop as waitpid has been known to
#    1806                         # return 0 even without WNOHANG in odd situations.
#
# /share/Apps/anaconda3/2020.07/envs/nlp/lib/python3.8/subprocess.py in _try_wait(self, wait_flags)
#    1760             """All callers to this function MUST hold self._waitpid_lock."""
#    1761             try:
# -> 1762                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1763             except ChildProcessError:
#    1764                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %%
import seaborn as sns
df = pd.DataFrame(npmis,columns=['n_topics','npmi_average'])
# df = pd.concat([df,pd.DataFrame(npmis,columns=['n_topics','npmi_average'])])

sns.lineplot(data=df,x='n_topics',y='npmi_average')

# df.to_csv('./result/npmi_{0}{1}{2}.csv'.format(model_spec['name'],model_spec['prevalence'],
#                                               model_spec['content']))

df.to_csv('./result/npmi_{0}_no_covar.csv'.format(model_spec['name']))

# %%
# df = pd.read_csv('./result/npmi_bertopic.csv')
# df = pd.concat([df,pd.read_csv('./result/npmi_bertopic_31_40.csv')])
# sns.lineplot(data=df,x='n_topics',y='npmi_average')
# Out:
# <AxesSubplot:xlabel='n_topics', ylabel='npmi_average'>

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                         Name  \
# 0      -1   5640                  -1_yourself_life_being_feel
# 1       0   4169                    0_therapy_eating_feel_eat
# 2       1   1070                       1_recovery_work_run_am
# 3       2    763                    2_travel_happy_going_feel
# 4       3    735              3_hospital_inpatient_going_care
# 5       4    495  4_eatingdisorders_eating_disorders_disorder
# 6       5    276                5_instagram_blog_tumblr_being
# 7       6    135                    6_reading_book_books_read
# 8       7     27                  7_summer_warm_bikini_warmer
# 9       8     26           8_college_school_toschool_studying
# 10      9     13       9_houses_neighbours_terraces_bungalows
# 11     10     11      10_skincare_moisturizer_lotion_cleanser
#
#                                        Representation  \
# 0   [yourself, life, being, feel, eat, myself, goi...
# 1   [therapy, eating, feel, eat, healthy, her, be,...
# 2   [recovery, work, run, am, be, being, yourself,...
# 3   [travel, happy, going, feel, life, hope, you, ...
# 4   [hospital, inpatient, going, care, go, be, bab...
# 5   [eatingdisorders, eating, disorders, disorder,...
# 6   [instagram, blog, tumblr, being, blogs, social...
# 7   [reading, book, books, read, writing, kindle, ...
# 8   [summer, warm, bikini, warmer, cold, hot, temp...
# 9   [college, school, toschool, studying, major, u...
# 10  [houses, neighbours, terraces, bungalows, hous...
# 11  [skincare, moisturizer, lotion, cleanser, skin...
#
#                                   Representative_Docs
# 0   [Tw! Exercise stuff So, for my recovery i star...
# 1   [Therapy .. // the relationship > everything e...
# 2   [picture this: ☕️you're minding your own busin...
# 3   [So we've been opening up A LOT recently on th...
# 4   [This self quarantine is hard and I really mis...
# 5   [In honor of #MentalHealthAwarenessMonth, it i...
# 6   [last night i caught myself starting to go dow...
# 7   [Throwback to an outback sunrise and the clear...
# 8   [When we were in the desert, we had a whole co...
# 9   [Question: What are you gonna do about school?...
# 10  [Question: We do have semi-attached homes in t...
# 11  [*clean hands only*\n_______\ni've been pretty...

# %% [markdown]
# # Post-processing

# %% [markdown]
# topic distribution and topic selection
#
# for topic selection I used elbow method (selecting top topics till we get to the highest gap)

# %%
#topic selection
topics4docs,topics4docs_bin = topic_selection(topic_doc_dist)

#topic distribution addition
for i in range(topic_doc_dist.shape[1]):
    text_df['Topic{0}_dist'.format(i)] = topic_doc_dist[:,i]
#topic selection addition
for i in range(topic_doc_dist.shape[1]):
    text_df['Topic{0}_select'.format(i)] = topics4docs_bin[:,i]

#saving data to csv
text_df.to_csv('document_topic_info.csv')

# %%
#storing top terms
topic_df = pd.DataFrame(data=top_terms,columns=['top_terms'])
topic_df.to_csv('topic_terms.csv')

# %% [markdown]
# Running Coherence

# %%
from lda_mallet import lda_score
import pickle

# import importlib
# importlib.reload(scorer.score_per_topic(None))

#initiate scorer
scorer = lda_score(wiki_path='./data/wiki_sampled_5p.txt',db_path='./data/wiki_full/',npmi_skip_threshold=0.30)

'''
loading wikipedia vocab to 
    1. remove the top terms that are not in the wikipedia
    2. use for gensim.coherence vocab argument in case any pairs are not in the DB
'''
with open('./data/wiki_full_vocab.obj','rb') as f: #wiki_sampled5p_vocab.obj
    scorer.wiki_vocab_dict = pickle.load(f)
    
#add all_top_terms (except the ones that are not in the wiki_pedia vocab)
scorer.all_top_terms = [[t for t in top_terms[i].split() if t in scorer.wiki_vocab_dict.token2id.keys()] for i in range(len(top_terms))]
#the output is a dictionary: the key is 0-n_topics and associated with npmi score for top-k topics 
#in which k=5,10,15,20
topic_scores = scorer.score_per_topic(None)
#getting avergae of multiple k for each topic
topic_score_avg = [np.mean([vi for ki,vi in v.items()]) for k,v in topic_scores.items()]
# Out:
# Load NPMI coherence DB.
# Number of keys : 1938962
# percentage of misses = 47% exceeds the threshold = 30.0%
# computing Coherence Value...

# %% [markdown]
# # scoring top terms and top documents

# %%
show_top_doc = 10
show_top_terms = 10
file_name = 'top_documents_bertopic_12_full_text.txt'

#writing the results in a text file
with open(file_name,'w') as tfile:
    if model_spec['name'] == 'bertopic':
        i = 0
        for k in repr_docs.keys():
            tfile.write('Topic '+ str(i) + ' : '+'\n'+'top terms: '+', '.join(top_terms[i].split()[:show_top_terms])+'\n')
            for txt in repr_docs[k]:
#                 tfile.write(list(text_df[text_df.text==txt].original_text)[0]+'\n')
                row = text_df[text_df.original_text==txt]
                tfile.write('Doc ID: {0}, distribution: {1} ; {2} \n'.format(list(row.id)[0],
                                                        list(row['Topic{0}_dist'.format(i)])[0],
                                                            list(row.original_text)[0]))
                tfile.write(''.join(['-']*60)+'\n')
            i+=1
    
    else:
        for i in range(len(top_terms)):
            #writing top terms
            tfile.write('Topic '+ str(i) + ' : '+'\n'+'top terms: '+', '.join(top_terms[i].split()[:show_top_terms])+'\n')
            #selecting top documents
            top_docs = text_df.sort_values('Topic{0}_dist'.format(i),ascending=False).iloc[0:show_top_doc,:]
            for _,row in top_docs.iterrows():
                tfile.write('Doc ID: {0}, distribution: {1} ; {2} \n'.format(row.id,row['Topic{0}_dist'.format(i)],row['original_text']))
                tfile.write(''.join(['-']*60)+'\n')

# %% [markdown]
# # Storing to DB

# %% [markdown]
# The process is described in the code cell below
#
# **Used the link below to insert and load blob**
#
# https://pynative.com/python-mysql-blob-insert-retrieve-file-image-as-a-blob-in-mysql/

# %%
#1. save model id (for LDA save as zip and then save)
'''
2. for each topic
    3. save topic
    4. retreive the saved topic_id and save r_topic_model
    5. for each doc save r_topic_post
'''
###table format
#model: model_id, data, model_type, last_used?
# topic: topic_id, coherence, term1-50, probab1-50
#r_topic_model: topic_id, model_id 
#r_topic_post: topic_id, post_id, proportion

##check the columns of a table
# cursor.execute("show columns from r_topic_post") #execute a command
# myresult = cursor.fetchall() #get all the results 
# myresult
# Out:
# '\n2. for each topic\n    3. save topic\n    4. retreive the saved topic_id and save r_topic_model\n    5. for each doc save r_topic_post\n'

# %%
#saving the model first
#model: model_id, data, model_type, last_used?
if model_spec['name'].lower() == 'lda':
    #read binary data of the saved model
    with open('MalletState_ '+model_spec['save_path']+' .gz','rb') as model_file:
        binary_data = model_file.read()
else:
    pass #write codes for other models

#storing the model
cursor.execute(" INSERT INTO model (data, model_type) VALUES (%s,%s)",
                    (binary_data,model_spec['name']))

# %%
#load the model with model id to use for next steps
cursor.execute("Select * from model ORDER BY model_id DESC LIMIT 1")
result = cursor.fetchall()
model_id,model_name = result[0][0],result[0][2]

# %%
#saving each topic separately alongside relation to model table and post table
for k in range(0,model_spec['K']):#iterating over each topic
    #getting topic top terms
    topic_top_terms = top_terms[k].split()
    #we have to find the index in vocab (ans[0][2]) and then call ans[0][1][k][found_index] to get
    #the probability of each term
    if model_spec['name'] == 'LDA':
        probab = [float(term_probab[k][i]) for w in topic_top_terms for i in range(len(topic_vocab)) if w == topic_vocab[i]]
    else:
        probab = term_probab[k]
    #adding coherence score, top terms and their probabilities
    vals = tuple([float(topic_score_avg[k])]) + tuple(topic_top_terms) + tuple(probab)
    #save each topic seperately
    cursor.execute(" INSERT INTO topic(coherence,{0},{1}) VALUES (%s,{2})".format(
                                        ','.join(['term'+str(i) for i in range(1,len(topic_top_terms)+1)]),
                                        ','.join(['prob'+str(i) for i in range(1,len(topic_top_terms)+1)]),
                                        ','.join(['%s']*(len(topic_top_terms)*2))),vals)
    
    '''
    retreiving saved topic_id and save an entry for topic_id,model_id in topic_model_r table
    '''
    #load the latest stored topic
    cursor.execute("Select * from topic ORDER BY topic_id DESC LIMIT 1")
    result = cursor.fetchall()
    topic_id = result[0][0]
    #save the topic_id,model_id in r_topic_model table 
    cursor.execute(" INSERT INTO r_topic_model(topic_id,model_id) VALUES (%s,%s)",
                  (topic_id,model_id,))
    
    '''
    saving topic-document proportion for each topic-doc pairs
    '''
    #r_topic_post : topic_id, post_id, proportion
    doc_counter = 0
    for doc_id in list(text_df.id):
        cursor.execute(" INSERT INTO r_topic_post(topic_id,post_id,proportion) VALUES (%s,%s,%s)",
                  (topic_id,doc_id,float(topic_doc_dist[doc_counter,k])))
        doc_counter += 1

# %%
cnx.commit()

# %%
# cursor.execute("delete from r_topic_model")
# cursor.execute("delete from r_topic_post")
# cursor.execute("delete from topic")
# cursor.execute("delete from model")

# cursor.execute("select * from post")
# cursor.execute("SELECT DISTINCT user.* FROM user JOIN post ON user.user_id = post.user_id WHERE post.platform_type_id = %s",('4',))
# cursor.execute("SELECT * FROM post WHERE user_id = %s AND created BETWEEN %s AND %s;",(3,'1/1/2023','1/1/2013',))
# cursor.execute("SELECT r_topic_post.topic_id, AVG(r_topic_post.proportion) as average_proportion FROM r_topic_post JOIN r_topic_model ON r_topic_post.topic_id = r_topic_model.topic_id WHERE r_topic_post.post_id = %s AND r_topic_model.model_id = %s GROUP BY r_topic_post.topic_id;",('1187','2',))
# cursor.execute('select * from model')
cursor.fetchall()
# Out:
# [(11, Decimal('0.005300000')),
#  (12, Decimal('0.223030000')),
#  (13, Decimal('0.002400000')),
#  (14, Decimal('0.007130000')),
#  (15, Decimal('0.005350000')),
#  (16, Decimal('0.012220000')),
#  (17, Decimal('0.006210000')),
#  (18, Decimal('0.005680000')),
#  (19, Decimal('0.004940000')),
#  (20, Decimal('0.727740000'))]

# %% [markdown]
# # Post-processing for Author-topic distribution
#
# **if you are reading from DB set the from_db= True**

# %%
from_db = False

# %%
if not from_db:
    topics = [[i,topic_score_avg[i],'_'.join(top_terms[i].split()[0:3])] \
              for i in range(len(top_terms))]
else:
    #taking last topics 
    cursor.execute("select * from topic")
    topics = [list(i[0:2]) + ['_'.join(i[2:6])] for i in cursor.fetchall()[-7:]] #each topic include topic_id, coherence_score and top three terms

# %%
topics
# Out:
# [[0, 0.13093816558924454, 'cup_chocolate_tbsp'],
#  [1, 0.03679840662145004, 'guys_new_video'],
#  [2, 0.05682526304229091, 'recovery_hard_better'],
#  [3, 0.07237440927610028, 'home_morning_last'],
#  [4, 0.17858081356084665, 'food_eating_body'],
#  [5, 0.15583521058337063, 'bowl_oats_butter'],
#  [6, 0.06630970139832629, '#glutenfree_#healthy_#foodie'],
#  [7, 0.07591599143525932, 'school_uk_family'],
#  [8, 0.022238935549487533, 'body_look_real'],
#  [9, 0.0775602157688427, 'yoga_run_running'],
#  [10, 0.03580528305488123, 'vegan_plant_based'],
#  [11, 0.04026261422511173, 'self_take_years'],
#  [12, 0.14623481894280768, 'body_look_skin'],
#  [13, 0.06123383898506602, 'eating_support_alliance'],
#  [14, 0.09385309418283183, 'therapy_session_bit'],
#  [15, 0.06777174823724447, 'fucking_recovery_shit']]

# %%
#taking post_topics
if from_db:
    cursor.execute("select * from r_topic_post where topic_id between {0} and {1}".format(min(topics)[0],max(topics)[0]))
    res = cursor.fetchall() #topic_id, document_id, topic_dist
    
    doc_dist = {}
    
    for item in res:
        if item[1] not in doc_dist.keys():
            doc_dist[item[1]] = {}
        doc_dist[item[1]][item[0]] = item[2]
else:
    doc_dist = text_df.iloc[:,6:6+len(topics)].values.copy().T#topic_doc_dist.copy().T

# %%
#clipping doc_dist and converting to pandas DF as well
from tqdm import tqdm
from similarity import picking_topic

ddist_df = pd.DataFrame(doc_dist).T

ddist_np = ddist_df.values

for i in tqdm(range(ddist_np.shape[0])):
    ddist_np[i] = picking_topic(ddist_np[i].astype('float')) * ddist_np[i].astype('float')
# Out:
# 100%|██████████████████████████████████| 13360/13360 [00:00<00:00, 16508.34it/s]

# %%
if from_db:
    ddist_df = ddist_df.rename(columns={i[0]:i[2] for i in topics})
    ddist_df['id'] = ddist_df.index
    ddist_df = ddist_df.merge(text_df[['id','blog']],on='id')
else:
    ddist_df = ddist_df.rename(columns={i[0]:i[2] for i in topics})
    ddist_df['id'] = list(text_df.id)
    ddist_df['blog'] = list(text_df.blog)

# %%
ddist_blog = ddist_df.groupby('blog').sum()
ddist_blog.iloc[:,0:-1] = ddist_blog.values[:,0:-1]/np.sum(ddist_blog.values[:,0:-1],axis=0)
ddist_blog
# Out:
#                           cup_chocolate_tbsp  guys_new_video  \
# blog
# Breeelenehan                        0.002516        0.147604
# alliancefored                       0.000643        0.009987
# amandavsevilla                      0.004356        0.032375
# anxiousgayyy                        0.000000        0.000000
# ariessuntaurusrising                0.000790        0.005162
# bagelbells                          0.000489        0.005943
# brittle-bunny                       0.000000        0.000567
# faithhopeloveandtherapy             0.007835        0.037521
# fearless-foodie                     0.000000        0.012592
# finallyrecoveringforgood            0.000000        0.001678
# fuck-eatingdisorders                0.000000        0.001238
# healthfulradiance                   0.950749        0.018355
# hellsite-residential                0.000000        0.002189
# imtrying-butimpissed                0.001653        0.025329
# intentandotrascender                0.000000        0.000000
# itsclairexu                         0.021839        0.016792
# lets-get-better                     0.000000        0.001367
# matchayogurt                        0.000422        0.002200
# mirithebrave                        0.000000        0.026035
# mote-of-dust                        0.000000        0.001958
# palpitationstation                  0.002530        0.014099
# rec-hovery                          0.000000        0.000000
# shameofateen                        0.000000        0.001566
# veganhollyg                         0.006178        0.635444
#
#                           recovery_hard_better  home_morning_last  \
# blog
# Breeelenehan                          0.004664           0.047340
# alliancefored                         0.009379           0.010921
# amandavsevilla                        0.009347           0.036984
# anxiousgayyy                          0.013962           0.002370
# ariessuntaurusrising                  0.061001           0.023395
# bagelbells                            0.017330           0.009540
# brittle-bunny                         0.022144           0.010263
# faithhopeloveandtherapy               0.080160           0.374732
# fearless-foodie                       0.258602           0.027845
# finallyrecoveringforgood              0.029767           0.007057
# fuck-eatingdisorders                  0.005926           0.000504
# healthfulradiance                     0.013305           0.109074
# hellsite-residential                  0.026573           0.008537
# imtrying-butimpissed                  0.224475           0.089143
# intentandotrascender                  0.004379           0.000000
# itsclairexu                           0.030968           0.124866
# lets-get-better                       0.013736           0.009424
# matchayogurt                          0.005585           0.002751
# mirithebrave                          0.058111           0.019123
# mote-of-dust                          0.024507           0.001022
# palpitationstation                    0.065510           0.043790
# rec-hovery                            0.000784           0.000272
# shameofateen                          0.013773           0.002587
# veganhollyg                           0.006011           0.038461
#
#                           food_eating_body  bowl_oats_butter  \
# blog
# Breeelenehan                      0.063769          0.008559
# alliancefored                     0.003106          0.000000
# amandavsevilla                    0.024930          0.033738
# anxiousgayyy                      0.020589          0.000459
# ariessuntaurusrising              0.032345          0.004841
# bagelbells                        0.024444          0.003007
# brittle-bunny                     0.031666          0.005309
# faithhopeloveandtherapy           0.116216          0.092721
# fearless-foodie                   0.013054          0.000000
# finallyrecoveringforgood          0.027228          0.002511
# fuck-eatingdisorders              0.007752          0.000000
# healthfulradiance                 0.031786          0.288667
# hellsite-residential              0.065590          0.004558
# imtrying-butimpissed              0.134320          0.031537
# intentandotrascender              0.009020          0.000000
# itsclairexu                       0.193642          0.377469
# lets-get-better                   0.046677          0.000000
# matchayogurt                      0.022233          0.002290
# mirithebrave                      0.008929          0.002257
# mote-of-dust                      0.029777          0.001800
# palpitationstation                0.059942          0.009552
# rec-hovery                        0.005891          0.000000
# shameofateen                      0.008170          0.000625
# veganhollyg                       0.018922          0.130101
#
#                           #glutenfree_#healthy_#foodie  school_uk_family  \
# blog
# Breeelenehan                                  0.000000          0.010497
# alliancefored                                 0.000000          0.038094
# amandavsevilla                                0.003700          0.017570
# anxiousgayyy                                  0.000000          0.000000
# ariessuntaurusrising                          0.000000          0.013596
# bagelbells                                    0.000000          0.012989
# brittle-bunny                                 0.000644          0.000762
# faithhopeloveandtherapy                       0.006897          0.534408
# fearless-foodie                               0.000000          0.102314
# finallyrecoveringforgood                      0.000000          0.000000
# fuck-eatingdisorders                          0.000000          0.001700
# healthfulradiance                             0.961954          0.000944
# hellsite-residential                          0.000000          0.015767
# imtrying-butimpissed                          0.001321          0.028804
# intentandotrascender                          0.000000          0.000640
# itsclairexu                                   0.006750          0.024418
# lets-get-better                               0.000000          0.001763
# matchayogurt                                  0.000000          0.008523
# mirithebrave                                  0.000000          0.094952
# mote-of-dust                                  0.000000          0.003577
# palpitationstation                            0.000000          0.074118
# rec-hovery                                    0.000000          0.005020
# shameofateen                                  0.000000          0.000000
# veganhollyg                                   0.018734          0.009545
#
#                           body_look_real  yoga_run_running  vegan_plant_based  \
# blog
# Breeelenehan                    0.532144          0.051082           0.169424
# alliancefored                   0.001347          0.047564           0.016619
# amandavsevilla                  0.007380          0.277077           0.163188
# anxiousgayyy                    0.000000          0.000000           0.002866
# ariessuntaurusrising            0.000000          0.016251           0.002448
# bagelbells                      0.007757          0.029055           0.004469
# brittle-bunny                   0.000000          0.000000           0.000000
# faithhopeloveandtherapy         0.002940          0.201036           0.031670
# fearless-foodie                 0.005193          0.017938           0.007145
# finallyrecoveringforgood        0.003951          0.000000           0.000000
# fuck-eatingdisorders            0.000000          0.001079           0.000000
# healthfulradiance               0.022796          0.052321           0.162301
# hellsite-residential            0.000000          0.008784           0.002096
# imtrying-butimpissed            0.024383          0.004956           0.020977
# intentandotrascender            0.000000          0.001721           0.000000
# itsclairexu                     0.025647          0.028188           0.308957
# lets-get-better                 0.009668          0.000000           0.000000
# matchayogurt                    0.002322          0.013371           0.004310
# mirithebrave                    0.004228          0.046792           0.009581
# mote-of-dust                    0.000000          0.002019           0.000000
# palpitationstation              0.004483          0.067552           0.021207
# rec-hovery                      0.000000          0.000000           0.000000
# shameofateen                    0.003199          0.001519           0.000000
# veganhollyg                     0.342563          0.131694           0.072743
#
#                           self_take_years  body_look_skin  \
# blog
# Breeelenehan                     0.064852        0.044392
# alliancefored                    0.087774        0.023086
# amandavsevilla                   0.172625        0.036326
# anxiousgayyy                     0.001188        0.005122
# ariessuntaurusrising             0.014462        0.064333
# bagelbells                       0.013290        0.025764
# brittle-bunny                    0.001830        0.013720
# faithhopeloveandtherapy          0.067666        0.112877
# fearless-foodie                  0.047745        0.037550
# finallyrecoveringforgood         0.002976        0.009779
# fuck-eatingdisorders             0.002041        0.000000
# healthfulradiance                0.073976        0.044748
# hellsite-residential             0.001517        0.015348
# imtrying-butimpissed             0.048961        0.118443
# intentandotrascender             0.001485        0.000000
# itsclairexu                      0.238720        0.051194
# lets-get-better                  0.009209        0.040396
# matchayogurt                     0.001563        0.004865
# mirithebrave                     0.044489        0.131193
# mote-of-dust                     0.020589        0.022183
# palpitationstation               0.046328        0.163693
# rec-hovery                       0.000985        0.000000
# shameofateen                     0.001269        0.009290
# veganhollyg                      0.034460        0.025698
#
#                           eating_support_alliance  therapy_session_bit  \
# blog
# Breeelenehan                             0.000727             0.004226
# alliancefored                            0.950848             0.005924
# amandavsevilla                           0.000727             0.007150
# anxiousgayyy                             0.000000             0.000788
# ariessuntaurusrising                     0.002121             0.017608
# bagelbells                               0.001613             0.004020
# brittle-bunny                            0.000000             0.006898
# faithhopeloveandtherapy                  0.005718             0.847348
# fearless-foodie                          0.006258             0.021363
# finallyrecoveringforgood                 0.000924             0.003832
# fuck-eatingdisorders                     0.001261             0.000318
# healthfulradiance                        0.000943             0.001653
# hellsite-residential                     0.000761             0.003524
# imtrying-butimpissed                     0.006039             0.015512
# intentandotrascender                     0.000000             0.000713
# itsclairexu                              0.003818             0.004555
# lets-get-better                          0.000000             0.001730
# matchayogurt                             0.001113             0.000497
# mirithebrave                             0.011359             0.013848
# mote-of-dust                             0.000659             0.001458
# palpitationstation                       0.003357             0.018567
# rec-hovery                               0.001754             0.000000
# shameofateen                             0.000000             0.003111
# veganhollyg                              0.000000             0.015357
#
#                           fucking_recovery_shit        id
# blog
# Breeelenehan                           0.003936   1817888
# alliancefored                          0.000537   6029796
# amandavsevilla                         0.007206   6064822
# anxiousgayyy                           0.013777    132541
# ariessuntaurusrising                   0.047891   4032806
# bagelbells                             0.056688   3125727
# brittle-bunny                          0.006597   2315848
# faithhopeloveandtherapy                0.027912  37023154
# fearless-foodie                        0.026350  13335756
# finallyrecoveringforgood               0.012652   1422428
# fuck-eatingdisorders                   0.002690    514741
# healthfulradiance                      0.002465  14660880
# hellsite-residential                   0.036415   3786588
# imtrying-butimpissed                   0.295391   6672342
# intentandotrascender                   0.000000    214931
# itsclairexu                            0.005789  14188297
# lets-get-better                        0.019570   1696667
# matchayogurt                           0.028285    940846
# mirithebrave                           0.013612   4726871
# mote-of-dust                           0.004893   1726371
# palpitationstation                     0.377692  19109199
# rec-hovery                             0.005196    294559
# shameofateen                           0.003111   1097491
# veganhollyg                            0.001345  12465920

# %%
import seaborn as sns
from matplotlib import pyplot as plt
plt.figure(figsize=(15,15))
sns.set(font_scale=1)
sns.heatmap(ddist_blog.iloc[:,0:-1].astype('float').T,fmt=".2f",annot=True)

plt.xticks(rotation=30,ha='right') 
plt.savefig('./result/edml/lda_nodejs.svg')
# plt.show()

# %%
list(text_df[text_df.id == 16638].url)
# Out:
# ['https://faithhopeloveandtherapy.tumblr.com/post/189209497991/strangecupoftea-we-must-risk-unlearning-what']

# %%
topics[0][2]
# Out:
# '#glutenfree_#healthy_#foodie'

# %%
topic_num = 13
top_terms_n = 10

df = pd.DataFrame()

for i in range(topic_num):
    temp_df = pd.DataFrame(text_df.sort_values('Topic'+str(i)+'_dist',ascending=False).head(20)[['original_text','url']])
    temp_df['topic'] = topics[i][2]
    #bold the terms in top terms
    topic_top_terms = top_terms[i].split()[0:top_terms_n]
    temp_df['top_terms'] = '_'.join(topic_top_terms)
    texts = list(temp_df['original_text'])
    for i in range(len(texts)):
        for term in topic_top_terms:
            texts[i] = texts[i].replace(term,'<b>{0}</b>'.format(term))
    temp_df['original_text'] = texts
    df = pd.concat([temp_df,df])

df.iloc[-1].original_text,df.iloc[-1].top_terms
# Out:
# ("like a regular loaded veg bowl, but elevated 🤷🏻\u200d♀️ all of my current faves in one spot. doesn't get better than that 🤤 i'm out for the rest of the day, hope it's been a good one for you all! ▪️▪️▪️▪️▪️▪️▪️▪️▪️▪️\nroasted purple brussel sprouts, roasted curry cauliflower, roasted zucchini chunks, loaded eggplant stew, roasted carrot chips, sun-dried tomato cashew cream, olive oil drizzle\n.\n.\n<b>#healthy</b> <b>#healthy</b>food #vegan #thefeedfeed #thefeedfeedvegan #mbg #thechalkboardeats #foodgrams <b>#wellness</b> #blogger #hbfit #wellandgoodeats #curry #vegancurry <b>#fitness</b> #healthblogger <b>#healthy</b>recipe #whatveganseat #buzzfeedfood #blogger <b>#healthy</b>dinner <b>#healthy</b>stew #veggiebowl #kale #veganfoodspace #grainfree <b>#glutenfree</b> #paleo #eggplant #cauli #roastedveg",
#  '#glutenfree_#healthy_#foodie_#healthyfood_#foodblogger_#wellness_#healthyinspo_#healthylife_#plantpower_#fitness')

# %%
df
# Out:
#                                           original_text  \
# 6786  Guess who just booked the next #<b>holly</b>go...
# 7325  Sorry for another pic from May Ball, but it ga...
# 6740  Come with us to the mountains 🏔✨ Episode  of t...
# 1487  Wanted to say a huge THANK YOU for all the lov...
# 7197  I love London 🇬🇧 But one of my favourite thing...
# ...                                                 ...
# 3315  hitting all my OG followers in their feels wit...
# 3165  more...thanksgiving...leftovers... 😚 bc i know...
# 3078  on wednesday we *eat* pink...and on thursday w...
# 2835  i just tried pasta salad for the first time…\n...
# 3660  like a regular loaded veg bowl, but elevated 🤷...
#
#                                            url                         topic
# 6786  https://www.instagram.com/p/Ce0X-05N5pB/                guys_new_video
# 7325  https://www.instagram.com/p/BVzNLpAlcru/                guys_new_video
# 6740  https://www.instagram.com/p/CidKIngAr2e/                guys_new_video
# 1487  https://www.instagram.com/p/BwBq2mBhJQ1/                guys_new_video
# 7197  https://www.instagram.com/p/Bmu8FutAvTm/                guys_new_video
# ...                                        ...                           ...
# 3315  https://www.instagram.com/p/CAGbjJFJCiQ/  #glutenfree_#healthy_#foodie
# 3165  https://www.instagram.com/p/CIMHpXxD-8F/  #glutenfree_#healthy_#foodie
# 3078  https://www.instagram.com/p/CNswcYqjwVC/  #glutenfree_#healthy_#foodie
# 2835  https://www.instagram.com/p/CgzUBB6q8L6/  #glutenfree_#healthy_#foodie
# 3660  https://www.instagram.com/p/BzOgm6MDQqK/  #glutenfree_#healthy_#foodie
#
# [260 rows x 3 columns]

# %%
import math, datetime
import rpy2.robjects.lib.ggplot2 as ggplot2
import rpy2.robjects as ro
from rpy2.robjects.packages import importr
base = importr('base')

dataf_rnorm = robjects.DataFrame(ddist_blog.iloc[:,0:-1])
robjects.r(''' 
library(data.table)
topic.title.tall <- melt(setDT(ddist_blog), id.vars = c("title"), variable.name = "topic")
''')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[206], line 7
#       4 from rpy2.robjects.packages import importr
#       5 base = importr('base')
# ----> 7 dataf_rnorm = robjects.DataFrame(ddist_blog.iloc[:,0:-1])
#       8 robjects.r('''
#       9 library(data.table)
#      10 topic.title.tall <- melt(setDT(ddist_blog), id.vars = c("title"), variable.name = "topic")
#      11 ''')
#
# File /usr/local/lib/python3.9/site-packages/rpy2/robjects/vectors.py:1292, in DataFrame.__init__(self, obj, stringsasfactor, checknames)
#    1290 cv = conversion.get_conversion()
#    1291 try:
# -> 1292     kv = [(str(k), cv.py2rpy(v)) for k, v in obj.items()]
#    1293 except AttributeError:
#    1294     raise ValueError(
#    1295         'obj can only be'
#    1296         'an instance of rpy2.rinterface.ListSexpVector, '
#    (...)
#    1299         '(key, value) pairs '
#    1300         '(such a Python dict, rpy2.rlike.container OrdDict).')
#
# File /usr/local/lib/python3.9/site-packages/rpy2/robjects/vectors.py:1292, in <listcomp>(.0)
#    1290 cv = conversion.get_conversion()
#    1291 try:
# -> 1292     kv = [(str(k), cv.py2rpy(v)) for k, v in obj.items()]
#    1293 except AttributeError:
#    1294     raise ValueError(
#    1295         'obj can only be'
#    1296         'an instance of rpy2.rinterface.ListSexpVector, '
#    (...)
#    1299         '(key, value) pairs '
#    1300         '(such a Python dict, rpy2.rlike.container OrdDict).')
#
# File /usr/local/Cellar/python@3.9/3.9.16/Frameworks/Python.framework/Versions/3.9/lib/python3.9/functools.py:888, in singledispatch.<locals>.wrapper(*args, **kw)
#     884 if not args:
#     885     raise TypeError(f'{funcname} requires at least '
#     886                     '1 positional argument')
# --> 888 return dispatch(args[0].__class__)(*args, **kw)
#
# File /usr/local/lib/python3.9/site-packages/rpy2/robjects/pandas2ri.py:223, in py2rpy_pandasseries(obj)
#     216             raise ValueError(
#     217                 'Series can only be of one type, or None '
#     218                 '(and here we have %s and %s). If happening with '
#     219                 'a pandas DataFrame the method infer_objects() '
#     220                 'will normalize data types before conversion.' %
#     221                 (homogeneous_type, type(x)))
#     222     # TODO: Could this be merged with obj.type.name == 'O' case above ?
# --> 223     res = _PANDASTYPE2RPY2[homogeneous_type](obj)
#     224 elif type(obj.dtype) in (pandas.Float64Dtype, pandas.BooleanDtype):
#     225     res = _PANDASTYPE2RPY2[type(obj.dtype)](obj)
#
# KeyError: <class 'float'>

# %%
from plotnine import ggplot, aes, geom_line,geom_tile, scale_fill_gradient
(
ggplot(ddist_blog.iloc[:,0:-1], aes(x='blog')) +
    # geom_tile(aes(fill = value)) + 
    # geom_text(aes(label = round(value, 2))) +
    scale_fill_gradient(low = "white", high = "red")
    # +theme(text = element_text(size=20),axis.text.x = element_text(angle=45, hjust=1))
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /usr/local/lib/python3.9/site-packages/plotnine/mapping/evaluation.py:228, in evaluate(aesthetics, data, env)
#     227 try:
# --> 228     new_val = env.eval(col, inner_namespace=data)
#     229 except Exception as e:
#
# File /usr/local/lib/python3.9/site-packages/patsy/eval.py:169, in EvalEnvironment.eval(self, expr, source_name, inner_namespace)
#     168 code = compile(expr, source_name, "eval", self.flags, False)
# --> 169 return eval(code, {}, VarLookupDict([inner_namespace]
#     170                                     + self._namespaces))
#
# File <string>:1
#
# NameError: name 'blog' is not defined
#
# During handling of the above exception, another exception occurred:
#
# PlotnineError                             Traceback (most recent call last)
# File /usr/local/lib/python3.9/site-packages/IPython/core/formatters.py:708, in PlainTextFormatter.__call__(self, obj)
#     701 stream = StringIO()
#     702 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     703     self.max_width, self.newline,
#     704     max_seq_length=self.max_seq_length,
#     705     singleton_pprinters=self.singleton_printers,
#     706     type_pprinters=self.type_printers,
#     707     deferred_pprinters=self.deferred_printers)
# --> 708 printer.pretty(obj)
#     709 printer.flush()
#     710 return stream.getvalue()
#
# File /usr/local/lib/python3.9/site-packages/IPython/lib/pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
#     409                         and callable(cls.__dict__.get('__repr__')):
# --> 410                     return _repr_pprint(obj, self, cycle)
#     412     return _default_pprint(obj, self, cycle)
#     413 finally:
#
# File /usr/local/lib/python3.9/site-packages/IPython/lib/pretty.py:778, in _repr_pprint(obj, p, cycle)
#     776 """A pprint that just redirects to the normal repr function."""
#     777 # Find newlines and replace them with p.break_()
# --> 778 output = repr(obj)
#     779 lines = output.splitlines()
#     780 with p.group():
#
# File /usr/local/lib/python3.9/site-packages/plotnine/ggplot.py:114, in ggplot.__repr__(self)
#     110 def __repr__(self) -> str:
#     111     """
#     112     Print/show the plot
#     113     """
# --> 114     figure = self.draw(show=True)
#     116     dpi = figure.get_dpi()
#     117     W = int(figure.get_figwidth() * dpi)
#
# File /usr/local/lib/python3.9/site-packages/plotnine/ggplot.py:224, in ggplot.draw(self, show)
#     222 self = deepcopy(self)
#     223 with plot_context(self, show=show):
# --> 224     self._build()
#     226     # setup
#     227     figure, axs = self._create_figure()
#
# File /usr/local/lib/python3.9/site-packages/plotnine/ggplot.py:314, in ggplot._build(self)
#     310 layout.setup(layers, self)
#     312 # Compute aesthetics to produce data with generalised
#     313 # variable names
# --> 314 layers.compute_aesthetics(self)
#     316 # Transform data using all scales
#     317 layers.transform(scales)
#
# File /usr/local/lib/python3.9/site-packages/plotnine/layer.py:467, in Layers.compute_aesthetics(self, plot)
#     465 def compute_aesthetics(self, plot: Ggplot):
#     466     for l in self:
# --> 467         l.compute_aesthetics(plot)
#
# File /usr/local/lib/python3.9/site-packages/plotnine/layer.py:260, in layer.compute_aesthetics(self, plot)
#     253 def compute_aesthetics(self, plot: Ggplot):
#     254     """
#     255     Return a dataframe where the columns match the aesthetic mappings
#     256
#     257     Transformations like 'factor(cyl)' and other
#     258     expression evaluation are  made in here
#     259     """
# --> 260     evaled = evaluate(self.mapping._starting, self.data, plot.environment)
#     261     evaled_aes = aes(**{str(col): col for col in evaled})
#     262     plot.scales.add_defaults(evaled, evaled_aes)
#
# File /usr/local/lib/python3.9/site-packages/plotnine/mapping/evaluation.py:230, in evaluate(aesthetics, data, env)
#     228     new_val = env.eval(col, inner_namespace=data)
#     229 except Exception as e:
# --> 230     raise PlotnineError(_TPL_EVAL_FAIL.format(ae, col, str(e)))
#     232 try:
#     233     evaled[ae] = new_val
#
# PlotnineError: "Could not evaluate the 'x' mapping: 'blog' (original error: name 'blog' is not defined)"

# %%
ddist_blog
# Out:
#                      eating_support_alliance_us bowl_oats_butter_almond  \
# blog
# Breeelenehan                           0.004505                0.011943
# alliancefored                          0.901694                0.000727
# amandavsevilla                         0.009553                0.019371
# anxiousgayyy                           0.000502                     0.0
# healthfulradiance                      0.009095                0.587512
# imtrying-butimpissed                   0.024045                0.015182
# itsclairexu                            0.036686                0.293368
# veganhollyg                            0.013919                0.071898
#
#                      life_body_feel_like roasted_#healthy_oil_add  \
# blog
# Breeelenehan                    0.032642                 0.002196
# alliancefored                   0.074312                      0.0
# amandavsevilla                  0.158634                 0.015112
# anxiousgayyy                    0.020532                 0.000634
# healthfulradiance                0.09613                 0.699153
# imtrying-butimpissed            0.285263                 0.004865
# itsclairexu                      0.30226                  0.09059
# veganhollyg                     0.030227                 0.187451
#
#                      body_like_feel_day day_time_one_like  \
# blog
# Breeelenehan                   0.805447          0.123988
# alliancefored                  0.035109          0.021241
# amandavsevilla                 0.018207           0.11161
# anxiousgayyy                   0.002199          0.002959
# healthfulradiance              0.027373          0.112608
# imtrying-butimpissed           0.031289          0.040838
# itsclairexu                     0.05645          0.139927
# veganhollyg                    0.023927          0.446829
#
#                      cup_chocolate_butter_add        id
# blog
# Breeelenehan                         0.006482   1873399
# alliancefored                        0.000715   6127291
# amandavsevilla                       0.005156   6136628
# anxiousgayyy                              0.0    132541
# healthfulradiance                    0.944535  14710522
# imtrying-butimpissed                      0.0   1490061
# itsclairexu                           0.03727  14539093
# veganhollyg                          0.005842  12825333
